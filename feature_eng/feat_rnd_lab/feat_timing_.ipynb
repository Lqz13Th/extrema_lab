# %%
import sys
import os
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

def add_project_root(project_name: str = "extrema_lab"):
    cwd = os.getcwd()
    path_parts = cwd.split(os.sep)

    for i in range(len(path_parts), 0, -1):
        potential_root = os.sep.join(path_parts[:i])
        if os.path.basename(potential_root) == project_name:
            root = os.path.dirname(potential_root)
            if root not in sys.path:
                sys.path.append(root)
            print(f"added sys.path: {root}")
            return

    print(f"failed to fund {project_name}")


add_project_root("extrema_lab")
from extrema_lab.feature_eng.operator.utils_tools import *
# Out:
# added sys.path: C:\quant\work

# %%
symbol = "BTCUSDT"
threshold = 0.0031
feat_cal_window = 400
feat_norm_window = 400
feat_norm_rolling_mean_window = 200

origin_df = process_single_symbol(
    symbol,
    str(threshold),
    feat_cal_window,
    feat_norm_window,
    feat_norm_rolling_mean_window,
)

# %%
prices_np = origin_df["px"].to_numpy()[:20000]
avg_steps_05pct = avg_steps_to_volatility(prices_np, 0.005)
avg_steps_1pct = avg_steps_to_volatility(prices_np, 0.01)
avg_steps_2pct = avg_steps_to_volatility(prices_np, 0.02)
avg_steps_5pct = avg_steps_to_volatility(prices_np, 0.05)

print("波动 ±0.5% 的均值步数:", avg_steps_05pct)
print("波动 ±1% 的均值步数:", avg_steps_1pct)
print("波动 ±2% 的均值步数:", avg_steps_2pct)
print("波动 ±5% 的均值步数:", avg_steps_5pct)

origin_df = origin_df.with_columns([
    future_return_expr("px", avg_steps_05pct),
    future_return_expr("px", avg_steps_1pct),
    future_return_expr("px", avg_steps_2pct),
    future_return_expr("px", avg_steps_5pct),
])
print(origin_df)
origin_df = clean_df_drop_nulls(origin_df)
# Out:
# cal abs change 0.50% avg steps: 100%|██████████| 20000/20000 [00:00<00:00, 706123.67it/s]
# cal abs change 1.00% avg steps: 100%|██████████| 20000/20000 [00:00<00:00, 295652.52it/s]
# cal abs change 2.00% avg steps: 100%|██████████| 20000/20000 [00:00<00:00, 111540.26it/s]
# cal abs change 5.00% avg steps: 100%|██████████| 20000/20000 [00:00<00:00, 21463.69it/s]
# 波动 ±0.5% 的均值步数: 3
# 波动 ±1% 的均值步数: 14
# 波动 ±2% 的均值步数: 42
# 波动 ±5% 的均值步数: 245
# shape: (28_476, 273)
# ┌───────────┬──────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ timestamp ┆ px       ┆ sum_buy_s ┆ sum_sell_ ┆ … ┆ future_re ┆ future_re ┆ future_re ┆ future_re │
# │ ---       ┆ ---      ┆ z         ┆ sz        ┆   ┆ turn_3    ┆ turn_14   ┆ turn_42   ┆ turn_245  │
# │ i64       ┆ f64      ┆ ---       ┆ ---       ┆   ┆ ---       ┆ ---       ┆ ---       ┆ ---       │
# │           ┆          ┆ f64       ┆ f64       ┆   ┆ f64       ┆ f64       ┆ f64       ┆ f64       │
# ╞═══════════╪══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ 171979596 ┆ 63024.4  ┆ 1641.967  ┆ 1536.403  ┆ … ┆ 0.009333  ┆ -0.000073 ┆ -0.005355 ┆ -0.074165 │
# │ 6326000   ┆          ┆           ┆           ┆   ┆           ┆           ┆           ┆           │
# │ 171979597 ┆ 63219.8  ┆ 898.765   ┆ 39.16     ┆ … ┆ 0.003094  ┆ -0.006256 ┆ -0.005354 ┆ -0.079891 │
# │ 5796000   ┆          ┆           ┆           ┆   ┆           ┆           ┆           ┆           │
# │ 171979626 ┆ 63416.0  ┆ 3760.013  ┆ 2373.812  ┆ … ┆ 0.003091  ┆ -0.012404 ┆ -0.005357 ┆ -0.079892 │
# │ 8042000   ┆          ┆           ┆           ┆   ┆           ┆           ┆           ┆           │
# │ 171979634 ┆ 63612.6  ┆ 2565.745  ┆ 1159.27   ┆ … ┆ -0.003113 ┆ -0.012403 ┆ -0.011506 ┆ -0.07989  │
# │ 2454000   ┆          ┆           ┆           ┆   ┆           ┆           ┆           ┆           │
# │ 171979660 ┆ 63415.4  ┆ 1848.221  ┆ 2138.772  ┆ … ┆ -0.003113 ┆ -0.012404 ┆ -0.011507 ┆ -0.079891 │
# │ 1035000   ┆          ┆           ┆           ┆   ┆           ┆           ┆           ┆           │
# │ …         ┆ …        ┆ …         ┆ …         ┆ … ┆ …         ┆ …         ┆ …         ┆ …         │
# │ 175665540 ┆ 108754.5 ┆ 10184.342 ┆ 8017.601  ┆ … ┆ -0.003111 ┆ null      ┆ null      ┆ null      │
# │ 2467000   ┆          ┆           ┆           ┆   ┆           ┆           ┆           ┆           │
# │ 175666550 ┆ 109091.7 ┆ 4283.963  ┆ 4567.019  ┆ … ┆ -0.009273 ┆ null      ┆ null      ┆ null      │
# │ 2324000   ┆          ┆           ┆           ┆   ┆           ┆           ┆           ┆           │
# │ 175668039 ┆ 108753.4 ┆ 3149.858  ┆ 3748.467  ┆ … ┆ null      ┆ null      ┆ null      ┆ null      │
# │ 9421000   ┆          ┆           ┆           ┆   ┆           ┆           ┆           ┆           │
# │ 175668229 ┆ 108416.2 ┆ 698.747   ┆ 1248.173  ┆ … ┆ null      ┆ null      ┆ null      ┆ null      │
# │ 7506000   ┆          ┆           ┆           ┆   ┆           ┆           ┆           ┆           │
# │ 175668354 ┆ 108080.1 ┆ 1695.162  ┆ 1773.764  ┆ … ┆ null      ┆ null      ┆ null      ┆ null      │
# │ 4043000   ┆          ┆           ┆           ┆   ┆           ┆           ┆           ┆           │
# └───────────┴──────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴───────────┘
# Converted Polars DataFrame to Pandas
# Null counts per column:
# future_return_3        3
# future_return_14      14
# future_return_42      42
# future_return_245    245
# dtype: int64
# Dropping columns with nulls greater than 500000: []
# Shape after dropping columns: (28476, 273)
# Shape after dropping rows with nulls: (28231, 273)

# %%
origin_df
# Out:
# shape: (28_231, 273)
# ┌───────────┬──────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ timestamp ┆ px       ┆ sum_buy_s ┆ sum_sell_ ┆ … ┆ future_re ┆ future_re ┆ future_re ┆ future_re │
# │ ---       ┆ ---      ┆ z         ┆ sz        ┆   ┆ turn_3    ┆ turn_14   ┆ turn_42   ┆ turn_245  │
# │ i64       ┆ f64      ┆ ---       ┆ ---       ┆   ┆ ---       ┆ ---       ┆ ---       ┆ ---       │
# │           ┆          ┆ f64       ┆ f64       ┆   ┆ f64       ┆ f64       ┆ f64       ┆ f64       │
# ╞═══════════╪══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ 171979596 ┆ 63024.4  ┆ 1641.967  ┆ 1536.403  ┆ … ┆ 0.009333  ┆ -0.000073 ┆ -0.005355 ┆ -0.074165 │
# │ 6326000   ┆          ┆           ┆           ┆   ┆           ┆           ┆           ┆           │
# │ 171979597 ┆ 63219.8  ┆ 898.765   ┆ 39.16     ┆ … ┆ 0.003094  ┆ -0.006256 ┆ -0.005354 ┆ -0.079891 │
# │ 5796000   ┆          ┆           ┆           ┆   ┆           ┆           ┆           ┆           │
# │ 171979626 ┆ 63416.0  ┆ 3760.013  ┆ 2373.812  ┆ … ┆ 0.003091  ┆ -0.012404 ┆ -0.005357 ┆ -0.079892 │
# │ 8042000   ┆          ┆           ┆           ┆   ┆           ┆           ┆           ┆           │
# │ 171979634 ┆ 63612.6  ┆ 2565.745  ┆ 1159.27   ┆ … ┆ -0.003113 ┆ -0.012403 ┆ -0.011506 ┆ -0.07989  │
# │ 2454000   ┆          ┆           ┆           ┆   ┆           ┆           ┆           ┆           │
# │ 171979660 ┆ 63415.4  ┆ 1848.221  ┆ 2138.772  ┆ … ┆ -0.003113 ┆ -0.012404 ┆ -0.011507 ┆ -0.079891 │
# │ 1035000   ┆          ┆           ┆           ┆   ┆           ┆           ┆           ┆           │
# │ …         ┆ …        ┆ …         ┆ …         ┆ … ┆ …         ┆ …         ┆ …         ┆ …         │
# │ 175606477 ┆ 112532.5 ┆ 821.407   ┆ 1139.653  ┆ … ┆ -0.00311  ┆ 0.006152  ┆ -0.013642 ┆ -0.033573 │
# │ 7907000   ┆          ┆           ┆           ┆   ┆           ┆           ┆           ┆           │
# │ 175606512 ┆ 112183.6 ┆ 1680.593  ┆ 2404.959  ┆ … ┆ 0.003091  ┆ 0.006152  ┆ -0.013644 ┆ -0.027561 │
# │ 7400000   ┆          ┆           ┆           ┆   ┆           ┆           ┆           ┆           │
# │ 175606521 ┆ 112531.4 ┆ 989.019   ┆ 820.207   ┆ … ┆ -0.003111 ┆ 0.006155  ┆ -0.013643 ┆ -0.033573 │
# │ 0012000   ┆          ┆           ┆           ┆   ┆           ┆           ┆           ┆           │
# │ 175606529 ┆ 112182.5 ┆ 293.219   ┆ 335.53    ┆ … ┆ -0.003113 ┆ 0.012413  ┆ -0.007508 ┆ -0.033573 │
# │ 0709000   ┆          ┆           ┆           ┆   ┆           ┆           ┆           ┆           │
# │ 175606556 ┆ 112530.4 ┆ 1127.979  ┆ 1135.316  ┆ … ┆ -0.003114 ┆ 0.005013  ┆ -0.007507 ┆ -0.039548 │
# │ 0085000   ┆          ┆           ┆           ┆   ┆           ┆           ┆           ┆           │
# └───────────┴──────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴───────────┘

# %%
import polars as pl
import matplotlib.pyplot as plt
a="z_oi_di_zscaled"
b="oi_di_zscaled"
# 假设 origin_df 是你的 Polars DataFrame
# 转成 pandas DataFrame
pdf = origin_df.select([
    a,
    b,
    "px"
]).to_pandas()[-150000:]
pdf['ma'] = pdf['px'].rolling(window=500).mean()


fig, ax1 = plt.subplots(figsize=(12, 6))

ax2 = ax1.twinx()  # 第二个y轴，右侧
ax3 = ax1.twinx()  # 第三个y轴，右侧，需要偏移避免重叠

# 偏移第三个y轴，让它不和第二个y轴重叠
ax3.spines["right"].set_position(("axes", 1.1))  # 向右偏移 10%

# 画线
ax1.plot(pdf[a], color='blue', label=a)
ax1.set_ylabel(a, color='blue')
ax1.tick_params(axis='y', colors='blue')

ax2.plot(pdf['ma'], color='orange', label='ma')
ax2.set_ylabel('ma', color='orange')
ax2.tick_params(axis='y', colors='orange')

ax3.plot(pdf["px"], color='green', label="px")
ax3.set_ylabel("px", color='green')
ax3.tick_params(axis='y', colors='green')

plt.title("Three curves with independent y axes")
plt.xlabel("Index")

# 合并图例
lines_1, labels_1 = ax1.get_legend_handles_labels()
lines_2, labels_2 = ax2.get_legend_handles_labels()
lines_3, labels_3 = ax3.get_legend_handles_labels()
plt.legend(lines_1 + lines_2 + lines_3, labels_1 + labels_2 + labels_3, loc='upper left')

plt.show()

# %%
def plot_last_n_rows_with_px(y_test, y_test_binary, y_pred_prob, px, std_array=None, n=700, m=-1, alpha=1):
    # 截取最后 n 行
    y_test_slice = y_test[n:m]
    y_test_binary_slice = y_test_binary[n:m]
    y_pred_prob_slice = y_pred_prob[n:m]
    px_slice = px[n:m]
    
    if std_array is not None:
        std_slice = std_array[n:m]
    else:
        std_slice = None

    time_index = np.arange(len(y_test_slice))

    fig, ax1 = plt.subplots(figsize=(16, 7))

    # # 原始收益
    # ax1.plot(time_index, y_test_slice, label="Original Future Returns", color='gray', alpha=0.8)
    # ax1.set_ylabel("Original Future Returns", color='gray')
    # ax1.tick_params(axis='y', labelcolor='gray')

    ax2 = ax1.twinx()
    ax2.scatter(time_index, y_test_binary_slice, label="GMM Labels", color='tab:blue', marker='o', s=20, alpha=0.7)
    ax2.set_ylabel("GMM Labels (0 or 1)", color='tab:blue')
    ax2.tick_params(axis='y', labelcolor='tab:blue')
    # ax2.set_ylim(-0.1, 1.1)

    # 模型预测概率
    ax3 = ax1.twinx()
    ax3.spines.right.set_position(("outward", 60))
    ax3.plot(time_index, y_pred_prob_slice, label="MODEL Predicted Probability", color='tab:green', alpha=0.4)
    ax3.set_ylabel("MODEL Predicted Probability", color='tab:green')
    ax3.tick_params(axis='y', labelcolor='tab:green')
    # ax3.set_ylim(-1.05, 1.05)

    # 价格线 (第4轴)
    ax4 = ax1.twinx()
    ax4.spines.right.set_position(("outward", 120))  # 再右移一层
    ax4.plot(time_index, px_slice, label="Price (px)", color='tab:blue', linestyle='--', alpha=0.6)

    # 加上下轨线
    if std_slice is not None:
        ax4.plot(time_index, px_slice + alpha * std_slice, label="Price + std", color='tab:gray', linestyle=':', alpha=0.4)
        ax4.plot(time_index, px_slice - alpha * std_slice, label="Price - std", color='tab:gray', linestyle=':', alpha=0.4)

    ax4.set_ylabel("Price (px)", color='tab:red')
    ax4.tick_params(axis='y', labelcolor='tab:red')

    # x轴
    ax1.set_xlabel("Time Index")
    plt.title(f"Compare Returns, Labels, Prediction & Price (Last {n} Rows)")

    # 图例
    lines_1, labels_1 = ax1.get_legend_handles_labels()
    # lines_2, labels_2 = ax2.get_legend_handles_labels()
    lines_3, labels_3 = ax3.get_legend_handles_labels()
    lines_4, labels_4 = ax4.get_legend_handles_labels()

    ax1.legend(
        lines_1 +  lines_3 + lines_4,
        labels_1 +  labels_3 + labels_4,
        loc='upper left'
    )

    plt.tight_layout()
    plt.show()

# %%
import polars as pl
import numpy as np
from tqdm import tqdm

rolling_window = 500
alpha = 5

exclude_prefixes = ['px', 'timestamp', 'timestamp_dt', 'symbol']
target_col = "future_std_label"
co = [
    col for col in origin_df.columns
    if col.endswith("_zscaled") 
        # and (col.startswith("z_")) 
        and all(not col.startswith(prefix) for prefix in exclude_prefixes)
        and not col.startswith("future_return_")
        and col != "px"
]
a_df = (
    origin_df
    .with_columns([
        pl.col("px").rolling_std(window_size=rolling_window).alias("rolling_std"),
        pl.mean_horizontal(co).alias("factor_mean"),
    ])
)

def label_by_future_std(px: np.ndarray, std: np.ndarray) -> np.ndarray:
    n = len(px)
    labels = np.full(n, -1)  # 初始化为 -1（未触发）

    for i in tqdm(range(n), desc="Labeling by future std"):
        anchor_price = px[i]
        for j in range(i + 1, n):
            upper_bound = anchor_price + alpha * std[j]
            lower_bound = anchor_price - alpha * std[j]
            if px[j] >= upper_bound:
                labels[i] = 1
                break
            elif px[j] <= lower_bound:
                labels[i] = 0
                break

            else:
                labels[i] = -1

    return labels

px_np = a_df["px"].to_numpy()
std_np = a_df["rolling_std"].to_numpy()

labels_np = label_by_future_std(px_np, std_np)

a_df = a_df.with_columns(pl.Series("future_std_label", labels_np))
print(a_df)
a_df_filtered = a_df.filter(pl.col("future_std_label") >= 0)
a_df_filtered = clean_df_drop_nulls(a_df_filtered)
print(a_df_filtered)

weekly_dataframes = split_df_by_week(a_df_filtered)
print("num weekly dfs: ", len(weekly_dataframes))
# Out:
# Labeling by future std: 100%|██████████| 28231/28231 [00:18<00:00, 1536.60it/s]
# shape: (28_231, 276)
# ┌───────────┬──────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ timestamp ┆ px       ┆ sum_buy_s ┆ sum_sell_ ┆ … ┆ future_re ┆ rolling_s ┆ factor_me ┆ future_st │
# │ ---       ┆ ---      ┆ z         ┆ sz        ┆   ┆ turn_245  ┆ td        ┆ an        ┆ d_label   │
# │ i64       ┆ f64      ┆ ---       ┆ ---       ┆   ┆ ---       ┆ ---       ┆ ---       ┆ ---       │
# │           ┆          ┆ f64       ┆ f64       ┆   ┆ f64       ┆ f64       ┆ f64       ┆ i32       │
# ╞═══════════╪══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ 171979596 ┆ 63024.4  ┆ 1641.967  ┆ 1536.403  ┆ … ┆ -0.074165 ┆ null      ┆ 0.0       ┆ 0         │
# │ 6326000   ┆          ┆           ┆           ┆   ┆           ┆           ┆           ┆           │
# │ 171979597 ┆ 63219.8  ┆ 898.765   ┆ 39.16     ┆ … ┆ -0.079891 ┆ null      ┆ 0.090238  ┆ 0         │
# │ 5796000   ┆          ┆           ┆           ┆   ┆           ┆           ┆           ┆           │
# │ 171979626 ┆ 63416.0  ┆ 3760.013  ┆ 2373.812  ┆ … ┆ -0.079892 ┆ null      ┆ 0.13664   ┆ 0         │
# │ 8042000   ┆          ┆           ┆           ┆   ┆           ┆           ┆           ┆           │
# │ 171979634 ┆ 63612.6  ┆ 2565.745  ┆ 1159.27   ┆ … ┆ -0.07989  ┆ null      ┆ 0.157     ┆ 0         │
# │ 2454000   ┆          ┆           ┆           ┆   ┆           ┆           ┆           ┆           │
# │ 171979660 ┆ 63415.4  ┆ 1848.221  ┆ 2138.772  ┆ … ┆ -0.079891 ┆ null      ┆ 0.093663  ┆ 0         │
# │ 1035000   ┆          ┆           ┆           ┆   ┆           ┆           ┆           ┆           │
# │ …         ┆ …        ┆ …         ┆ …         ┆ … ┆ …         ┆ …         ┆ …         ┆ …         │
# │ 175606477 ┆ 112532.5 ┆ 821.407   ┆ 1139.653  ┆ … ┆ -0.033573 ┆ 2889.8768 ┆ -0.140841 ┆ -1        │
# │ 7907000   ┆          ┆           ┆           ┆   ┆           ┆ 51        ┆           ┆           │
# │ 175606512 ┆ 112183.6 ┆ 1680.593  ┆ 2404.959  ┆ … ┆ -0.027561 ┆ 2896.0324 ┆ -0.140919 ┆ -1        │
# │ 7400000   ┆          ┆           ┆           ┆   ┆           ┆ 76        ┆           ┆           │
# │ 175606521 ┆ 112531.4 ┆ 989.019   ┆ 820.207   ┆ … ┆ -0.033573 ┆ 2901.5537 ┆ -0.140829 ┆ -1        │
# │ 0012000   ┆          ┆           ┆           ┆   ┆           ┆ 89        ┆           ┆           │
# │ 175606529 ┆ 112182.5 ┆ 293.219   ┆ 335.53    ┆ … ┆ -0.033573 ┆ 2908.5380 ┆ -0.141002 ┆ -1        │
# │ 0709000   ┆          ┆           ┆           ┆   ┆           ┆ 47        ┆           ┆           │
# │ 175606556 ┆ 112530.4 ┆ 1127.979  ┆ 1135.316  ┆ … ┆ -0.039548 ┆ 2914.0160 ┆ -0.140888 ┆ -1        │
# │ 0085000   ┆          ┆           ┆           ┆   ┆           ┆ 15        ┆           ┆           │
# └───────────┴──────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴───────────┘
# Converted Polars DataFrame to Pandas
# Null counts per column:
# rolling_std    499
# dtype: int64
# Dropping columns with nulls greater than 500000: []
# Shape after dropping columns: (26929, 276)
# Shape after dropping rows with nulls: (26430, 276)
# shape: (26_430, 276)
# ┌───────────┬──────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ timestamp ┆ px       ┆ sum_buy_s ┆ sum_sell_ ┆ … ┆ future_re ┆ rolling_s ┆ factor_me ┆ future_st │
# │ ---       ┆ ---      ┆ z         ┆ sz        ┆   ┆ turn_245  ┆ td        ┆ an        ┆ d_label   │
# │ i64       ┆ f64      ┆ ---       ┆ ---       ┆   ┆ ---       ┆ ---       ┆ ---       ┆ ---       │
# │           ┆          ┆ f64       ┆ f64       ┆   ┆ f64       ┆ f64       ┆ f64       ┆ i32       │
# ╞═══════════╪══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ 172020325 ┆ 56106.2  ┆ 1942.268  ┆ 2671.307  ┆ … ┆ -0.011304 ┆ 2685.2080 ┆ -0.034867 ┆ 1         │
# │ 6456000   ┆          ┆           ┆           ┆   ┆           ┆ 48        ┆           ┆           │
# │ 172020334 ┆ 55932.2  ┆ 447.316   ┆ 1625.189  ┆ … ┆ -0.011303 ┆ 2675.8398 ┆ -0.034581 ┆ 1         │
# │ 1028000   ┆          ┆           ┆           ┆   ┆           ┆ 83        ┆           ┆           │
# │ 172020361 ┆ 56105.6  ┆ 2201.998  ┆ 2087.499  ┆ … ┆ -0.017415 ┆ 2665.3474 ┆ -0.033865 ┆ 1         │
# │ 8445000   ┆          ┆           ┆           ┆   ┆           ┆ 59        ┆           ┆           │
# │ 172020390 ┆ 56279.6  ┆ 1316.117  ┆ 922.746   ┆ … ┆ -0.017417 ┆ 2653.7065 ┆ -0.033195 ┆ 1         │
# │ 8069000   ┆          ┆           ┆           ┆   ┆           ┆ 04        ┆           ┆           │
# │ 172020399 ┆ 56454.2  ┆ 773.804   ┆ 190.914   ┆ … ┆ -0.023493 ┆ 2640.8925 ┆ -0.03282  ┆ 1         │
# │ 5294000   ┆          ┆           ┆           ┆   ┆           ┆ 16        ┆           ┆           │
# │ …         ┆ …        ┆ …         ┆ …         ┆ … ┆ …         ┆ …         ┆ …         ┆ …         │
# │ 175278735 ┆ 120797.6 ┆ 2258.402  ┆ 1619.338  ┆ … ┆ -0.035923 ┆ 4915.0174 ┆ -0.031552 ┆ 0         │
# │ 3416000   ┆          ┆           ┆           ┆   ┆           ┆ 29        ┆           ┆           │
# │ 175278819 ┆ 120423.1 ┆ 3517.871  ┆ 3479.18   ┆ … ┆ -0.035923 ┆ 4910.1481 ┆ -0.032154 ┆ 0         │
# │ 3037000   ┆          ┆           ┆           ┆   ┆           ┆ 35        ┆           ┆           │
# │ 175278847 ┆ 120421.9 ┆ 275.196   ┆ 239.762   ┆ … ┆ -0.035925 ┆ 4902.1106 ┆ -0.034426 ┆ 0         │
# │ 3601000   ┆          ┆           ┆           ┆   ┆           ┆ 55        ┆           ┆           │
# │ 175280286 ┆ 120661.6 ┆ 2907.939  ┆ 2549.922  ┆ … ┆ -0.034887 ┆ 4867.7471 ┆ -0.040769 ┆ 0         │
# │ 4012000   ┆          ┆           ┆           ┆   ┆           ┆ 69        ┆           ┆           │
# │ 175281845 ┆ 120657.8 ┆ 3490.967  ┆ 3378.6    ┆ … ┆ -0.022465 ┆ 4829.9395 ┆ -0.049746 ┆ 0         │
# │ 2233000   ┆          ┆           ┆           ┆   ┆           ┆ 47        ┆           ┆           │
# └───────────┴──────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴───────────┘
# num weekly dfs:  55

# %%
feat = "z_oi_di_zscaled"
up_thres = 0.35
dn_thres = -0.35

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

all_predictions_df = a_df.to_pandas()
all_predictions_df['timestamp'] = pd.to_datetime(all_predictions_df['timestamp'], unit='us') # Assuming microseconds


symbol_to_backtest = "tst"
df = all_predictions_df.copy()
df = df.sort_values('timestamp').reset_index(drop=True)

# ===============================================
# Backtesting Parameters (Ratios for costs)
# ===============================================
initial_capital = 100000  # Initial capital
commission_ratio = 0.0005 # Commission ratio (e.0.05%)
slippage_ratio = 0.0007   # Slippage ratio (e.g., 0.02%)

trade_size_ratio = 0.9    # Percentage of current equity to allocate per trade

# Strategy Thresholds (needs optimization)
long_threshold = up_thres # Predicted probability above this to go long (buy)
short_threshold = dn_thres # Predicted probability below this to go short (sell)

beta = 5


# Dynamic Take Profit / Stop Loss (in multiples of rolling_std/px)
long_stop_loss_multiplier = beta
long_take_profit_multiplier = beta
short_stop_loss_multiplier = beta
short_take_profit_multiplier = beta

# ===============================================
# Backtesting Main Logic (No change here from previous version)
# ===============================================

# Initialize account state
capital = initial_capital
position = 0          # Position size (positive for long, negative for short, 0 for flat)
entry_price = 0       # Entry price for current position
realized_pnl = 0      # Realized PnL from closed trades
equity_curve = [initial_capital] # Equity curve
unrealized_pnl_series = [0]

# Record trades
trades = []

for i in range(len(df)):
    current_time = df['timestamp'].iloc[i]
    current_px = df['px'].iloc[i]
    predicted_prob = df[feat].iloc[i]
    current_rolling_std = df['rolling_std'].iloc[i]

    # Calculate current total equity (capital + market value of position)
    if position > 0: # Long position
        unrealized_pnl = (current_px - entry_price) * position
    elif position < 0: # Short position
        unrealized_pnl = (entry_price - current_px) * abs(position) # Profit when price falls
    else: # Flat
        unrealized_pnl = 0

    current_equity = capital + unrealized_pnl
    equity_curve.append(current_equity)
    unrealized_pnl_series.append(unrealized_pnl)

    # -----------------------------------------------
    # Strategy Execution - Long-Short
    # -----------------------------------------------

    # Scenario 1: Currently FLAT (position == 0)
    if position == 0:
        if predicted_prob >= long_threshold: # Go Long Signal
            trade_type = 'BUY_OPEN'
            trade_price = current_px * (1 + slippage_ratio)
            num_shares = (current_equity * trade_size_ratio) / (trade_price * (1 + commission_ratio))

            if num_shares > 0:
                position = num_shares
                entry_price = trade_price
                # capital -= (position * entry_price * (1 + commission_ratio))

                trades.append({
                    'timestamp': current_time, 'type': trade_type, 'price': entry_price, 'shares': position,
                    'capital_after_trade': capital, 'equity_after_trade': current_equity, 'predicted_prob': predicted_prob
                })
                print(f"{current_time}: {trade_type} {position:.2f} @ {entry_price:.2f} (Prob: {predicted_prob:.4f}) | Capital: {capital:.2f}")

        elif predicted_prob <= short_threshold: # Go Short Signal
            trade_type = 'SELL_SHORT_OPEN'
            trade_price = current_px * (1 - slippage_ratio) # Price for short is lower (sell at market)
            num_shares = (current_equity * trade_size_ratio) / (trade_price * (1 + commission_ratio))

            if num_shares > 0:
                position = -num_shares # Negative for short position
                entry_price = trade_price
                # capital -= (abs(position) * entry_price * (1 + commission_ratio))

                trades.append({
                    'timestamp': current_time, 'type': trade_type, 'price': entry_price, 'shares': position,
                    'capital_after_trade': capital, 'equity_after_trade': current_equity, 'predicted_prob': predicted_prob
                })
                print(f"{current_time}: {trade_type} {position:.2f} @ {entry_price:.2f} (Prob: {predicted_prob:.4f}) | Capital: {capital:.2f}")

    # Scenario 2: Currently LONG (position > 0)
    elif position > 0:
        sl_price = entry_price - long_stop_loss_multiplier * current_rolling_std
        tp_price = entry_price + long_take_profit_multiplier * current_rolling_std

        should_close = False
        reason = ""

        if predicted_prob < short_threshold: # Changed from sell_threshold to short_threshold for consistent logic
            should_close = True
            reason = "Prediction below short threshold (close long)"
        # if current_px <= sl_price:
        #     should_close = True
        #     reason = "Long Stop Loss Hit"
        # elif current_px >= tp_price and predicted_prob < long_threshold:
        #     should_close = True
        #     reason = "Long Take Profit Hit"

        if should_close:
            trade_type = 'SELL_CLOSE_LONG'
            close_price = current_px * (1 - slippage_ratio)
            gross_pnl_on_trade = (close_price - entry_price) * position
            net_pnl_on_trade = gross_pnl_on_trade - (close_price * position * commission_ratio)

            realized_pnl += net_pnl_on_trade
            capital += net_pnl_on_trade

            trades.append({
                'timestamp': current_time, 'type': trade_type, 'price': close_price, 'shares': position,
                'pnl': net_pnl_on_trade, 'capital_after_trade': capital, 'equity_after_trade': current_equity,
                'reason': reason, 'predicted_prob': predicted_prob
            })
            print(f"{current_time}: {trade_type} {position:.2f} @ {close_price:.2f} | PnL: {net_pnl_on_trade:.2f} | Capital: {capital:.2f} | Reason: {reason}")

            position = 0
            entry_price = 0


    # Scenario 3: Currently SHORT (position < 0)
    elif position < 0:
        sl_price = entry_price + long_stop_loss_multiplier * current_rolling_std
        tp_price = entry_price - long_take_profit_multiplier * current_rolling_std

        should_close = False
        reason = ""

        if predicted_prob >= long_threshold: # Changed from buy_threshold to long_threshold
            should_close = True
            reason = "Prediction above long threshold (close short)"
        # if current_px >= sl_price:
        #     should_close = True
        #     reason = "Short Stop Loss Hit"
        # elif current_px <= tp_price and predicted_prob > short_threshold:
        #     should_close = True
        #     reason = "Short Take Profit Hit"

        if should_close:
            trade_type = 'BUY_TO_COVER_SHORT'
            close_price = current_px * (1 + slippage_ratio)
            gross_pnl_on_trade = (entry_price - close_price) * abs(position)
            net_pnl_on_trade = gross_pnl_on_trade - (close_price * abs(position) * commission_ratio)

            realized_pnl += net_pnl_on_trade
            capital += net_pnl_on_trade

            trades.append({
                'timestamp': current_time, 'type': trade_type, 'price': close_price, 'shares': position,
                'pnl': net_pnl_on_trade, 'capital_after_trade': capital, 'equity_after_trade': current_equity,
                'reason': reason, 'predicted_prob': predicted_prob
            })
            print(f"{current_time}: {trade_type} {abs(position):.2f} @ {close_price:.2f} | PnL: {net_pnl_on_trade:.2f} | Capital: {capital:.2f} | Reason: {reason}")

            position = 0
            entry_price = 0

# Final close-out at the end of backtest if any position is open
final_equity_append_time = df['timestamp'].iloc[-1] + pd.Timedelta(seconds=1)
if position != 0:
    last_px = df['px'].iloc[-1]
    if position > 0: # Close long
        final_close_price = last_px * (1 - slippage_ratio)
        gross_pnl_on_trade = (final_close_price - entry_price) * position
        net_pnl_on_trade = gross_pnl_on_trade - (final_close_price * position * commission_ratio)
        # capital += (position * final_close_price * (1 - commission_ratio))
        trades.append({
            'timestamp': final_equity_append_time, 'type': 'SELL_FINAL_LONG', 'price': final_close_price, 'shares': position,
            'pnl': net_pnl_on_trade, 'capital_after_trade': capital, 'equity_after_trade': equity_curve[-1],
            'reason': 'End of Backtest', 'predicted_prob': df[feat].iloc[-1]
        })
        print(f"End of Backtest: SELL_FINAL_LONG {position:.2f} @ {final_close_price:.2f} | PnL: {net_pnl_on_trade:.2f} | Capital: {capital:.2f}")
    else: # Close short
        final_close_price = last_px * (1 + slippage_ratio)
        gross_pnl_on_trade = (entry_price - final_close_price) * abs(position)
        net_pnl_on_trade = gross_pnl_on_trade - (final_close_price * abs(position) * commission_ratio)
        # capital += (abs(position) * entry_price * (1 - commission_ratio))
        trades.append({
            'timestamp': final_equity_append_time, 'type': 'BUY_FINAL_SHORT', 'price': final_close_price, 'shares': position,
            'pnl': net_pnl_on_trade, 'capital_after_trade': capital, 'equity_after_trade': equity_curve[-1],
            'reason': 'End of Backtest', 'predicted_prob': df[feat].iloc[-1]
        })
        print(f"End of Backtest: BUY_FINAL_SHORT {abs(position):.2f} @ {final_close_price:.2f} | PnL: {net_pnl_on_trade:.2f} | Capital: {capital:.2f}")
    realized_pnl += net_pnl_on_trade
    position = 0

# Final equity curve update
equity_curve[-1] = capital
unrealized_pnl_series[-1] = 0
# ===============================================
# Performance Metrics Calculation (KEY CHANGES HERE)
# ===============================================
equity_series = pd.Series(equity_curve, index=df['timestamp'].tolist() + [final_equity_append_time])
returns = equity_series.pct_change().dropna()
unrealized_pnl_series = pd.Series(unrealized_pnl_series, index=equity_series.index)

# Total Return
total_return = (capital - initial_capital) / initial_capital

# Annualized Return - Based on Total Duration
annualized_return = total_return # Default value if not enough data

if len(df) > 1:
    # Get the total duration of the backtest data
    total_duration = df['timestamp'].iloc[-1] - df['timestamp'].iloc[0]
    total_duration_seconds = total_duration.total_seconds()

    if total_duration_seconds > 0:
        # Number of seconds in a year
        seconds_in_year = 365 * 24 * 60 * 60

        # Annualization factor: (seconds in a year) / (total seconds in backtest)
        annualization_factor = seconds_in_year / total_duration_seconds

        # Apply annualization
        annualized_return = (1 + total_return)**annualization_factor - 1
    else:
        print("Warning: Total backtest duration is zero or invalid, cannot annualize return.")
else:
    print("Warning: Not enough data points to calculate total duration for annualization.")


# Max Drawdown
peak = equity_series.expanding(min_periods=1).max()
drawdown = (equity_series - peak) / peak
max_drawdown = drawdown.min()

# Sharpe Ratio (assuming risk-free rate is 0)
# For volatility, we use returns.std() and annualize it with the same factor
annualized_volatility = returns.std() * np.sqrt(annualization_factor) if 'annualization_factor' in locals() and annualization_factor > 0 else returns.std()
sharpe_ratio = annualized_return / annualized_volatility if annualized_volatility != 0 else np.nan

# Win Rate for closed trades
if len(trades) > 0:
    winning_trades = sum(1 for t in trades if 'pnl' in t and t['pnl'] > 0)
    total_closed_trades = sum(1 for t in trades if 'pnl' in t)
    win_rate = winning_trades / total_closed_trades if total_closed_trades > 0 else 0
else:
    win_rate = 0


print("\n" + "="*60)
print("Backtesting Results Summary (Long-Short Strategy):")
print(f"Initial Capital: {initial_capital:.2f}")
print(f"Final Capital: {capital:.2f}")
print(f"Total Return: {total_return:.2%}")
print(f"Total Realized PnL: {realized_pnl:.2f}")
print(f"年化收益 (近似): {annualized_return:.2%}")
print(f"Maximum Drawdown: {max_drawdown:.2%}")
print(f"Sharpe Ratio (Risk-Free Rate = 0): {sharpe_ratio:.2f}")
print(f"Number of Trades: {len(trades)}")
print(f"Win Rate: {win_rate:.2%}")
print("="*60)
print("tred no ma")
# ===============================================
# Plotting
# ===============================================

# Equity Curve
plt.figure(figsize=(12, 6))
plt.plot(equity_series.index, equity_series, label='Equity Curve')
plt.title(f'{symbol_to_backtest} Long-Short Strategy Equity Curve')
plt.xlabel('Timestamp')
plt.ylabel('Equity')
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# Returns Distribution
if not returns.empty:
    plt.figure(figsize=(10, 5))
    sns.histplot(returns, kde=True, bins=50)
    plt.title(f'{symbol_to_backtest} Returns Distribution')
    plt.xlabel('Return')
    plt.ylabel('Frequency')
    plt.grid(True)
    plt.tight_layout()
    plt.show()

# Drawdown Plot
if not drawdown.empty:
    plt.figure(figsize=(12, 6))
    plt.plot(drawdown.index, drawdown, label='Drawdown')
    plt.fill_between(drawdown.index, drawdown, 0, where=(drawdown < 0), color='red', alpha=0.3)
    plt.title(f'{symbol_to_backtest} Drawdown')
    plt.xlabel('Timestamp')
    plt.ylabel('Drawdown (%)')
    plt.grid(True)
    plt.legend()
    plt.tight_layout()
    plt.show()


# plt.figure(figsize=(12, 6))
# plt.plot(unrealized_pnl_series.index, unrealized_pnl_series, label="Unrealized PnL")
# plt.axhline(0, color='gray', linestyle='--')
# plt.title(f"{symbol_to_backtest} 浮动盈亏 (Unrealized PnL)")
# plt.xlabel("Timestamp")
# plt.ylabel("Unrealized PnL")
# plt.grid(True)
# plt.legend()
# plt.tight_layout()
# plt.show()
# Out:
# 2024-07-01 01:11:08.042000: BUY_OPEN 1.42 @ 63460.39 (Prob: 0.4754) | Capital: 100000.00
# 2024-07-09 17:02:10.699000: SELL_CLOSE_LONG 1.42 @ 57692.29 | PnL: -8217.17 | Capital: 91782.83 | Reason: Prediction below short threshold (close long)
# 2024-07-09 17:15:01.567000: SELL_SHORT_OPEN -1.44 @ 57513.01 (Prob: -0.3650) | Capital: 91782.83
# 2024-07-27 19:41:19.739000: BUY_TO_COVER_SHORT 1.44 @ 67918.51 | PnL: -14986.45 | Capital: 76796.39 | Reason: Prediction above long threshold (close short)
# 2024-07-27 19:47:30.600000: BUY_OPEN 1.01 @ 68129.26 (Prob: 0.3543) | Capital: 76796.39
# 2024-08-05 22:07:10.062000: SELL_CLOSE_LONG 1.01 @ 54664.41 | PnL: -13680.90 | Capital: 63115.48 | Reason: Prediction below short threshold (close long)
# 2024-08-05 22:11:13.818000: SELL_SHORT_OPEN -1.04 @ 54494.43 (Prob: -0.3518) | Capital: 63115.48
# 2024-08-07 14:45:34.513000: BUY_TO_COVER_SHORT 1.04 @ 56009.18 | PnL: -1607.34 | Capital: 61508.15 | Reason: Prediction above long threshold (close short)
# 2024-08-07 14:47:51.095000: BUY_OPEN 0.98 @ 56182.90 (Prob: 0.3621) | Capital: 61508.15
# 2024-08-11 12:16:46.719000: SELL_CLOSE_LONG 0.98 @ 60336.53 | PnL: 4060.84 | Capital: 65568.99 | Reason: Prediction below short threshold (close long)
# 2024-08-11 13:11:20.951000: SELL_SHORT_OPEN -0.98 @ 60149.47 (Prob: -0.3627) | Capital: 65568.99
# 2024-08-14 12:30:24.664000: BUY_TO_COVER_SHORT 0.98 @ 61724.18 | PnL: -1574.43 | Capital: 63994.57 | Reason: Prediction above long threshold (close short)
# 2024-08-14 12:30:37.066000: BUY_OPEN 0.94 @ 61532.74 (Prob: 0.3565) | Capital: 63994.57
# 2024-08-27 00:51:30.311000: SELL_CLOSE_LONG 0.94 @ 62763.14 | PnL: 1121.72 | Capital: 65116.29 | Reason: Prediction below short threshold (close long)
# 2024-08-27 01:03:51.509000: SELL_SHORT_OPEN -0.93 @ 62957.90 (Prob: -0.3605) | Capital: 65116.29
# 2024-09-02 10:23:12.723000: BUY_TO_COVER_SHORT 0.93 @ 58559.26 | PnL: 4065.20 | Capital: 69181.49 | Reason: Prediction above long threshold (close short)
# 2024-09-02 10:51:04.030000: BUY_OPEN 1.07 @ 58377.34 (Prob: 0.3611) | Capital: 69181.49
# 2024-09-06 17:14:44.013000: SELL_CLOSE_LONG 1.07 @ 54201.03 | PnL: -4480.97 | Capital: 64700.52 | Reason: Prediction below short threshold (close long)
# 2024-09-06 17:26:00.030000: SELL_SHORT_OPEN -1.07 @ 54369.21 (Prob: -0.3623) | Capital: 64700.52
# 2024-09-09 21:15:26.446000: BUY_TO_COVER_SHORT 1.07 @ 58002.97 | PnL: -3920.93 | Capital: 60779.60 | Reason: Prediction above long threshold (close short)
# 2024-09-09 21:15:28.597000: BUY_OPEN 0.94 @ 58182.80 (Prob: 0.3677) | Capital: 60779.60
# 2024-09-16 13:33:05.032000: SELL_CLOSE_LONG 0.94 @ 58324.64 | PnL: 105.89 | Capital: 60885.48 | Reason: Prediction below short threshold (close long)
# 2024-09-16 13:35:11.009000: SELL_SHORT_OPEN -0.94 @ 58143.67 (Prob: -0.3607) | Capital: 60885.48
# 2024-10-04 01:27:55.668000: BUY_TO_COVER_SHORT 0.94 @ 61145.87 | PnL: -2856.78 | Capital: 58028.70 | Reason: Prediction above long threshold (close short)
# 2024-10-04 01:40:32.108000: BUY_OPEN 0.86 @ 60956.04 (Prob: 0.3590) | Capital: 58028.70
# 2024-10-23 04:39:26.928000: SELL_CLOSE_LONG 0.86 @ 67149.66 | PnL: 5275.16 | Capital: 63303.86 | Reason: Prediction below short threshold (close long)
# 2024-10-23 06:52:49.032000: SELL_SHORT_OPEN -0.85 @ 66941.21 (Prob: -0.3604) | Capital: 63303.86
# 2024-10-30 13:50:48.427000: BUY_TO_COVER_SHORT 0.85 @ 71886.49 | PnL: -4237.38 | Capital: 59066.48 | Reason: Prediction above long threshold (close short)
# 2024-10-30 13:53:35.012000: BUY_OPEN 0.74 @ 72109.34 (Prob: 0.3550) | Capital: 59066.48
# 2024-11-05 18:12:16.072000: SELL_CLOSE_LONG 0.74 @ 69690.28 | PnL: -1808.14 | Capital: 57258.34 | Reason: Prediction below short threshold (close long)
# 2024-11-05 18:28:15.954000: SELL_SHORT_OPEN -0.74 @ 69906.43 (Prob: -0.3591) | Capital: 57258.34
# 2024-11-11 23:06:51.598000: BUY_TO_COVER_SHORT 0.74 @ 88789.11 | PnL: -13945.38 | Capital: 43312.95 | Reason: Prediction above long threshold (close short)
# 2024-11-11 23:10:29.683000: BUY_OPEN 0.44 @ 89064.80 (Prob: 0.3604) | Capital: 43312.95
# 2024-11-12 14:30:40.607000: SELL_CLOSE_LONG 0.44 @ 85894.33 | PnL: -1405.74 | Capital: 41907.22 | Reason: Prediction below short threshold (close long)
# 2024-11-12 14:31:09.089000: SELL_SHORT_OPEN -0.44 @ 85628.02 (Prob: -0.3626) | Capital: 41907.22
# 2024-11-13 23:29:07.654000: BUY_TO_COVER_SHORT 0.44 @ 90397.03 | PnL: -2119.45 | Capital: 39787.76 | Reason: Prediction above long threshold (close short)
# 2024-11-13 23:58:19.448000: BUY_OPEN 0.39 @ 90677.43 (Prob: 0.3578) | Capital: 39787.76
# 2024-11-24 11:34:27.722000: SELL_CLOSE_LONG 0.39 @ 97348.81 | PnL: 2614.03 | Capital: 42401.80 | Reason: Prediction below short threshold (close long)
# 2024-11-24 12:29:08.055000: SELL_SHORT_OPEN -0.39 @ 97047.02 (Prob: -0.3555) | Capital: 42401.80
# 2024-11-29 14:52:07.070000: BUY_TO_COVER_SHORT 0.39 @ 97852.45 | PnL: -335.79 | Capital: 42066.01 | Reason: Prediction above long threshold (close short)
# 2024-11-29 14:59:30.840000: BUY_OPEN 0.39 @ 98155.86 (Prob: 0.3610) | Capital: 42066.01
# 2024-12-05 20:32:09.326000: SELL_CLOSE_LONG 0.39 @ 98165.84 | PnL: -15.08 | Capital: 42050.93 | Reason: Prediction below short threshold (close long)
# 2024-12-05 20:33:54.330000: SELL_SHORT_OPEN -0.38 @ 98470.22 (Prob: -0.3529) | Capital: 42050.93
# 2024-12-20 12:32:30.027000: BUY_TO_COVER_SHORT 0.38 @ 93892.48 | PnL: 1740.49 | Capital: 43791.42 | Reason: Prediction above long threshold (close short)
# 2024-12-20 12:34:06.920000: BUY_OPEN 0.42 @ 93601.28 (Prob: 0.3633) | Capital: 43791.42
# 2024-12-28 11:56:41.023000: SELL_CLOSE_LONG 0.42 @ 94776.61 | PnL: 474.70 | Capital: 44266.12 | Reason: Prediction below short threshold (close long)
# 2024-12-28 13:00:00.462000: SELL_SHORT_OPEN -0.42 @ 94482.72 (Prob: -0.3587) | Capital: 44266.12
# 2025-01-05 20:48:50.478000: BUY_TO_COVER_SHORT 0.42 @ 98233.62 | PnL: -1601.51 | Capital: 42664.61 | Reason: Prediction above long threshold (close short)
# 2025-01-05 21:54:24.020000: BUY_OPEN 0.39 @ 98538.33 (Prob: 0.3577) | Capital: 42664.61
# 2025-01-08 22:41:04.022000: SELL_CLOSE_LONG 0.39 @ 95027.33 | PnL: -1385.98 | Capital: 41278.63 | Reason: Prediction below short threshold (close long)
# 2025-01-09 01:24:13.999000: SELL_SHORT_OPEN -0.39 @ 95241.88 (Prob: -0.3552) | Capital: 41278.63
# 2025-01-14 14:43:20.421000: BUY_TO_COVER_SHORT 0.39 @ 96910.49 | PnL: -669.44 | Capital: 40609.20 | Reason: Prediction above long threshold (close short)
# 2025-01-14 14:47:06.516000: BUY_OPEN 0.38 @ 96609.98 (Prob: 0.3531) | Capital: 40609.20
# 2025-01-19 22:39:34.806000: SELL_CLOSE_LONG 0.38 @ 103116.87 | PnL: 2440.88 | Capital: 43050.08 | Reason: Prediction below short threshold (close long)
# 2025-01-19 22:47:05.341000: SELL_SHORT_OPEN -0.38 @ 102797.19 (Prob: -0.3571) | Capital: 43050.08
# 2025-01-21 23:04:22.344000: BUY_TO_COVER_SHORT 0.38 @ 105790.10 | PnL: -1147.41 | Capital: 41902.66 | Reason: Prediction above long threshold (close short)
# 2025-01-21 23:20:07.892000: BUY_OPEN 0.36 @ 106118.23 (Prob: 0.3528) | Capital: 41902.66
# 2025-01-24 14:18:39.036000: SELL_CLOSE_LONG 0.36 @ 105073.40 | PnL: -389.79 | Capital: 41512.87 | Reason: Prediction below short threshold (close long)
# 2025-01-24 14:32:13.889000: SELL_SHORT_OPEN -0.36 @ 104747.53 (Prob: -0.3611) | Capital: 41512.87
# 2025-01-29 02:15:34.923000: BUY_TO_COVER_SHORT 0.36 @ 101978.33 | PnL: 969.05 | Capital: 42481.92 | Reason: Prediction above long threshold (close short)
# 2025-01-29 05:08:33.887000: BUY_OPEN 0.37 @ 102294.86 (Prob: 0.3658) | Capital: 42481.92
# 2025-02-03 00:46:52.878000: SELL_CLOSE_LONG 0.37 @ 96381.49 | PnL: -2227.08 | Capital: 40254.84 | Reason: Prediction below short threshold (close long)
# 2025-02-03 00:47:32.942000: SELL_SHORT_OPEN -0.38 @ 96082.69 (Prob: -0.3625) | Capital: 40254.84
# 2025-02-03 17:54:19.024000: BUY_TO_COVER_SHORT 0.38 @ 99122.14 | PnL: -1164.17 | Capital: 39090.67 | Reason: Prediction above long threshold (close short)
# 2025-02-03 17:55:28.990000: BUY_OPEN 0.36 @ 98814.82 (Prob: 0.3655) | Capital: 39090.67
# 2025-02-06 18:34:26.787000: SELL_CLOSE_LONG 0.36 @ 96164.34 | PnL: -960.31 | Capital: 38130.37 | Reason: Prediction below short threshold (close long)
# 2025-02-06 18:49:32.860000: SELL_SHORT_OPEN -0.36 @ 96463.03 (Prob: -0.3616) | Capital: 38130.37
# 2025-02-14 14:39:16.539000: BUY_TO_COVER_SHORT 0.36 @ 97223.31 | PnL: -287.62 | Capital: 37842.74 | Reason: Prediction above long threshold (close short)
# 2025-02-14 14:53:10.720000: BUY_OPEN 0.35 @ 97524.82 (Prob: 0.3553) | Capital: 37842.74
# 2025-02-25 07:35:04.352000: SELL_CLOSE_LONG 0.35 @ 88633.81 | PnL: -3118.91 | Capital: 34723.83 | Reason: Prediction below short threshold (close long)
# 2025-02-25 07:35:14.007000: SELL_SHORT_OPEN -0.35 @ 88358.91 (Prob: -0.3639) | Capital: 34723.83
# 2025-02-26 15:28:27.545000: BUY_TO_COVER_SHORT 0.35 @ 87858.06 | PnL: 161.53 | Capital: 34885.36 | Reason: Prediction above long threshold (close short)
# 2025-02-26 15:38:05.047000: BUY_OPEN 0.36 @ 88130.75 (Prob: 0.3656) | Capital: 34885.36
# 2025-03-03 14:56:34.208000: SELL_CLOSE_LONG 0.36 @ 89553.77 | PnL: 490.76 | Capital: 35376.11 | Reason: Prediction below short threshold (close long)
# 2025-03-03 14:57:25.608000: SELL_SHORT_OPEN -0.36 @ 89276.06 (Prob: -0.3649) | Capital: 35376.11
# 2025-03-04 16:14:21.032000: BUY_TO_COVER_SHORT 0.36 @ 83014.57 | PnL: 2217.12 | Capital: 37593.24 | Reason: Prediction above long threshold (close short)
# 2025-03-04 16:17:05.877000: BUY_OPEN 0.41 @ 82757.19 (Prob: 0.3630) | Capital: 37593.24
# 2025-03-07 00:25:25.935000: SELL_CLOSE_LONG 0.41 @ 87064.01 | PnL: 1742.11 | Capital: 39335.34 | Reason: Prediction below short threshold (close long)
# 2025-03-07 00:25:41.346000: SELL_SHORT_OPEN -0.41 @ 86794.10 (Prob: -0.3597) | Capital: 39335.34
# 2025-03-10 00:21:15.587000: BUY_TO_COVER_SHORT 0.41 @ 80495.31 | PnL: 2551.48 | Capital: 41886.82 | Reason: Prediction above long threshold (close short)
# 2025-03-10 00:24:08.775000: BUY_OPEN 0.47 @ 80745.28 (Prob: 0.3600) | Capital: 41886.82
# 2025-03-14 14:08:12.322000: SELL_CLOSE_LONG 0.47 @ 83050.62 | PnL: 1056.40 | Capital: 42943.21 | Reason: Prediction below short threshold (close long)
# 2025-03-14 14:10:14.700000: SELL_SHORT_OPEN -0.46 @ 83308.14 (Prob: -0.3588) | Capital: 42943.21
# 2025-03-23 17:19:27.131000: BUY_TO_COVER_SHORT 0.46 @ 85434.66 | PnL: -1005.86 | Capital: 41937.35 | Reason: Prediction above long threshold (close short)
# 2025-03-23 17:32:31.067000: BUY_OPEN 0.44 @ 85169.58 (Prob: 0.3621) | Capital: 41937.35
# 2025-03-31 03:30:45.550000: SELL_CLOSE_LONG 0.44 @ 81782.11 | PnL: -1518.55 | Capital: 40418.80 | Reason: Prediction below short threshold (close long)
# 2025-03-31 03:48:20.372000: SELL_SHORT_OPEN -0.45 @ 81528.49 (Prob: -0.3591) | Capital: 40418.80
# 2025-04-02 20:28:09.999000: BUY_TO_COVER_SHORT 0.45 @ 85370.72 | PnL: -1732.53 | Capital: 38686.27 | Reason: Prediction above long threshold (close short)
# 2025-04-02 20:28:11.587000: BUY_OPEN 0.41 @ 85636.90 (Prob: 0.3610) | Capital: 38686.27
# 2025-04-07 05:05:31.040000: SELL_CLOSE_LONG 0.41 @ 76630.72 | PnL: -3675.41 | Capital: 35010.86 | Reason: Prediction below short threshold (close long)
# 2025-04-07 05:09:10.124000: SELL_SHORT_OPEN -0.41 @ 76868.45 (Prob: -0.3556) | Capital: 35010.86
# 2025-04-07 14:32:48.743000: BUY_TO_COVER_SHORT 0.41 @ 78844.15 | PnL: -825.62 | Capital: 34185.24 | Reason: Prediction above long threshold (close short)
# 2025-04-07 14:33:33.700000: BUY_OPEN 0.39 @ 79088.62 (Prob: 0.3528) | Capital: 34185.24
# 2025-04-09 05:28:40.627000: SELL_CLOSE_LONG 0.39 @ 76699.27 | PnL: -943.94 | Capital: 33241.30 | Reason: Prediction below short threshold (close long)
# 2025-04-09 05:31:56.146000: SELL_SHORT_OPEN -0.39 @ 76461.44 (Prob: -0.3585) | Capital: 33241.30
# 2025-04-23 00:02:51.002000: BUY_TO_COVER_SHORT 0.39 @ 93760.29 | PnL: -6783.49 | Capital: 26457.81 | Reason: Prediction above long threshold (close short)
# 2025-04-23 00:11:03.558000: BUY_OPEN 0.25 @ 93469.28 (Prob: 0.3598) | Capital: 26457.81
# 2025-05-01 13:20:41.115000: SELL_CLOSE_LONG 0.25 @ 96416.36 | PnL: 738.14 | Capital: 27195.95 | Reason: Prediction below short threshold (close long)
# 2025-05-01 13:35:43.870000: SELL_SHORT_OPEN -0.25 @ 96117.37 (Prob: -0.3600) | Capital: 27195.95
# 2025-06-12 14:07:17.206000: BUY_TO_COVER_SHORT 0.25 @ 107329.48 | PnL: -2867.40 | Capital: 24328.54 | Reason: Prediction above long threshold (close short)
# 2025-06-12 14:37:19.584000: BUY_OPEN 0.20 @ 107662.21 (Prob: 0.3628) | Capital: 24328.54
# 2025-06-22 16:25:01.034000: SELL_CLOSE_LONG 0.20 @ 98562.96 | PnL: -1859.64 | Capital: 22468.90 | Reason: Prediction below short threshold (close long)
# 2025-06-22 16:36:27.288000: SELL_SHORT_OPEN -0.20 @ 98868.74 (Prob: -0.3600) | Capital: 22468.90
# 2025-08-01 22:06:33.135000: BUY_TO_COVER_SHORT 0.20 @ 113611.27 | PnL: -3025.45 | Capital: 19443.45 | Reason: Prediction above long threshold (close short)
# 2025-08-01 22:27:50.519000: BUY_OPEN 0.15 @ 113258.93 (Prob: 0.3604) | Capital: 19443.45
# 2025-08-19 10:08:17.693000: SELL_CLOSE_LONG 0.15 @ 115375.48 | PnL: 317.95 | Capital: 19761.39 | Reason: Prediction below short threshold (close long)
# 2025-08-19 13:30:52.100000: SELL_SHORT_OPEN -0.15 @ 115733.33 (Prob: -0.3575) | Capital: 19761.39
# End of Backtest: BUY_FINAL_SHORT 0.15 @ 112609.17 | PnL: 471.22 | Capital: 19761.39
#
# ============================================================
# Backtesting Results Summary (Long-Short Strategy):
# Initial Capital: 100000.00
# Final Capital: 19761.39
# Total Return: -80.24%
# Total Realized PnL: -79767.39
# 年化收益 (近似): -75.58%
# Maximum Drawdown: -82.58%
# Sharpe Ratio (Risk-Free Rate = 0): -275.05
# Number of Trades: 108
# Win Rate: 35.19%
# ============================================================
# tred no ma

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

all_predictions_df = a_df.to_pandas()
all_predictions_df['timestamp'] = pd.to_datetime(all_predictions_df['timestamp'], unit='us') # Assuming microseconds


symbol_to_backtest = "tst"
df = all_predictions_df.copy()
df = df.sort_values('timestamp').reset_index(drop=True)

# ===============================================
# Backtesting Parameters (Ratios for costs)
# ===============================================
initial_capital = 100000  # Initial capital
commission_ratio = 0.0005 # Commission ratio (e.0.05%)
slippage_ratio = 0.0007   # Slippage ratio (e.g., 0.02%)

trade_size_ratio = 0.9    # Percentage of current equity to allocate per trade

# Strategy Thresholds (needs optimization)
long_threshold = up_thres # Predicted probability above this to go long (buy)
short_threshold = dn_thres # Predicted probability below this to go short (sell)

beta = 5


# Dynamic Take Profit / Stop Loss (in multiples of rolling_std/px)
long_stop_loss_multiplier = beta
long_take_profit_multiplier = beta
short_stop_loss_multiplier = beta
short_take_profit_multiplier = beta

# ===============================================
# Backtesting Main Logic (No change here from previous version)
# ===============================================

# Initialize account state
capital = initial_capital
position = 0          # Position size (positive for long, negative for short, 0 for flat)
entry_price = 0       # Entry price for current position
realized_pnl = 0      # Realized PnL from closed trades
equity_curve = [initial_capital] # Equity curve
unrealized_pnl_series = [0]

# Record trades
trades = []

for i in range(len(df)):
    current_time = df['timestamp'].iloc[i]
    current_px = df['px'].iloc[i]
    predicted_prob = df[feat].iloc[i]
    current_rolling_std = df['rolling_std'].iloc[i]

    # Calculate current total equity (capital + market value of position)
    if position > 0: # Long position
        unrealized_pnl = (current_px - entry_price) * position
    elif position < 0: # Short position
        unrealized_pnl = (entry_price - current_px) * abs(position) # Profit when price falls
    else: # Flat
        unrealized_pnl = 0

    current_equity = capital + unrealized_pnl
    equity_curve.append(current_equity)
    unrealized_pnl_series.append(unrealized_pnl)

    # -----------------------------------------------
    # Strategy Execution - Long-Short
    # -----------------------------------------------

    # Scenario 1: Currently FLAT (position == 0)
    if position == 0:
        if predicted_prob <= short_threshold: # Go Long Signal
            trade_type = 'BUY_OPEN'
            trade_price = current_px * (1 + slippage_ratio)
            num_shares = (current_equity * trade_size_ratio) / (trade_price * (1 + commission_ratio))

            if num_shares > 0:
                position = num_shares
                entry_price = trade_price
                # capital -= (position * entry_price * (1 + commission_ratio))

                trades.append({
                    'timestamp': current_time, 'type': trade_type, 'price': entry_price, 'shares': position,
                    'capital_after_trade': capital, 'equity_after_trade': current_equity, 'predicted_prob': predicted_prob
                })
                print(f"{current_time}: {trade_type} {position:.2f} @ {entry_price:.2f} (Prob: {predicted_prob:.4f}) | Capital: {capital:.2f}")

        elif predicted_prob >= long_threshold: # Go Short Signal
            trade_type = 'SELL_SHORT_OPEN'
            trade_price = current_px * (1 - slippage_ratio) # Price for short is lower (sell at market)
            num_shares = (current_equity * trade_size_ratio) / (trade_price * (1 + commission_ratio))

            if num_shares > 0:
                position = -num_shares # Negative for short position
                entry_price = trade_price
                # capital -= (abs(position) * entry_price * (1 + commission_ratio))

                trades.append({
                    'timestamp': current_time, 'type': trade_type, 'price': entry_price, 'shares': position,
                    'capital_after_trade': capital, 'equity_after_trade': current_equity, 'predicted_prob': predicted_prob
                })
                print(f"{current_time}: {trade_type} {position:.2f} @ {entry_price:.2f} (Prob: {predicted_prob:.4f}) | Capital: {capital:.2f}")

    # Scenario 2: Currently LONG (position > 0)
    elif position > 0:
        sl_price = entry_price - long_stop_loss_multiplier * current_rolling_std
        tp_price = entry_price + long_take_profit_multiplier * current_rolling_std

        should_close = False
        reason = ""

        if predicted_prob >= long_threshold: # Changed from sell_threshold to short_threshold for consistent logic
            should_close = True
            reason = "Prediction below short threshold (close long)"
        # if current_px <= sl_price:
        #     should_close = True
        #     reason = "Long Stop Loss Hit"
        # elif current_px >= tp_price and predicted_prob > short_threshold:
        #     should_close = True
        #     reason = "Long Take Profit Hit"

        if should_close:
            trade_type = 'SELL_CLOSE_LONG'
            close_price = current_px * (1 - slippage_ratio)
            gross_pnl_on_trade = (close_price - entry_price) * position
            net_pnl_on_trade = gross_pnl_on_trade - (close_price * position * commission_ratio)

            realized_pnl += net_pnl_on_trade
            capital += net_pnl_on_trade

            trades.append({
                'timestamp': current_time, 'type': trade_type, 'price': close_price, 'shares': position,
                'pnl': net_pnl_on_trade, 'capital_after_trade': capital, 'equity_after_trade': current_equity,
                'reason': reason, 'predicted_prob': predicted_prob
            })
            print(f"{current_time}: {trade_type} {position:.2f} @ {close_price:.2f} | PnL: {net_pnl_on_trade:.2f} | Capital: {capital:.2f} | Reason: {reason}")

            position = 0
            entry_price = 0


    # Scenario 3: Currently SHORT (position < 0)
    elif position < 0:
        sl_price = entry_price + long_stop_loss_multiplier * current_rolling_std
        tp_price = entry_price - long_take_profit_multiplier * current_rolling_std

        should_close = False
        reason = ""

        if predicted_prob <= short_threshold: # Changed from buy_threshold to long_threshold
            should_close = True
            reason = "Prediction above long threshold (close short)"
        # if current_px >= sl_price:
        #     should_close = True
        #     reason = "Short Stop Loss Hit"
        # elif current_px <= tp_price and predicted_prob < long_threshold:
        #     should_close = True
        #     reason = "Short Take Profit Hit"

        if should_close:
            trade_type = 'BUY_TO_COVER_SHORT'
            close_price = current_px * (1 + slippage_ratio)
            gross_pnl_on_trade = (entry_price - close_price) * abs(position)
            net_pnl_on_trade = gross_pnl_on_trade - (close_price * abs(position) * commission_ratio)

            realized_pnl += net_pnl_on_trade
            capital += net_pnl_on_trade

            trades.append({
                'timestamp': current_time, 'type': trade_type, 'price': close_price, 'shares': position,
                'pnl': net_pnl_on_trade, 'capital_after_trade': capital, 'equity_after_trade': current_equity,
                'reason': reason, 'predicted_prob': predicted_prob
            })
            print(f"{current_time}: {trade_type} {abs(position):.2f} @ {close_price:.2f} | PnL: {net_pnl_on_trade:.2f} | Capital: {capital:.2f} | Reason: {reason}")

            position = 0
            entry_price = 0

# Final close-out at the end of backtest if any position is open
final_equity_append_time = df['timestamp'].iloc[-1] + pd.Timedelta(seconds=1)
if position != 0:
    last_px = df['px'].iloc[-1]
    if position > 0: # Close long
        final_close_price = last_px * (1 - slippage_ratio)
        gross_pnl_on_trade = (final_close_price - entry_price) * position
        net_pnl_on_trade = gross_pnl_on_trade - (final_close_price * position * commission_ratio)
        # capital += (position * final_close_price * (1 - commission_ratio))
        trades.append({
            'timestamp': final_equity_append_time, 'type': 'SELL_FINAL_LONG', 'price': final_close_price, 'shares': position,
            'pnl': net_pnl_on_trade, 'capital_after_trade': capital, 'equity_after_trade': equity_curve[-1],
            'reason': 'End of Backtest', 'predicted_prob': df[feat].iloc[-1]
        })
        print(f"End of Backtest: SELL_FINAL_LONG {position:.2f} @ {final_close_price:.2f} | PnL: {net_pnl_on_trade:.2f} | Capital: {capital:.2f}")
    else: # Close short
        final_close_price = last_px * (1 + slippage_ratio)
        gross_pnl_on_trade = (entry_price - final_close_price) * abs(position)
        net_pnl_on_trade = gross_pnl_on_trade - (final_close_price * abs(position) * commission_ratio)
        # capital += (abs(position) * entry_price * (1 - commission_ratio))
        trades.append({
            'timestamp': final_equity_append_time, 'type': 'BUY_FINAL_SHORT', 'price': final_close_price, 'shares': position,
            'pnl': net_pnl_on_trade, 'capital_after_trade': capital, 'equity_after_trade': equity_curve[-1],
            'reason': 'End of Backtest', 'predicted_prob': df[feat].iloc[-1]
        })
        print(f"End of Backtest: BUY_FINAL_SHORT {abs(position):.2f} @ {final_close_price:.2f} | PnL: {net_pnl_on_trade:.2f} | Capital: {capital:.2f}")
    realized_pnl += net_pnl_on_trade
    position = 0

# Final equity curve update
equity_curve[-1] = capital
unrealized_pnl_series[-1] = 0
# ===============================================
# Performance Metrics Calculation (KEY CHANGES HERE)
# ===============================================
equity_series = pd.Series(equity_curve, index=df['timestamp'].tolist() + [final_equity_append_time])
returns = equity_series.pct_change().dropna()
unrealized_pnl_series = pd.Series(unrealized_pnl_series, index=equity_series.index)

# Total Return
total_return = (capital - initial_capital) / initial_capital

# Annualized Return - Based on Total Duration
annualized_return = total_return # Default value if not enough data

if len(df) > 1:
    # Get the total duration of the backtest data
    total_duration = df['timestamp'].iloc[-1] - df['timestamp'].iloc[0]
    total_duration_seconds = total_duration.total_seconds()

    if total_duration_seconds > 0:
        # Number of seconds in a year
        seconds_in_year = 365 * 24 * 60 * 60

        # Annualization factor: (seconds in a year) / (total seconds in backtest)
        annualization_factor = seconds_in_year / total_duration_seconds

        # Apply annualization
        annualized_return = (1 + total_return)**annualization_factor - 1
    else:
        print("Warning: Total backtest duration is zero or invalid, cannot annualize return.")
else:
    print("Warning: Not enough data points to calculate total duration for annualization.")


# Max Drawdown
peak = equity_series.expanding(min_periods=1).max()
drawdown = (equity_series - peak) / peak
max_drawdown = drawdown.min()

# Sharpe Ratio (assuming risk-free rate is 0)
# For volatility, we use returns.std() and annualize it with the same factor
annualized_volatility = returns.std() * np.sqrt(annualization_factor) if 'annualization_factor' in locals() and annualization_factor > 0 else returns.std()
sharpe_ratio = annualized_return / annualized_volatility if annualized_volatility != 0 else np.nan

# Win Rate for closed trades
if len(trades) > 0:
    winning_trades = sum(1 for t in trades if 'pnl' in t and t['pnl'] > 0)
    total_closed_trades = sum(1 for t in trades if 'pnl' in t)
    win_rate = winning_trades / total_closed_trades if total_closed_trades > 0 else 0
else:
    win_rate = 0


print("\n" + "="*60)
print("Backtesting Results Summary (Long-Short Strategy):")
print(f"Initial Capital: {initial_capital:.2f}")
print(f"Final Capital: {capital:.2f}")
print(f"Total Return: {total_return:.2%}")
print(f"Total Realized PnL: {realized_pnl:.2f}")
print(f"年化收益 (近似): {annualized_return:.2%}")
print(f"Maximum Drawdown: {max_drawdown:.2%}")
print(f"Sharpe Ratio (Risk-Free Rate = 0): {sharpe_ratio:.2f}")
print(f"Number of Trades: {len(trades)}")
print(f"Win Rate: {win_rate:.2%}")
print("="*60)
print("reverse no ma")

# ===============================================
# Plotting
# ===============================================

# Equity Curve
plt.figure(figsize=(12, 6))
plt.plot(equity_series.index, equity_series, label='Equity Curve')
plt.title(f'{symbol_to_backtest} Long-Short Strategy Equity Curve')
plt.xlabel('Timestamp')
plt.ylabel('Equity')
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# Returns Distribution
if not returns.empty:
    plt.figure(figsize=(10, 5))
    sns.histplot(returns, kde=True, bins=50)
    plt.title(f'{symbol_to_backtest} Returns Distribution')
    plt.xlabel('Return')
    plt.ylabel('Frequency')
    plt.grid(True)
    plt.tight_layout()
    plt.show()

# Drawdown Plot
if not drawdown.empty:
    plt.figure(figsize=(12, 6))
    plt.plot(drawdown.index, drawdown, label='Drawdown')
    plt.fill_between(drawdown.index, drawdown, 0, where=(drawdown < 0), color='red', alpha=0.3)
    plt.title(f'{symbol_to_backtest} Drawdown')
    plt.xlabel('Timestamp')
    plt.ylabel('Drawdown (%)')
    plt.grid(True)
    plt.legend()
    plt.tight_layout()
    plt.show()


# plt.figure(figsize=(12, 6))
# plt.plot(unrealized_pnl_series.index, unrealized_pnl_series, label="Unrealized PnL")
# plt.axhline(0, color='gray', linestyle='--')
# plt.title(f"{symbol_to_backtest} 浮动盈亏 (Unrealized PnL)")
# plt.xlabel("Timestamp")
# plt.ylabel("Unrealized PnL")
# plt.grid(True)
# plt.legend()
# plt.tight_layout()
# plt.show()
# Out:
# 2024-07-01 01:11:08.042000: SELL_SHORT_OPEN -1.42 @ 63371.61 (Prob: 0.4754) | Capital: 100000.00
# 2024-07-09 17:02:10.699000: BUY_TO_COVER_SHORT 1.42 @ 57773.11 | PnL: 7905.97 | Capital: 107905.97 | Reason: Prediction above long threshold (close short)
# 2024-07-09 17:15:01.567000: BUY_OPEN 1.69 @ 57593.59 (Prob: -0.3650) | Capital: 107905.97
# 2024-07-27 19:41:19.739000: SELL_CLOSE_LONG 1.69 @ 67823.49 | PnL: 17184.08 | Capital: 125090.05 | Reason: Prediction below short threshold (close long)
# 2024-07-27 19:47:30.600000: SELL_SHORT_OPEN -1.65 @ 68033.94 (Prob: 0.3543) | Capital: 125090.05
# 2024-12-28 13:00:00.462000: BUY_OPEN 1.67 @ 94615.08 (Prob: -0.3587) | Capital: 176104.37
# 2025-01-05 20:48:50.478000: SELL_CLOSE_LONG 1.67 @ 98096.18 | PnL: 5746.31 | Capital: 181850.68 | Reason: Prediction below short threshold (close long)
# 2025-01-05 21:54:24.020000: SELL_SHORT_OPEN -1.66 @ 98400.47 (Prob: 0.3577) | Capital: 181850.68
# 2025-01-08 22:41:04.022000: BUY_TO_COVER_SHORT 1.66 @ 95160.47 | PnL: 5307.18 | Capital: 187157.86 | Reason: Prediction above long threshold (close short)
# 2025-01-09 01:24:13.999000: BUY_OPEN 1.77 @ 95375.32 (Prob: -0.3552) | Capital: 187157.86
# 2025-01-14 14:43:20.421000: SELL_CLOSE_LONG 1.77 @ 96774.91 | PnL: 2385.17 | Capital: 189543.03 | Reason: Prediction below short threshold (close long)
# 2025-01-14 14:47:06.516000: SELL_SHORT_OPEN -1.77 @ 96474.82 (Prob: 0.3531) | Capital: 189543.03
# 2025-01-19 22:39:34.806000: BUY_TO_COVER_SHORT 1.77 @ 103261.33 | PnL: -12085.30 | Capital: 177457.73 | Reason: Prediction above long threshold (close short)
# 2025-01-19 22:47:05.341000: BUY_OPEN 1.55 @ 102941.21 (Prob: -0.3571) | Capital: 177457.73
# 2025-01-21 23:04:22.344000: SELL_CLOSE_LONG 1.55 @ 105642.10 | PnL: 4106.39 | Capital: 181564.12 | Reason: Prediction below short threshold (close long)
# 2025-01-21 23:20:07.892000: SELL_SHORT_OPEN -1.54 @ 105969.77 (Prob: 0.3528) | Capital: 181564.12
# 2025-01-24 14:18:39.036000: BUY_TO_COVER_SHORT 1.54 @ 105220.60 | PnL: 1073.57 | Capital: 182637.69 | Reason: Prediction above long threshold (close short)
# 2025-01-24 14:32:13.889000: BUY_OPEN 1.57 @ 104894.27 (Prob: -0.3611) | Capital: 182637.69
# 2025-01-29 02:15:34.923000: SELL_CLOSE_LONG 1.57 @ 101835.67 | PnL: -4870.33 | Capital: 177767.36 | Reason: Prediction below short threshold (close long)
# 2025-01-29 05:08:33.887000: SELL_SHORT_OPEN -1.57 @ 102151.74 (Prob: 0.3658) | Capital: 177767.36
# 2025-02-03 00:46:52.878000: BUY_TO_COVER_SHORT 1.57 @ 96516.51 | PnL: 8745.97 | Capital: 186513.33 | Reason: Prediction above long threshold (close short)
# 2025-02-03 00:47:32.942000: BUY_OPEN 1.74 @ 96217.30 (Prob: -0.3625) | Capital: 186513.33
# 2025-02-03 17:54:19.024000: SELL_CLOSE_LONG 1.74 @ 98983.46 | PnL: 4737.16 | Capital: 191250.50 | Reason: Prediction below short threshold (close long)
# 2025-02-03 17:55:28.990000: SELL_SHORT_OPEN -1.74 @ 98676.58 (Prob: 0.3655) | Capital: 191250.50
# 2025-02-06 18:34:26.787000: BUY_TO_COVER_SHORT 1.74 @ 96299.06 | PnL: 4061.17 | Capital: 195311.67 | Reason: Prediction above long threshold (close short)
# 2025-02-06 18:49:32.860000: BUY_OPEN 1.82 @ 96598.17 (Prob: -0.3616) | Capital: 195311.67
# 2025-02-14 14:39:16.539000: SELL_CLOSE_LONG 1.82 @ 97087.29 | PnL: 801.32 | Capital: 196112.99 | Reason: Prediction below short threshold (close long)
# 2025-02-14 14:53:10.720000: SELL_SHORT_OPEN -1.81 @ 97388.38 (Prob: 0.3553) | Capital: 196112.99
# 2025-02-25 07:35:04.352000: BUY_TO_COVER_SHORT 1.81 @ 88757.99 | PnL: 15553.07 | Capital: 211666.07 | Reason: Prediction above long threshold (close short)
# 2025-02-25 07:35:14.007000: BUY_OPEN 2.15 @ 88482.69 (Prob: -0.3639) | Capital: 211666.07
# 2025-02-26 15:28:27.545000: SELL_CLOSE_LONG 2.15 @ 87735.14 | PnL: -1703.04 | Capital: 209963.03 | Reason: Prediction below short threshold (close long)
# 2025-02-26 15:38:05.047000: SELL_SHORT_OPEN -2.15 @ 88007.45 (Prob: 0.3656) | Capital: 209963.03
# 2025-03-03 14:56:34.208000: BUY_TO_COVER_SHORT 2.15 @ 89679.23 | PnL: -3684.03 | Capital: 206279.00 | Reason: Prediction above long threshold (close short)
# 2025-03-03 14:57:25.608000: BUY_OPEN 2.08 @ 89401.14 (Prob: -0.3649) | Capital: 206279.00
# 2025-03-04 16:14:21.032000: SELL_CLOSE_LONG 2.08 @ 82898.43 | PnL: -13582.85 | Capital: 192696.14 | Reason: Prediction below short threshold (close long)
# 2025-03-04 16:17:05.877000: SELL_SHORT_OPEN -2.10 @ 82641.41 (Prob: 0.3630) | Capital: 192696.14
# 2025-03-07 00:25:25.935000: BUY_TO_COVER_SHORT 2.10 @ 87185.99 | PnL: -9623.66 | Capital: 183072.49 | Reason: Prediction above long threshold (close short)
# 2025-03-07 00:25:41.346000: BUY_OPEN 1.89 @ 86915.70 (Prob: -0.3597) | Capital: 183072.49
# 2025-03-10 00:21:15.587000: SELL_CLOSE_LONG 1.89 @ 80382.69 | PnL: -12454.52 | Capital: 170617.97 | Reason: Prediction below short threshold (close long)
# 2025-03-10 00:24:08.775000: SELL_SHORT_OPEN -1.90 @ 80632.32 (Prob: 0.3600) | Capital: 170617.97
# 2025-03-14 14:08:12.322000: BUY_TO_COVER_SHORT 1.90 @ 83166.98 | PnL: -4903.74 | Capital: 165714.23 | Reason: Prediction above long threshold (close short)
# 2025-03-14 14:10:14.700000: BUY_OPEN 1.79 @ 83424.86 (Prob: -0.3588) | Capital: 165714.23
# 2025-03-23 17:19:27.131000: SELL_CLOSE_LONG 1.79 @ 85315.14 | PnL: 3301.44 | Capital: 169015.66 | Reason: Prediction below short threshold (close long)
# 2025-03-23 17:32:31.067000: SELL_SHORT_OPEN -1.79 @ 85050.42 (Prob: 0.3621) | Capital: 169015.66
# 2025-03-31 03:30:45.550000: BUY_TO_COVER_SHORT 1.79 @ 81896.69 | PnL: 5564.49 | Capital: 174580.15 | Reason: Prediction above long threshold (close short)
#
# ============================================================
# Backtesting Results Summary (Long-Short Strategy):
# Initial Capital: 100000.00
# Final Capital: 315261.93
# Total Return: 215.26%
# Total Realized PnL: 206697.34
# 年化收益 (近似): 171.39%
# Maximum Drawdown: -29.99%
# Sharpe Ratio (Risk-Free Rate = 0): 662.10
# Number of Trades: 108
# Win Rate: 62.96%
# ============================================================
# reverse no ma

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

all_predictions_df = a_df.to_pandas()
all_predictions_df['timestamp'] = pd.to_datetime(all_predictions_df['timestamp'], unit='us') # Assuming microseconds
all_predictions_df['ma'] = all_predictions_df['px'].rolling(window=200).mean()


symbol_to_backtest = "tst"
df = all_predictions_df.copy()
df = df.sort_values('timestamp').reset_index(drop=True)

# ===============================================
# Backtesting Parameters (Ratios for costs)
# ===============================================
initial_capital = 100000  # Initial capital
commission_ratio = 0.0005 # Commission ratio (e.0.05%)
slippage_ratio = 0.0007   # Slippage ratio (e.g., 0.02%)

trade_size_ratio = 0.9    # Percentage of current equity to allocate per trade

# Strategy Thresholds (needs optimization)
long_threshold = up_thres # Predicted probability above this to go long (buy)
short_threshold = dn_thres # Predicted probability below this to go short (sell)

beta = 4


# Dynamic Take Profit / Stop Loss (in multiples of rolling_std/px)
long_stop_loss_multiplier = beta
long_take_profit_multiplier = beta
short_stop_loss_multiplier = beta
short_take_profit_multiplier = beta

# ===============================================
# Backtesting Main Logic (No change here from previous version)
# ===============================================

# Initialize account state
capital = initial_capital
position = 0          # Position size (positive for long, negative for short, 0 for flat)
entry_price = 0       # Entry price for current position
realized_pnl = 0      # Realized PnL from closed trades
equity_curve = [initial_capital] # Equity curve
unrealized_pnl_series = [0]

# Record trades
trades = []

for i in range(len(df)):
    current_time = df['timestamp'].iloc[i]
    current_px = df['px'].iloc[i]
    predicted_prob = df[feat].iloc[i]
    current_rolling_std = df['rolling_std'].iloc[i]
    ma = df['ma'].iloc[i]

    # Calculate current total equity (capital + market value of position)
    if position > 0: # Long position
        unrealized_pnl = (current_px - entry_price) * position
    elif position < 0: # Short position
        unrealized_pnl = (entry_price - current_px) * abs(position) # Profit when price falls
    else: # Flat
        unrealized_pnl = 0

    current_equity = capital + unrealized_pnl
    equity_curve.append(current_equity)
    unrealized_pnl_series.append(unrealized_pnl)

    # -----------------------------------------------
    # Strategy Execution - Long-Short
    # -----------------------------------------------

    # Scenario 1: Currently FLAT (position == 0)
    if position == 0:
        if predicted_prob >= long_threshold and current_px > ma: # Go Long Signal
            trade_type = 'BUY_OPEN'
            trade_price = current_px * (1 + slippage_ratio)
            num_shares = (current_equity * trade_size_ratio) / (trade_price * (1 + commission_ratio))

            if num_shares > 0:
                position = num_shares
                entry_price = trade_price
                # capital -= (position * entry_price * (1 + commission_ratio))

                trades.append({
                    'timestamp': current_time, 'type': trade_type, 'price': entry_price, 'shares': position,
                    'capital_after_trade': capital, 'equity_after_trade': current_equity, 'predicted_prob': predicted_prob
                })
                # print(f"{current_time}: {trade_type} {position:.2f} @ {entry_price:.2f} (Prob: {predicted_prob:.4f}) | Capital: {capital:.2f}")

        elif predicted_prob <= short_threshold and current_px < ma: # Go Short Signal
            trade_type = 'SELL_SHORT_OPEN'
            trade_price = current_px * (1 - slippage_ratio) # Price for short is lower (sell at market)
            num_shares = (current_equity * trade_size_ratio) / (trade_price * (1 + commission_ratio))

            if num_shares > 0:
                position = -num_shares # Negative for short position
                entry_price = trade_price
                # capital -= (abs(position) * entry_price * (1 + commission_ratio))

                trades.append({
                    'timestamp': current_time, 'type': trade_type, 'price': entry_price, 'shares': position,
                    'capital_after_trade': capital, 'equity_after_trade': current_equity, 'predicted_prob': predicted_prob
                })
                # print(f"{current_time}: {trade_type} {position:.2f} @ {entry_price:.2f} (Prob: {predicted_prob:.4f}) | Capital: {capital:.2f}")

    # Scenario 2: Currently LONG (position > 0)
    elif position > 0:
        sl_price = entry_price - long_stop_loss_multiplier * current_rolling_std
        tp_price = entry_price + long_take_profit_multiplier * current_rolling_std

        should_close = False
        reason = ""

        if predicted_prob < short_threshold: # Changed from sell_threshold to short_threshold for consistent logic
            should_close = True
            reason = "Prediction below short threshold (close long)"
        # if current_px <= sl_price:
        #     should_close = True
        #     reason = "Long Stop Loss Hit"
        # elif current_px >= tp_price and predicted_prob < long_threshold:
        #     should_close = True
        #     reason = "Long Take Profit Hit"

        if should_close:
            trade_type = 'SELL_CLOSE_LONG'
            close_price = current_px * (1 - slippage_ratio)
            gross_pnl_on_trade = (close_price - entry_price) * position
            net_pnl_on_trade = gross_pnl_on_trade - (close_price * position * commission_ratio)

            realized_pnl += net_pnl_on_trade
            capital += net_pnl_on_trade

            trades.append({
                'timestamp': current_time, 'type': trade_type, 'price': close_price, 'shares': position,
                'pnl': net_pnl_on_trade, 'capital_after_trade': capital, 'equity_after_trade': current_equity,
                'reason': reason, 'predicted_prob': predicted_prob
            })
            # print(f"{current_time}: {trade_type} {position:.2f} @ {close_price:.2f} | PnL: {net_pnl_on_trade:.2f} | Capital: {capital:.2f} | Reason: {reason}")

            position = 0
            entry_price = 0


    # Scenario 3: Currently SHORT (position < 0)
    elif position < 0:
        sl_price = entry_price + long_stop_loss_multiplier * current_rolling_std
        tp_price = entry_price - long_take_profit_multiplier * current_rolling_std

        should_close = False
        reason = ""

        if predicted_prob >= long_threshold: # Changed from buy_threshold to long_threshold
            should_close = True
            reason = "Prediction above long threshold (close short)"
        # if current_px >= sl_price:
        #     should_close = True
        #     reason = "Short Stop Loss Hit"
        # elif current_px <= tp_price and predicted_prob > short_threshold:
        #     should_close = True
        #     reason = "Short Take Profit Hit"

        if should_close:
            trade_type = 'BUY_TO_COVER_SHORT'
            close_price = current_px * (1 + slippage_ratio)
            gross_pnl_on_trade = (entry_price - close_price) * abs(position)
            net_pnl_on_trade = gross_pnl_on_trade - (close_price * abs(position) * commission_ratio)

            realized_pnl += net_pnl_on_trade
            capital += net_pnl_on_trade

            trades.append({
                'timestamp': current_time, 'type': trade_type, 'price': close_price, 'shares': position,
                'pnl': net_pnl_on_trade, 'capital_after_trade': capital, 'equity_after_trade': current_equity,
                'reason': reason, 'predicted_prob': predicted_prob
            })
            # print(f"{current_time}: {trade_type} {abs(position):.2f} @ {close_price:.2f} | PnL: {net_pnl_on_trade:.2f} | Capital: {capital:.2f} | Reason: {reason}")

            position = 0
            entry_price = 0

# Final close-out at the end of backtest if any position is open
final_equity_append_time = df['timestamp'].iloc[-1] + pd.Timedelta(seconds=1)
if position != 0:
    last_px = df['px'].iloc[-1]
    if position > 0: # Close long
        final_close_price = last_px * (1 - slippage_ratio)
        gross_pnl_on_trade = (final_close_price - entry_price) * position
        net_pnl_on_trade = gross_pnl_on_trade - (final_close_price * position * commission_ratio)
        # capital += (position * final_close_price * (1 - commission_ratio))
        trades.append({
            'timestamp': final_equity_append_time, 'type': 'SELL_FINAL_LONG', 'price': final_close_price, 'shares': position,
            'pnl': net_pnl_on_trade, 'capital_after_trade': capital, 'equity_after_trade': equity_curve[-1],
            'reason': 'End of Backtest', 'predicted_prob': df[feat].iloc[-1]
        })
        # print(f"End of Backtest: SELL_FINAL_LONG {position:.2f} @ {final_close_price:.2f} | PnL: {net_pnl_on_trade:.2f} | Capital: {capital:.2f}")
    else: # Close short
        final_close_price = last_px * (1 + slippage_ratio)
        gross_pnl_on_trade = (entry_price - final_close_price) * abs(position)
        net_pnl_on_trade = gross_pnl_on_trade - (final_close_price * abs(position) * commission_ratio)
        # capital += (abs(position) * entry_price * (1 - commission_ratio))
        trades.append({
            'timestamp': final_equity_append_time, 'type': 'BUY_FINAL_SHORT', 'price': final_close_price, 'shares': position,
            'pnl': net_pnl_on_trade, 'capital_after_trade': capital, 'equity_after_trade': equity_curve[-1],
            'reason': 'End of Backtest', 'predicted_prob': df[feat].iloc[-1]
        })
        # print(f"End of Backtest: BUY_FINAL_SHORT {abs(position):.2f} @ {final_close_price:.2f} | PnL: {net_pnl_on_trade:.2f} | Capital: {capital:.2f}")
    realized_pnl += net_pnl_on_trade
    position = 0

# Final equity curve update
equity_curve[-1] = capital
unrealized_pnl_series[-1] = 0
# ===============================================
# Performance Metrics Calculation (KEY CHANGES HERE)
# ===============================================
equity_series = pd.Series(equity_curve, index=df['timestamp'].tolist() + [final_equity_append_time])
returns = equity_series.pct_change().dropna()
unrealized_pnl_series = pd.Series(unrealized_pnl_series, index=equity_series.index)

# Total Return
total_return = (capital - initial_capital) / initial_capital

# Annualized Return - Based on Total Duration
annualized_return = total_return # Default value if not enough data

if len(df) > 1:
    # Get the total duration of the backtest data
    total_duration = df['timestamp'].iloc[-1] - df['timestamp'].iloc[0]
    total_duration_seconds = total_duration.total_seconds()

    if total_duration_seconds > 0:
        # Number of seconds in a year
        seconds_in_year = 365 * 24 * 60 * 60

        # Annualization factor: (seconds in a year) / (total seconds in backtest)
        annualization_factor = seconds_in_year / total_duration_seconds

        # Apply annualization
        annualized_return = (1 + total_return)**annualization_factor - 1
    else:
        print("Warning: Total backtest duration is zero or invalid, cannot annualize return.")
else:
    print("Warning: Not enough data points to calculate total duration for annualization.")


# Max Drawdown
peak = equity_series.expanding(min_periods=1).max()
drawdown = (equity_series - peak) / peak
max_drawdown = drawdown.min()

# Sharpe Ratio (assuming risk-free rate is 0)
# For volatility, we use returns.std() and annualize it with the same factor
annualized_volatility = returns.std() * np.sqrt(annualization_factor) if 'annualization_factor' in locals() and annualization_factor > 0 else returns.std()
sharpe_ratio = annualized_return / annualized_volatility if annualized_volatility != 0 else np.nan

# Win Rate for closed trades
if len(trades) > 0:
    winning_trades = sum(1 for t in trades if 'pnl' in t and t['pnl'] > 0)
    total_closed_trades = sum(1 for t in trades if 'pnl' in t)
    win_rate = winning_trades / total_closed_trades if total_closed_trades > 0 else 0
else:
    win_rate = 0


print("\n" + "="*60)
print("Backtesting Results Summary (Long-Short Strategy):")
print(f"Initial Capital: {initial_capital:.2f}")
print(f"Final Capital: {capital:.2f}")
print(f"Total Return: {total_return:.2%}")
print(f"Total Realized PnL: {realized_pnl:.2f}")
print(f"年化收益 (近似): {annualized_return:.2%}")
print(f"Maximum Drawdown: {max_drawdown:.2%}")
print(f"Sharpe Ratio (Risk-Free Rate = 0): {sharpe_ratio:.2f}")
print(f"Number of Trades: {len(trades)}")
print(f"Win Rate: {win_rate:.2%}")
print("="*60)
print("tred ma")
# ===============================================
# Plotting
# ===============================================

# Equity Curve
plt.figure(figsize=(12, 6))
plt.plot(equity_series.index, equity_series, label='Equity Curve')
plt.title(f'{symbol_to_backtest} Long-Short Strategy Equity Curve')
plt.xlabel('Timestamp')
plt.ylabel('Equity')
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# Returns Distribution
if not returns.empty:
    plt.figure(figsize=(10, 5))
    sns.histplot(returns, kde=True, bins=50)
    plt.title(f'{symbol_to_backtest} Returns Distribution')
    plt.xlabel('Return')
    plt.ylabel('Frequency')
    plt.grid(True)
    plt.tight_layout()
    plt.show()

# Drawdown Plot
if not drawdown.empty:
    plt.figure(figsize=(12, 6))
    plt.plot(drawdown.index, drawdown, label='Drawdown')
    plt.fill_between(drawdown.index, drawdown, 0, where=(drawdown < 0), color='red', alpha=0.3)
    plt.title(f'{symbol_to_backtest} Drawdown')
    plt.xlabel('Timestamp')
    plt.ylabel('Drawdown (%)')
    plt.grid(True)
    plt.legend()
    plt.tight_layout()
    plt.show()


# plt.figure(figsize=(12, 6))
# plt.plot(unrealized_pnl_series.index, unrealized_pnl_series, label="Unrealized PnL")
# plt.axhline(0, color='gray', linestyle='--')
# plt.title(f"{symbol_to_backtest} 浮动盈亏 (Unrealized PnL)")
# plt.xlabel("Timestamp")
# plt.ylabel("Unrealized PnL")
# plt.grid(True)
# plt.legend()
# plt.tight_layout()
# plt.show()
# Out:
# ============================================================
# Backtesting Results Summary (Long-Short Strategy):
# Initial Capital: 100000.00
# Final Capital: 18913.33
# Total Return: -81.09%
# Total Realized PnL: -80635.68
# 年化收益 (近似): -76.50%
# Maximum Drawdown: -83.36%
# Sharpe Ratio (Risk-Free Rate = 0): -282.22
# Number of Trades: 108
# Win Rate: 33.33%
# ============================================================
# tred ma

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

all_predictions_df = a_df.to_pandas()
all_predictions_df['timestamp'] = pd.to_datetime(all_predictions_df['timestamp'], unit='us') # Assuming microseconds
all_predictions_df['ma'] = all_predictions_df['px'].rolling(window=500).mean()


symbol_to_backtest = "tst"
df = all_predictions_df.copy()
df = df.sort_values('timestamp').reset_index(drop=True)

# ===============================================
# Backtesting Parameters (Ratios for costs)
# ===============================================
initial_capital = 100000  # Initial capital
commission_ratio = 0.0005 # Commission ratio (e.0.05%)
slippage_ratio = 0.001   # Slippage ratio (e.g., 0.02%)

trade_size_ratio = 0.9    # Percentage of current equity to allocate per trade

# Strategy Thresholds (needs optimization)
long_threshold = up_thres # Predicted probability above this to go long (buy)
short_threshold = dn_thres # Predicted probability below this to go short (sell)

beta = 2


# Dynamic Take Profit / Stop Loss (in multiples of rolling_std/px)
long_stop_loss_multiplier = beta
long_take_profit_multiplier = beta
short_stop_loss_multiplier = beta
short_take_profit_multiplier = beta

# ===============================================
# Backtesting Main Logic (No change here from previous version)
# ===============================================

# Initialize account state
capital = initial_capital
position = 0          # Position size (positive for long, negative for short, 0 for flat)
entry_price = 0       # Entry price for current position
realized_pnl = 0      # Realized PnL from closed trades
equity_curve = [initial_capital] # Equity curve
unrealized_pnl_series = [0]

# Record trades
trades = []

for i in range(len(df)):
    current_time = df['timestamp'].iloc[i]
    current_px = df['px'].iloc[i]
    predicted_prob = df[feat].iloc[i]
    current_rolling_std = df['rolling_std'].iloc[i]
    ma = df['ma'].iloc[i]

    # Calculate current total equity (capital + market value of position)
    if position > 0: # Long position
        unrealized_pnl = (current_px - entry_price) * position
    elif position < 0: # Short position
        unrealized_pnl = (entry_price - current_px) * abs(position) # Profit when price falls
    else: # Flat
        unrealized_pnl = 0

    current_equity = capital + unrealized_pnl
    equity_curve.append(current_equity)
    unrealized_pnl_series.append(unrealized_pnl)

    # -----------------------------------------------
    # Strategy Execution - Long-Short
    # -----------------------------------------------

    # Scenario 1: Currently FLAT (position == 0)
    if position == 0:
        if predicted_prob <= short_threshold and current_px < ma: # Go Long Signal
            trade_type = 'BUY_OPEN'
            trade_price = current_px * (1 + slippage_ratio)
            num_shares = (current_equity * trade_size_ratio) / (trade_price * (1 + commission_ratio))

            if num_shares > 0:
                position = num_shares
                entry_price = trade_price
                # capital -= (position * entry_price * (1 + commission_ratio))

                trades.append({
                    'timestamp': current_time, 'type': trade_type, 'price': entry_price, 'shares': position,
                    'capital_after_trade': capital, 'equity_after_trade': current_equity, 'predicted_prob': predicted_prob
                })
                print(f"{current_time}: {trade_type} {position:.2f} @ {entry_price:.2f} (Prob: {predicted_prob:.4f}) | Capital: {capital:.2f}")
                print(i, current_px, ma)

        elif predicted_prob >= long_threshold and current_px > ma: # Go Short Signal
            trade_type = 'SELL_SHORT_OPEN'
            trade_price = current_px * (1 - slippage_ratio) # Price for short is lower (sell at market)
            num_shares = (current_equity * trade_size_ratio) / (trade_price * (1 + commission_ratio))

            if num_shares > 0:
                position = -num_shares # Negative for short position
                entry_price = trade_price
                # capital -= (abs(position) * entry_price * (1 + commission_ratio))

                trades.append({
                    'timestamp': current_time, 'type': trade_type, 'price': entry_price, 'shares': position,
                    'capital_after_trade': capital, 'equity_after_trade': current_equity, 'predicted_prob': predicted_prob
                })
                print(f"{current_time}: {trade_type} {position:.2f} @ {entry_price:.2f} (Prob: {predicted_prob:.4f}) | Capital: {capital:.2f}")
                print(i, current_px, ma)


    # Scenario 2: Currently LONG (position > 0)
    elif position > 0:
        sl_price = entry_price - long_stop_loss_multiplier * current_rolling_std
        tp_price = entry_price + long_take_profit_multiplier * current_rolling_std

        should_close = False
        reason = ""

        if predicted_prob >= long_threshold: # Changed from sell_threshold to short_threshold for consistent logic
            should_close = True
            reason = "Prediction below short threshold (close long)"
        # if current_px <= sl_price:
        #     should_close = True
        #     reason = "Long Stop Loss Hit"
        # elif current_px >= tp_price and predicted_prob > short_threshold:
        #     should_close = True
        #     reason = "Long Take Profit Hit"

        if should_close:
            trade_type = 'SELL_CLOSE_LONG'
            close_price = current_px * (1 - slippage_ratio)
            gross_pnl_on_trade = (close_price - entry_price) * position
            net_pnl_on_trade = gross_pnl_on_trade - (close_price * position * commission_ratio)

            realized_pnl += net_pnl_on_trade
            capital += net_pnl_on_trade

            trades.append({
                'timestamp': current_time, 'type': trade_type, 'price': close_price, 'shares': position,
                'pnl': net_pnl_on_trade, 'capital_after_trade': capital, 'equity_after_trade': current_equity,
                'reason': reason, 'predicted_prob': predicted_prob
            })
            print(f"{current_time}: {trade_type} {position:.2f} @ {close_price:.2f} | PnL: {net_pnl_on_trade:.2f} | Capital: {capital:.2f} | Reason: {reason}")
            print(i)

            position = 0
            entry_price = 0


    # Scenario 3: Currently SHORT (position < 0)
    elif position < 0:
        sl_price = entry_price + long_stop_loss_multiplier * current_rolling_std
        tp_price = entry_price - long_take_profit_multiplier * current_rolling_std

        should_close = False
        reason = ""

        if predicted_prob <= short_threshold: # Changed from buy_threshold to long_threshold
            should_close = True
            reason = "Prediction above long threshold (close short)"
        # if current_px >= sl_price:
        #     should_close = True
        #     reason = "Short Stop Loss Hit"
        # elif current_px <= tp_price and predicted_prob < long_threshold:
        #     should_close = True
        #     reason = "Short Take Profit Hit"

        if should_close:
            trade_type = 'BUY_TO_COVER_SHORT'
            close_price = current_px * (1 + slippage_ratio)
            gross_pnl_on_trade = (entry_price - close_price) * abs(position)
            net_pnl_on_trade = gross_pnl_on_trade - (close_price * abs(position) * commission_ratio)

            realized_pnl += net_pnl_on_trade
            capital += net_pnl_on_trade

            trades.append({
                'timestamp': current_time, 'type': trade_type, 'price': close_price, 'shares': position,
                'pnl': net_pnl_on_trade, 'capital_after_trade': capital, 'equity_after_trade': current_equity,
                'reason': reason, 'predicted_prob': predicted_prob
            })
            print(f"{current_time}: {trade_type} {abs(position):.2f} @ {close_price:.2f} | PnL: {net_pnl_on_trade:.2f} | Capital: {capital:.2f} | Reason: {reason}")
            print(i)

            position = 0
            entry_price = 0

# Final close-out at the end of backtest if any position is open
final_equity_append_time = df['timestamp'].iloc[-1] + pd.Timedelta(seconds=1)
if position != 0:
    last_px = df['px'].iloc[-1]
    if position > 0: # Close long
        final_close_price = last_px * (1 - slippage_ratio)
        gross_pnl_on_trade = (final_close_price - entry_price) * position
        net_pnl_on_trade = gross_pnl_on_trade - (final_close_price * position * commission_ratio)
        # capital += (position * final_close_price * (1 - commission_ratio))
        trades.append({
            'timestamp': final_equity_append_time, 'type': 'SELL_FINAL_LONG', 'price': final_close_price, 'shares': position,
            'pnl': net_pnl_on_trade, 'capital_after_trade': capital, 'equity_after_trade': equity_curve[-1],
            'reason': 'End of Backtest', 'predicted_prob': df[feat].iloc[-1]
        })
        print(f"End of Backtest: SELL_FINAL_LONG {position:.2f} @ {final_close_price:.2f} | PnL: {net_pnl_on_trade:.2f} | Capital: {capital:.2f}")
    else: # Close short
        final_close_price = last_px * (1 + slippage_ratio)
        gross_pnl_on_trade = (entry_price - final_close_price) * abs(position)
        net_pnl_on_trade = gross_pnl_on_trade - (final_close_price * abs(position) * commission_ratio)
        # capital += (abs(position) * entry_price * (1 - commission_ratio))
        trades.append({
            'timestamp': final_equity_append_time, 'type': 'BUY_FINAL_SHORT', 'price': final_close_price, 'shares': position,
            'pnl': net_pnl_on_trade, 'capital_after_trade': capital, 'equity_after_trade': equity_curve[-1],
            'reason': 'End of Backtest', 'predicted_prob': df[feat].iloc[-1]
        })
        print(f"End of Backtest: BUY_FINAL_SHORT {abs(position):.2f} @ {final_close_price:.2f} | PnL: {net_pnl_on_trade:.2f} | Capital: {capital:.2f}")
    realized_pnl += net_pnl_on_trade
    position = 0

# Final equity curve update
equity_curve[-1] = capital
unrealized_pnl_series[-1] = 0
# ===============================================
# Performance Metrics Calculation (KEY CHANGES HERE)
# ===============================================
equity_series = pd.Series(equity_curve, index=df['timestamp'].tolist() + [final_equity_append_time])
returns = equity_series.pct_change().dropna()
unrealized_pnl_series = pd.Series(unrealized_pnl_series, index=equity_series.index)

# Total Return
total_return = (capital - initial_capital) / initial_capital

# Annualized Return - Based on Total Duration
annualized_return = total_return # Default value if not enough data

if len(df) > 1:
    # Get the total duration of the backtest data
    total_duration = df['timestamp'].iloc[-1] - df['timestamp'].iloc[0]
    total_duration_seconds = total_duration.total_seconds()

    if total_duration_seconds > 0:
        # Number of seconds in a year
        seconds_in_year = 365 * 24 * 60 * 60

        # Annualization factor: (seconds in a year) / (total seconds in backtest)
        annualization_factor = seconds_in_year / total_duration_seconds

        # Apply annualization
        annualized_return = (1 + total_return)**annualization_factor - 1
    else:
        print("Warning: Total backtest duration is zero or invalid, cannot annualize return.")
else:
    print("Warning: Not enough data points to calculate total duration for annualization.")


# Max Drawdown
peak = equity_series.expanding(min_periods=1).max()
drawdown = (equity_series - peak) / peak
max_drawdown = drawdown.min()

# Sharpe Ratio (assuming risk-free rate is 0)
# For volatility, we use returns.std() and annualize it with the same factor
annualized_volatility = returns.std() * np.sqrt(annualization_factor) if 'annualization_factor' in locals() and annualization_factor > 0 else returns.std()
sharpe_ratio = annualized_return / annualized_volatility if annualized_volatility != 0 else np.nan

# Win Rate for closed trades
if len(trades) > 0:
    winning_trades = sum(1 for t in trades if 'pnl' in t and t['pnl'] > 0)
    total_closed_trades = sum(1 for t in trades if 'pnl' in t)
    win_rate = winning_trades / total_closed_trades if total_closed_trades > 0 else 0
else:
    win_rate = 0


print("\n" + "="*60)
print("Backtesting Results Summary (Long-Short Strategy):")
print(f"Initial Capital: {initial_capital:.2f}")
print(f"Final Capital: {capital:.2f}")
print(f"Total Return: {total_return:.2%}")
print(f"Total Realized PnL: {realized_pnl:.2f}")
print(f"年化收益 (近似): {annualized_return:.2%}")
print(f"Maximum Drawdown: {max_drawdown:.2%}")
print(f"Sharpe Ratio (Risk-Free Rate = 0): {sharpe_ratio:.2f}")
print(f"Number of Trades: {len(trades)}")
print(f"Win Rate: {win_rate:.2%}")
print("="*60)
print("reverse ma")

# ===============================================
# Plotting
# ===============================================

# Equity Curve
plt.figure(figsize=(12, 6))
plt.plot(equity_series.index, equity_series, label='Equity Curve')
plt.title(f'{symbol_to_backtest} Long-Short Strategy Equity Curve')
plt.xlabel('Timestamp')
plt.ylabel('Equity')
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# Returns Distribution
if not returns.empty:
    plt.figure(figsize=(10, 5))
    sns.histplot(returns, kde=True, bins=50)
    plt.title(f'{symbol_to_backtest} Returns Distribution')
    plt.xlabel('Return')
    plt.ylabel('Frequency')
    plt.grid(True)
    plt.tight_layout()
    plt.show()

# Drawdown Plot
if not drawdown.empty:
    plt.figure(figsize=(12, 6))
    plt.plot(drawdown.index, drawdown, label='Drawdown')
    plt.fill_between(drawdown.index, drawdown, 0, where=(drawdown < 0), color='red', alpha=0.3)
    plt.title(f'{symbol_to_backtest} Drawdown')
    plt.xlabel('Timestamp')
    plt.ylabel('Drawdown (%)')
    plt.grid(True)
    plt.legend()
    plt.tight_layout()
    plt.show()


# plt.figure(figsize=(12, 6))
# plt.plot(unrealized_pnl_series.index, unrealized_pnl_series, label="Unrealized PnL")
# plt.axhline(0, color='gray', linestyle='--')
# plt.title(f"{symbol_to_backtest} 浮动盈亏 (Unrealized PnL)")
# plt.xlabel("Timestamp")
# plt.ylabel("Unrealized PnL")
# plt.grid(True)
# plt.legend()
# plt.tight_layout()
# plt.show()
# Out:
# 2024-07-06 15:31:56.776000: SELL_SHORT_OPEN -1.57 @ 57246.10 (Prob: 0.3663) | Capital: 100000.00
# 542 57303.4 57161.77952
# 2024-07-09 17:02:10.699000: BUY_TO_COVER_SHORT 1.57 @ 57790.43 | PnL: -900.76 | Capital: 99099.24 | Reason: Prediction above long threshold (close short)
# 885
# 2024-07-12 12:30:45.848000: BUY_OPEN 1.56 @ 57187.23 (Prob: -0.3559) | Capital: 99099.24
# 1134 57130.1 57276.9934
# 2024-07-27 19:41:19.739000: SELL_CLOSE_LONG 1.56 @ 67803.13 | PnL: 16495.46 | Capital: 115594.70 | Reason: Prediction below short threshold (close long)
# 2017
# 2024-07-27 19:47:30.600000: SELL_SHORT_OPEN -1.53 @ 68013.52 (Prob: 0.3543) | Capital: 115594.70
# 2018 68081.6 66210.188
# 2024-08-05 22:07:10.062000: BUY_TO_COVER_SHORT 1.53 @ 54757.40 | PnL: 20224.90 | Capital: 135819.60 | Reason: Prediction above long threshold (close short)
# 3790
# 2024-08-07 14:45:34.513000: SELL_SHORT_OPEN -2.19 @ 55914.03 (Prob: 0.3556) | Capital: 135819.60
# 4172 55970.0 55457.48176
# 2024-08-11 12:16:46.719000: BUY_TO_COVER_SHORT 2.19 @ 60439.18 | PnL: -9953.84 | Capital: 125865.76 | Reason: Prediction above long threshold (close short)
# 4645
# 2024-08-11 20:08:03.109000: BUY_OPEN 1.92 @ 58949.79 (Prob: -0.5931) | Capital: 125865.76
# 4673 58890.9 58912.808600000004
# 2024-08-14 12:30:24.664000: SELL_CLOSE_LONG 1.92 @ 61619.32 | PnL: 5068.08 | Capital: 130933.84 | Reason: Prediction below short threshold (close long)
# 2024-11-11 23:06:51.598000: SELL_CLOSE_LONG 1.84 @ 88638.27 | PnL: 34941.32 | Capital: 177190.37 | Reason: Prediction below short threshold (close long)
# 10199
# 2024-11-11 23:10:29.683000: SELL_SHORT_OPEN -1.79 @ 88913.50 (Prob: 0.3604) | Capital: 177190.37
# 10200 89002.5 79258.503
# 2024-11-12 14:30:40.607000: BUY_TO_COVER_SHORT 1.79 @ 86040.45 | PnL: 5073.27 | Capital: 182263.64 | Reason: Prediction above long threshold (close short)
# 10369
# 2024-11-13 23:29:07.654000: SELL_SHORT_OPEN -1.82 @ 90243.47 (Prob: 0.3504) | Capital: 182263.64
# 10692 90333.8 88715.6704
# 2024-11-24 11:34:27.722000: BUY_TO_COVER_SHORT 1.82 @ 97514.42 | PnL: -13298.52 | Capital: 168965.12 | Reason: Prediction above long threshold (close short)
# 11562
# 2024-11-25 15:11:47.032000: BUY_OPEN 1.60 @ 95048.65 (Prob: -0.3811) | Capital: 168965.12
# 11636 94953.7 95063.571
# 2024-11-29 14:52:07.070000: SELL_CLOSE_LONG 1.60 @ 97686.22 | PnL: 4139.63 | Capital: 173104.75 | Reason: Prediction below short threshold (close long)
# 11951
# 2024-11-29 14:59:30.840000: SELL_SHORT_OPEN -1.59 @ 97989.11 (Prob: 0.3610) | Capital: 173104.75
# 11952 98087.2 95532.2884
# 2024-12-05 20:32:09.326000: BUY_TO_COVER_SHORT 1.59 @ 98332.83 | PnL: -624.35 | Capital: 172480.40 | Reason: Prediction above long threshold (close short)
# 12369
# 2024-12-05 22:26:41.176000: BUY_OPEN 1.58 @ 98022.82 (Prob: -0.3679) | Capital: 172480.40
# 12380 97924.9 98004.026
# 2024-12-20 12:32:30.027000: SELL_CLOSE_LONG 1.58 @ 93732.97 | PnL: -6864.35 | Capital: 165616.05 | Reason: Prediction below short threshold (close long)
# 13685
# 2024-12-21 07:35:10.664000: SELL_SHORT_OPEN -1.51 @ 98880.82 (Prob: 0.8740) | Capital: 165616.05
# 13768 98979.8 98764.82979999999
# 2024-12-28 11:56:41.023000: BUY_TO_COVER_SHORT 1.51 @ 94937.84 | PnL: 5869.21 | Capital: 171485.27 | Reason: Prediction above long threshold (close short)
# 14230
# 2024-12-28 13:00:00.462000: BUY_OPEN 1.63 @ 94643.45 (Prob: -0.3587) | Capital: 171485.27
# 14231 94548.9 96127.0432
# 2025-01-05 20:48:50.478000: SELL_CLOSE_LONG 1.63 @ 98066.74 | PnL: 5499.70 | Capital: 176984.97 | Reason: Prediction below short threshold (close long)
# 14556
# 2025-01-05 21:54:24.020000: SELL_SHORT_OPEN -1.62 @ 98370.93 (Prob: 0.3577) | Capital: 176984.97
# 14557 98469.4 95576.51879999999
# 2025-01-08 22:41:04.022000: BUY_TO_COVER_SHORT 1.62 @ 95188.99 | PnL: 5072.73 | Capital: 182057.70 | Reason: Prediction above long threshold (close short)
# 14774
# 2025-01-09 01:24:13.999000: BUY_OPEN 1.72 @ 95403.91 (Prob: -0.3552) | Capital: 182057.70
# 14775 95308.6 96163.095
# 2025-01-14 14:43:20.421000: SELL_CLOSE_LONG 1.72 @ 96745.86 | PnL: 2220.55 | Capital: 184278.25 | Reason: Prediction below short threshold (close long)
# 15172
# 2025-01-14 14:47:06.516000: SELL_SHORT_OPEN -1.72 @ 96445.86 (Prob: 0.3531) | Capital: 184278.25
# 15173 96542.4 93753.569
# 2025-01-19 22:39:34.806000: BUY_TO_COVER_SHORT 1.72 @ 103292.29 | PnL: -11856.16 | Capital: 172422.09 | Reason: Prediction above long threshold (close short)
# 15539
# 2025-01-19 23:31:15.198000: BUY_OPEN 1.55 @ 100116.92 (Prob: -0.5190) | Capital: 172422.09
# 15581 100016.9 100125.428
# 2025-01-21 23:04:22.344000: SELL_CLOSE_LONG 1.55 @ 105610.38 | PnL: 8428.74 | Capital: 180850.83 | Reason: Prediction below short threshold (close long)
# 16256
# 2025-01-21 23:20:07.892000: SELL_SHORT_OPEN -1.54 @ 105937.96 (Prob: 0.3528) | Capital: 180850.83
# 16257 106044.0 104121.6404
# 2025-01-24 14:18:39.036000: BUY_TO_COVER_SHORT 1.54 @ 105252.15 | PnL: 972.35 | Capital: 181823.18 | Reason: Prediction above long threshold (close short)
# 16639
# 2025-01-24 23:04:34.396000: BUY_OPEN 1.56 @ 104584.48 (Prob: -0.5990) | Capital: 181823.18
# 16673 104480.0 104502.59659999999
# 2025-01-29 02:15:34.923000: SELL_CLOSE_LONG 1.56 @ 101805.09 | PnL: -4426.27 | Capital: 177396.90 | Reason: Prediction below short threshold (close long)
# 16952
# 2025-01-29 18:48:39.030000: SELL_SHORT_OPEN -1.55 @ 102748.05 (Prob: 0.5175) | Capital: 177396.90
# 16971 102850.9 102772.548
# 2025-02-03 00:46:52.878000: BUY_TO_COVER_SHORT 1.55 @ 96545.45 | PnL: 9558.25 | Capital: 186955.16 | Reason: Prediction above long threshold (close short)
# 17258
# 2025-02-03 00:47:32.942000: BUY_OPEN 1.75 @ 96246.15 (Prob: -0.3625) | Capital: 186955.16
# 17259 96150.0 100880.406
# 2025-02-03 17:54:19.024000: SELL_CLOSE_LONG 1.75 @ 98953.75 | PnL: 4644.66 | Capital: 191599.82 | Reason: Prediction below short threshold (close long)
# 17523
# 2025-02-03 17:55:28.990000: SELL_SHORT_OPEN -1.75 @ 98646.95 (Prob: 0.3655) | Capital: 191599.82
# 17524 98745.7 97262.563
# 2025-02-06 18:34:26.787000: BUY_TO_COVER_SHORT 1.75 @ 96327.93 | PnL: 3967.59 | Capital: 195567.41 | Reason: Prediction above long threshold (close short)
# 17824
# 2025-02-06 18:49:32.860000: BUY_OPEN 1.82 @ 96627.13 (Prob: -0.3616) | Capital: 195567.41
# 17825 96530.6 97197.41
# 2025-02-14 14:39:16.539000: SELL_CLOSE_LONG 1.82 @ 97058.14 | PnL: 696.37 | Capital: 196263.78 | Reason: Prediction below short threshold (close long)
# 18191
# 2025-02-14 14:53:10.720000: SELL_SHORT_OPEN -1.81 @ 97359.14 (Prob: 0.3553) | Capital: 196263.78
# 18192 97456.6 96912.3912
# 2025-02-25 07:35:04.352000: BUY_TO_COVER_SHORT 1.81 @ 88784.60 | PnL: 15468.41 | Capital: 211732.19 | Reason: Prediction above long threshold (close short)
# 18562
# 2025-02-25 07:35:14.007000: BUY_OPEN 2.15 @ 88509.22 (Prob: -0.3639) | Capital: 211732.19
# 18563 88420.8 95399.769
# 2025-02-26 15:28:27.545000: SELL_CLOSE_LONG 2.15 @ 87708.80 | PnL: -1816.80 | Capital: 209915.39 | Reason: Prediction below short threshold (close long)
# 18790
# 2025-03-02 17:31:06.007000: SELL_SHORT_OPEN -2.03 @ 92796.91 (Prob: 0.3528) | Capital: 209915.39
# 19570 92889.8 83596.25720000001
# 2025-03-03 14:56:34.208000: BUY_TO_COVER_SHORT 2.03 @ 89706.12 | PnL: 6198.09 | Capital: 216113.48 | Reason: Prediction above long threshold (close short)
# 19728
# 2025-03-03 18:26:06.698000: BUY_OPEN 2.19 @ 88577.29 (Prob: -0.7088) | Capital: 216113.48
# 19782 88488.8 88569.0168
# 2025-03-04 16:14:21.032000: SELL_CLOSE_LONG 2.19 @ 82873.54 | PnL: -12609.23 | Capital: 203504.25 | Reason: Prediction below short threshold (close long)
# 20105
# 2025-03-04 18:53:21.051000: SELL_SHORT_OPEN -2.12 @ 86266.05 (Prob: 0.6963) | Capital: 203504.25
# 20148 86352.4 86297.3174
# 2025-03-07 00:25:25.935000: BUY_TO_COVER_SHORT 2.12 @ 87212.12 | PnL: -2100.17 | Capital: 201404.07 | Reason: Prediction above long threshold (close short)
# 20561
# 2025-03-07 00:25:41.346000: BUY_OPEN 2.08 @ 86941.75 (Prob: -0.3597) | Capital: 201404.07
# 20562 86854.9 88203.38139999998
# 2025-03-10 00:21:15.587000: SELL_CLOSE_LONG 2.08 @ 80358.56 | PnL: -13802.08 | Capital: 187601.99 | Reason: Prediction below short threshold (close long)
# 21004
# 2025-03-16 22:09:36.927000: BUY_OPEN 2.05 @ 82293.81 (Prob: -0.5654) | Capital: 187601.99
# 21842 82211.6 82460.9194
# 2025-03-23 17:19:27.131000: SELL_CLOSE_LONG 2.05 @ 85289.53 | PnL: 6055.77 | Capital: 193657.76 | Reason: Prediction below short threshold (close long)
# 22149
# 2025-03-23 17:32:31.067000: SELL_SHORT_OPEN -2.05 @ 85024.89 (Prob: 0.3621) | Capital: 193657.76
# 22150 85110.0 83589.21
# 2025-03-31 03:30:45.550000: BUY_TO_COVER_SHORT 2.05 @ 81921.24 | PnL: 6275.05 | Capital: 199932.81 | Reason: Prediction above long threshold (close short)
# 22438
# 2025-03-31 03:48:20.372000: BUY_OPEN 2.20 @ 81667.19 (Prob: -0.3591) | Capital: 199932.81
# 22439 81585.6 85061.6202
# 2025-04-02 20:28:09.999000: SELL_CLOSE_LONG 2.20 @ 85225.69 | PnL: 7742.79 | Capital: 207675.60 | Reason: Prediction below short threshold (close long)
# 22630
# 2025-04-02 20:28:11.587000: SELL_SHORT_OPEN -2.19 @ 85491.42 (Prob: 0.3610) | Capital: 207675.60
#
# ============================================================
# Backtesting Results Summary (Long-Short Strategy):
# Initial Capital: 100000.00
# Final Capital: 384603.75
# Total Return: 284.60%
# Total Realized PnL: 273954.12
# 年化收益 (近似): 222.60%
# Maximum Drawdown: -16.96%
# Sharpe Ratio (Risk-Free Rate = 0): 945.60
# Number of Trades: 100
# Win Rate: 66.00%
# ============================================================
# reverse ma

# %%
import polars as pl
import matplotlib.pyplot as plt
a="z_oi_di_zscaled"
b="oi_di_zscaled"
# 假设 origin_df 是你的 Polars DataFrame
# 转成 pandas DataFrame
pdf = origin_df.select([
    a,
    b,
    "px"
]).to_pandas()[-150000:]
pdf['ma'] = pdf['px'].rolling(window=500).mean()


fig, ax1 = plt.subplots(figsize=(12, 6))

ax2 = ax1.twinx()  # 第二个y轴，右侧
ax3 = ax1.twinx()  # 第三个y轴，右侧，需要偏移避免重叠

# 偏移第三个y轴，让它不和第二个y轴重叠
ax3.spines["right"].set_position(("axes", 1.1))  # 向右偏移 10%

# 画线
ax1.plot(pdf[a], color='blue', label=a)
ax1.set_ylabel(a, color='blue')
ax1.tick_params(axis='y', colors='blue')

ax2.plot(pdf['ma'], color='orange', label='ma')
ax2.set_ylabel('ma', color='orange')
ax2.tick_params(axis='y', colors='orange')

ax3.plot(pdf["px"], color='green', label="px")
ax3.set_ylabel("px", color='green')
ax3.tick_params(axis='y', colors='green')

plt.title("Three curves with independent y axes")
plt.xlabel("Index")

# 合并图例
lines_1, labels_1 = ax1.get_legend_handles_labels()
lines_2, labels_2 = ax2.get_legend_handles_labels()
lines_3, labels_3 = ax3.get_legend_handles_labels()
plt.legend(lines_1 + lines_2 + lines_3, labels_1 + labels_2 + labels_3, loc='upper left')

plt.show()

# %%
print(all_predictions_df[feat])
print(all_predictions_df["ma"])

plot_last_n_rows_with_px(
    all_predictions_df[feat], 
    all_predictions_df["ma"],
    all_predictions_df[feat], 
    all_predictions_df['px'],
    std_array=all_predictions_df['rolling_std'],
    n=1,
    m=-1,
    alpha=beta,
)
# Out:
# 0        0.000000
# 1        0.304430
# 2        0.475386
# 3        0.330728
# 4        0.449296
#            ...
# 28226   -0.694526
# 28227   -0.694777
# 28228   -0.694998
# 28229   -0.695189
# 28230   -0.695351
# Name: z_oi_di_zscaled, Length: 28231, dtype: float64
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN
#             ...
# 28226    116913.0480
# 28227    116907.8702
# 28228    116902.6764
# 28229    116896.0710
# 28230    116890.8778
# Name: ma, Length: 28231, dtype: float64

# %%
print(all_predictions_df[feat])
plot_last_n_rows_with_px(
    all_predictions_df[feat], 
    all_predictions_df[feat],      
    all_predictions_df[feat], 
    all_predictions_df['px'],
    std_array=all_predictions_df['rolling_std'],
    n=1,
    m=-1,
    alpha=beta,
)
# Out:
# 0        0.000000
# 1        0.304430
# 2        0.475386
# 3        0.330728
# 4        0.449296
#            ...
# 28226   -0.694526
# 28227   -0.694777
# 28228   -0.694998
# 28229   -0.695189
# 28230   -0.695351
# Name: z_oi_di_zscaled, Length: 28231, dtype: float64
