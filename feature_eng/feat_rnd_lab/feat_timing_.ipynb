# %%
import sys
import os
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

def add_project_root(project_name: str = "extrema_lab"):
    cwd = os.getcwd()
    path_parts = cwd.split(os.sep)

    for i in range(len(path_parts), 0, -1):
        potential_root = os.sep.join(path_parts[:i])
        if os.path.basename(potential_root) == project_name:
            root = os.path.dirname(potential_root)
            if root not in sys.path:
                sys.path.append(root)
            print(f"added sys.path: {root}")
            return

    print(f"failed to fund {project_name}")


add_project_root("extrema_lab")
from extrema_lab.feature_eng.operator.utils_tools import *
# Out:
# added sys.path: C:\quant\work

# %%
symbol = "BTCUSDT"
threshold = 0.0031
feat_cal_window = 400
feat_norm_window = 400
feat_norm_rolling_mean_window = 200

origin_df = process_single_symbol(
    symbol,
    str(threshold),
    feat_cal_window,
    feat_norm_window,
    feat_norm_rolling_mean_window,
)

# %%
prices_np = origin_df["px"].to_numpy()[:20000]
avg_steps_05pct = avg_steps_to_volatility(prices_np, 0.005)
avg_steps_1pct = avg_steps_to_volatility(prices_np, 0.01)
avg_steps_2pct = avg_steps_to_volatility(prices_np, 0.02)
avg_steps_5pct = avg_steps_to_volatility(prices_np, 0.05)

print("波动 ±0.5% 的均值步数:", avg_steps_05pct)
print("波动 ±1% 的均值步数:", avg_steps_1pct)
print("波动 ±2% 的均值步数:", avg_steps_2pct)
print("波动 ±5% 的均值步数:", avg_steps_5pct)

origin_df = origin_df.with_columns([
    future_return_expr("px", avg_steps_05pct),
    future_return_expr("px", avg_steps_1pct),
    future_return_expr("px", avg_steps_2pct),
    future_return_expr("px", avg_steps_5pct),
])
print(origin_df)
origin_df = clean_df_drop_nulls(origin_df)
# Out:
# cal abs change 0.50% avg steps: 100%|██████████| 20000/20000 [00:00<00:00, 797851.25it/s]
# cal abs change 1.00% avg steps: 100%|██████████| 20000/20000 [00:00<00:00, 284952.68it/s]
# cal abs change 2.00% avg steps: 100%|██████████| 20000/20000 [00:00<00:00, 112375.52it/s]
# cal abs change 5.00% avg steps: 100%|██████████| 20000/20000 [00:00<00:00, 21313.86it/s]
# 波动 ±0.5% 的均值步数: 3
# 波动 ±1% 的均值步数: 14
# 波动 ±2% 的均值步数: 42
# 波动 ±5% 的均值步数: 245
# shape: (28_474, 273)
# ┌───────────┬──────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ timestamp ┆ px       ┆ sum_buy_s ┆ sum_sell_ ┆ … ┆ future_re ┆ future_re ┆ future_re ┆ future_re │
# │ ---       ┆ ---      ┆ z         ┆ sz        ┆   ┆ turn_3    ┆ turn_14   ┆ turn_42   ┆ turn_245  │
# │ i64       ┆ f64      ┆ ---       ┆ ---       ┆   ┆ ---       ┆ ---       ┆ ---       ┆ ---       │
# │           ┆          ┆ f64       ┆ f64       ┆   ┆ f64       ┆ f64       ┆ f64       ┆ f64       │
# ╞═══════════╪══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ 171979434 ┆ 62765.4  ┆ 1469.862  ┆ 989.364   ┆ … ┆ 0.009336  ┆ -0.000057 ┆ 0.004953  ┆ -0.070354 │
# │ 6863000   ┆          ┆           ┆           ┆   ┆           ┆           ┆           ┆           │
# │ 171979560 ┆ 62960.0  ┆ 1252.314  ┆ 1049.962  ┆ … ┆ 0.003097  ┆ -0.000057 ┆ -0.00126  ┆ -0.070353 │
# │ 9089000   ┆          ┆           ┆           ┆   ┆           ┆           ┆           ┆           │
# │ 171979597 ┆ 63155.6  ┆ 1241.123  ┆ 585.889   ┆ … ┆ 0.003091  ┆ -0.006245 ┆ -0.00744  ┆ -0.076106 │
# │ 4168000   ┆          ┆           ┆           ┆   ┆           ┆           ┆           ┆           │
# │ 171979597 ┆ 63351.4  ┆ 1442.882  ┆ 184.21    ┆ … ┆ 0.003094  ┆ -0.006245 ┆ -0.013577 ┆ -0.08182  │
# │ 7521000   ┆          ┆           ┆           ┆   ┆           ┆           ┆           ┆           │
# │ 171979598 ┆ 63155.0  ┆ 197.033   ┆ 191.229   ┆ … ┆ 0.009334  ┆ -0.006245 ┆ -0.013578 ┆ -0.076098 │
# │ 0392000   ┆          ┆           ┆           ┆   ┆           ┆           ┆           ┆           │
# │ …         ┆ …        ┆ …         ┆ …         ┆ … ┆ …         ┆ …         ┆ …         ┆ …         │
# │ 175665540 ┆ 108754.5 ┆ 10184.342 ┆ 8017.601  ┆ … ┆ -0.003111 ┆ null      ┆ null      ┆ null      │
# │ 2467000   ┆          ┆           ┆           ┆   ┆           ┆           ┆           ┆           │
# │ 175666550 ┆ 109091.7 ┆ 4283.963  ┆ 4567.019  ┆ … ┆ -0.009273 ┆ null      ┆ null      ┆ null      │
# │ 2324000   ┆          ┆           ┆           ┆   ┆           ┆           ┆           ┆           │
# │ 175668039 ┆ 108753.4 ┆ 3149.858  ┆ 3748.467  ┆ … ┆ null      ┆ null      ┆ null      ┆ null      │
# │ 9421000   ┆          ┆           ┆           ┆   ┆           ┆           ┆           ┆           │
# │ 175668229 ┆ 108416.2 ┆ 698.747   ┆ 1248.173  ┆ … ┆ null      ┆ null      ┆ null      ┆ null      │
# │ 7506000   ┆          ┆           ┆           ┆   ┆           ┆           ┆           ┆           │
# │ 175668354 ┆ 108080.1 ┆ 1695.162  ┆ 1773.764  ┆ … ┆ null      ┆ null      ┆ null      ┆ null      │
# │ 4043000   ┆          ┆           ┆           ┆   ┆           ┆           ┆           ┆           │
# └───────────┴──────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴───────────┘
# Converted Polars DataFrame to Pandas
# Null counts per column:
# future_return_3        3
# future_return_14      14
# future_return_42      42
# future_return_245    245
# dtype: int64
# Dropping columns with nulls greater than 500000: []
# Shape after dropping columns: (28474, 273)
# Shape after dropping rows with nulls: (28229, 273)

# %%
origin_df
# Out:
# shape: (28_229, 273)
# ┌───────────┬──────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ timestamp ┆ px       ┆ sum_buy_s ┆ sum_sell_ ┆ … ┆ future_re ┆ future_re ┆ future_re ┆ future_re │
# │ ---       ┆ ---      ┆ z         ┆ sz        ┆   ┆ turn_3    ┆ turn_14   ┆ turn_42   ┆ turn_245  │
# │ i64       ┆ f64      ┆ ---       ┆ ---       ┆   ┆ ---       ┆ ---       ┆ ---       ┆ ---       │
# │           ┆          ┆ f64       ┆ f64       ┆   ┆ f64       ┆ f64       ┆ f64       ┆ f64       │
# ╞═══════════╪══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ 171979434 ┆ 62765.4  ┆ 1469.862  ┆ 989.364   ┆ … ┆ 0.009336  ┆ -0.000057 ┆ 0.004953  ┆ -0.070354 │
# │ 6863000   ┆          ┆           ┆           ┆   ┆           ┆           ┆           ┆           │
# │ 171979560 ┆ 62960.0  ┆ 1252.314  ┆ 1049.962  ┆ … ┆ 0.003097  ┆ -0.000057 ┆ -0.00126  ┆ -0.070353 │
# │ 9089000   ┆          ┆           ┆           ┆   ┆           ┆           ┆           ┆           │
# │ 171979597 ┆ 63155.6  ┆ 1241.123  ┆ 585.889   ┆ … ┆ 0.003091  ┆ -0.006245 ┆ -0.00744  ┆ -0.076106 │
# │ 4168000   ┆          ┆           ┆           ┆   ┆           ┆           ┆           ┆           │
# │ 171979597 ┆ 63351.4  ┆ 1442.882  ┆ 184.21    ┆ … ┆ 0.003094  ┆ -0.006245 ┆ -0.013577 ┆ -0.08182  │
# │ 7521000   ┆          ┆           ┆           ┆   ┆           ┆           ┆           ┆           │
# │ 171979598 ┆ 63155.0  ┆ 197.033   ┆ 191.229   ┆ … ┆ 0.009334  ┆ -0.006245 ┆ -0.013578 ┆ -0.076098 │
# │ 0392000   ┆          ┆           ┆           ┆   ┆           ┆           ┆           ┆           │
# │ …         ┆ …        ┆ …         ┆ …         ┆ … ┆ …         ┆ …         ┆ …         ┆ …         │
# │ 175606477 ┆ 112532.5 ┆ 821.407   ┆ 1139.653  ┆ … ┆ -0.00311  ┆ 0.006152  ┆ -0.013642 ┆ -0.033573 │
# │ 7907000   ┆          ┆           ┆           ┆   ┆           ┆           ┆           ┆           │
# │ 175606512 ┆ 112183.6 ┆ 1680.593  ┆ 2404.959  ┆ … ┆ 0.003091  ┆ 0.006152  ┆ -0.013644 ┆ -0.027561 │
# │ 7400000   ┆          ┆           ┆           ┆   ┆           ┆           ┆           ┆           │
# │ 175606521 ┆ 112531.4 ┆ 989.019   ┆ 820.207   ┆ … ┆ -0.003111 ┆ 0.006155  ┆ -0.013643 ┆ -0.033573 │
# │ 0012000   ┆          ┆           ┆           ┆   ┆           ┆           ┆           ┆           │
# │ 175606529 ┆ 112182.5 ┆ 293.219   ┆ 335.53    ┆ … ┆ -0.003113 ┆ 0.012413  ┆ -0.007508 ┆ -0.033573 │
# │ 0709000   ┆          ┆           ┆           ┆   ┆           ┆           ┆           ┆           │
# │ 175606556 ┆ 112530.4 ┆ 1127.979  ┆ 1135.316  ┆ … ┆ -0.003114 ┆ 0.005013  ┆ -0.007507 ┆ -0.039548 │
# │ 0085000   ┆          ┆           ┆           ┆   ┆           ┆           ┆           ┆           │
# └───────────┴──────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴───────────┘

# %%
import polars as pl
import matplotlib.pyplot as plt
a="z_oi_di_zscaled"
b="oi_di_zscaled"
# 假设 origin_df 是你的 Polars DataFrame
# 转成 pandas DataFrame
pdf = origin_df.select([
    a,
    b,
    "px"
]).to_pandas()[-150000:]
pdf['ma'] = pdf['px'].rolling(window=500).mean()


fig, ax1 = plt.subplots(figsize=(12, 6))

ax2 = ax1.twinx()  # 第二个y轴，右侧
ax3 = ax1.twinx()  # 第三个y轴，右侧，需要偏移避免重叠

# 偏移第三个y轴，让它不和第二个y轴重叠
ax3.spines["right"].set_position(("axes", 1.1))  # 向右偏移 10%

# 画线
ax1.plot(pdf[a], color='blue', label=a)
ax1.set_ylabel(a, color='blue')
ax1.tick_params(axis='y', colors='blue')

ax2.plot(pdf['ma'], color='orange', label='ma')
ax2.set_ylabel('ma', color='orange')
ax2.tick_params(axis='y', colors='orange')

ax3.plot(pdf["px"], color='green', label="px")
ax3.set_ylabel("px", color='green')
ax3.tick_params(axis='y', colors='green')

plt.title("Three curves with independent y axes")
plt.xlabel("Index")

# 合并图例
lines_1, labels_1 = ax1.get_legend_handles_labels()
lines_2, labels_2 = ax2.get_legend_handles_labels()
lines_3, labels_3 = ax3.get_legend_handles_labels()
plt.legend(lines_1 + lines_2 + lines_3, labels_1 + labels_2 + labels_3, loc='upper left')

plt.show()

# %%
def plot_last_n_rows_with_px(y_test, y_test_binary, y_pred_prob, px, std_array=None, n=700, m=-1, alpha=1):
    # 截取最后 n 行
    y_test_slice = y_test[n:m]
    y_test_binary_slice = y_test_binary[n:m]
    y_pred_prob_slice = y_pred_prob[n:m]
    px_slice = px[n:m]
    
    if std_array is not None:
        std_slice = std_array[n:m]
    else:
        std_slice = None

    time_index = np.arange(len(y_test_slice))

    fig, ax1 = plt.subplots(figsize=(16, 7))

    # # 原始收益
    # ax1.plot(time_index, y_test_slice, label="Original Future Returns", color='gray', alpha=0.8)
    # ax1.set_ylabel("Original Future Returns", color='gray')
    # ax1.tick_params(axis='y', labelcolor='gray')

    ax2 = ax1.twinx()
    ax2.scatter(time_index, y_test_binary_slice, label="GMM Labels", color='tab:blue', marker='o', s=20, alpha=0.7)
    ax2.set_ylabel("GMM Labels (0 or 1)", color='tab:blue')
    ax2.tick_params(axis='y', labelcolor='tab:blue')
    # ax2.set_ylim(-0.1, 1.1)

    # 模型预测概率
    ax3 = ax1.twinx()
    ax3.spines.right.set_position(("outward", 60))
    ax3.plot(time_index, y_pred_prob_slice, label="MODEL Predicted Probability", color='tab:green', alpha=0.4)
    ax3.set_ylabel("MODEL Predicted Probability", color='tab:green')
    ax3.tick_params(axis='y', labelcolor='tab:green')
    # ax3.set_ylim(-1.05, 1.05)

    # 价格线 (第4轴)
    ax4 = ax1.twinx()
    ax4.spines.right.set_position(("outward", 120))  # 再右移一层
    ax4.plot(time_index, px_slice, label="Price (px)", color='tab:blue', linestyle='--', alpha=0.6)

    # 加上下轨线
    if std_slice is not None:
        ax4.plot(time_index, px_slice + alpha * std_slice, label="Price + std", color='tab:gray', linestyle=':', alpha=0.4)
        ax4.plot(time_index, px_slice - alpha * std_slice, label="Price - std", color='tab:gray', linestyle=':', alpha=0.4)

    ax4.set_ylabel("Price (px)", color='tab:red')
    ax4.tick_params(axis='y', labelcolor='tab:red')

    # x轴
    ax1.set_xlabel("Time Index")
    plt.title(f"Compare Returns, Labels, Prediction & Price (Last {n} Rows)")

    # 图例
    lines_1, labels_1 = ax1.get_legend_handles_labels()
    # lines_2, labels_2 = ax2.get_legend_handles_labels()
    lines_3, labels_3 = ax3.get_legend_handles_labels()
    lines_4, labels_4 = ax4.get_legend_handles_labels()

    ax1.legend(
        lines_1 +  lines_3 + lines_4,
        labels_1 +  labels_3 + labels_4,
        loc='upper left'
    )

    plt.tight_layout()
    plt.show()

# %%
import polars as pl
import numpy as np
from tqdm import tqdm

rolling_window = 500
alpha = 5

exclude_prefixes = ['px', 'timestamp', 'timestamp_dt', 'symbol']
target_col = "future_std_label"
co = [
    col for col in origin_df.columns
    if col.endswith("_zscaled") 
        # and (col.startswith("z_")) 
        and all(not col.startswith(prefix) for prefix in exclude_prefixes)
        and not col.startswith("future_return_")
        and col != "px"
]
a_df = (
    origin_df
    .with_columns([
        pl.col("px").rolling_std(window_size=rolling_window).alias("rolling_std"),
        pl.mean_horizontal(co).alias("factor_mean"),
    ])
)

def label_by_future_std(px: np.ndarray, std: np.ndarray) -> np.ndarray:
    n = len(px)
    labels = np.full(n, -1)  # 初始化为 -1（未触发）

    for i in tqdm(range(n), desc="Labeling by future std"):
        anchor_price = px[i]
        for j in range(i + 1, n):
            upper_bound = anchor_price + alpha * std[j]
            lower_bound = anchor_price - alpha * std[j]
            if px[j] >= upper_bound:
                labels[i] = 1
                break
            elif px[j] <= lower_bound:
                labels[i] = 0
                break

            else:
                labels[i] = -1

    return labels

px_np = a_df["px"].to_numpy()
std_np = a_df["rolling_std"].to_numpy()

labels_np = label_by_future_std(px_np, std_np)

a_df = a_df.with_columns(pl.Series("future_std_label", labels_np))
print(a_df)
a_df_filtered = a_df.filter(pl.col("future_std_label") >= 0)
a_df_filtered = clean_df_drop_nulls(a_df_filtered)
print(a_df_filtered)

weekly_dataframes = split_df_by_week(a_df_filtered)
print("num weekly dfs: ", len(weekly_dataframes))
# Out:
# Labeling by future std: 100%|██████████| 28229/28229 [00:19<00:00, 1461.88it/s]
# shape: (28_229, 276)
# ┌───────────┬──────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ timestamp ┆ px       ┆ sum_buy_s ┆ sum_sell_ ┆ … ┆ future_re ┆ rolling_s ┆ factor_me ┆ future_st │
# │ ---       ┆ ---      ┆ z         ┆ sz        ┆   ┆ turn_245  ┆ td        ┆ an        ┆ d_label   │
# │ i64       ┆ f64      ┆ ---       ┆ ---       ┆   ┆ ---       ┆ ---       ┆ ---       ┆ ---       │
# │           ┆          ┆ f64       ┆ f64       ┆   ┆ f64       ┆ f64       ┆ f64       ┆ i32       │
# ╞═══════════╪══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ 171979434 ┆ 62765.4  ┆ 1469.862  ┆ 989.364   ┆ … ┆ -0.070354 ┆ null      ┆ 0.0       ┆ 0         │
# │ 6863000   ┆          ┆           ┆           ┆   ┆           ┆           ┆           ┆           │
# │ 171979560 ┆ 62960.0  ┆ 1252.314  ┆ 1049.962  ┆ … ┆ -0.070353 ┆ null      ┆ -0.033362 ┆ 0         │
# │ 9089000   ┆          ┆           ┆           ┆   ┆           ┆           ┆           ┆           │
# │ 171979597 ┆ 63155.6  ┆ 1241.123  ┆ 585.889   ┆ … ┆ -0.076106 ┆ null      ┆ -0.05454  ┆ 0         │
# │ 4168000   ┆          ┆           ┆           ┆   ┆           ┆           ┆           ┆           │
# │ 171979597 ┆ 63351.4  ┆ 1442.882  ┆ 184.21    ┆ … ┆ -0.08182  ┆ null      ┆ -0.060566 ┆ 0         │
# │ 7521000   ┆          ┆           ┆           ┆   ┆           ┆           ┆           ┆           │
# │ 171979598 ┆ 63155.0  ┆ 197.033   ┆ 191.229   ┆ … ┆ -0.076098 ┆ null      ┆ -0.108152 ┆ 0         │
# │ 0392000   ┆          ┆           ┆           ┆   ┆           ┆           ┆           ┆           │
# │ …         ┆ …        ┆ …         ┆ …         ┆ … ┆ …         ┆ …         ┆ …         ┆ …         │
# │ 175606477 ┆ 112532.5 ┆ 821.407   ┆ 1139.653  ┆ … ┆ -0.033573 ┆ 2889.8768 ┆ -0.146859 ┆ -1        │
# │ 7907000   ┆          ┆           ┆           ┆   ┆           ┆ 51        ┆           ┆           │
# │ 175606512 ┆ 112183.6 ┆ 1680.593  ┆ 2404.959  ┆ … ┆ -0.027561 ┆ 2896.0324 ┆ -0.147658 ┆ -1        │
# │ 7400000   ┆          ┆           ┆           ┆   ┆           ┆ 76        ┆           ┆           │
# │ 175606521 ┆ 112531.4 ┆ 989.019   ┆ 820.207   ┆ … ┆ -0.033573 ┆ 2901.5537 ┆ -0.148268 ┆ -1        │
# │ 0012000   ┆          ┆           ┆           ┆   ┆           ┆ 89        ┆           ┆           │
# │ 175606529 ┆ 112182.5 ┆ 293.219   ┆ 335.53    ┆ … ┆ -0.033573 ┆ 2908.5380 ┆ -0.149164 ┆ -1        │
# │ 0709000   ┆          ┆           ┆           ┆   ┆           ┆ 47        ┆           ┆           │
# │ 175606556 ┆ 112530.4 ┆ 1127.979  ┆ 1135.316  ┆ … ┆ -0.039548 ┆ 2914.0160 ┆ -0.149642 ┆ -1        │
# │ 0085000   ┆          ┆           ┆           ┆   ┆           ┆ 15        ┆           ┆           │
# └───────────┴──────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴───────────┘
# Converted Polars DataFrame to Pandas
# Null counts per column:
# rolling_std    499
# dtype: int64
# Dropping columns with nulls greater than 500000: []
# Shape after dropping columns: (26927, 276)
# Shape after dropping rows with nulls: (26428, 276)
# shape: (26_428, 276)
# ┌───────────┬──────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ timestamp ┆ px       ┆ sum_buy_s ┆ sum_sell_ ┆ … ┆ future_re ┆ rolling_s ┆ factor_me ┆ future_st │
# │ ---       ┆ ---      ┆ z         ┆ sz        ┆   ┆ turn_245  ┆ td        ┆ an        ┆ d_label   │
# │ i64       ┆ f64      ┆ ---       ┆ ---       ┆   ┆ ---       ┆ ---       ┆ ---       ┆ ---       │
# │           ┆          ┆ f64       ┆ f64       ┆   ┆ f64       ┆ f64       ┆ f64       ┆ i32       │
# ╞═══════════╪══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ 172020361 ┆ 56105.6  ┆ 2201.998  ┆ 2087.499  ┆ … ┆ -0.017415 ┆ 2664.4152 ┆ 0.013398  ┆ 1         │
# │ 8445000   ┆          ┆           ┆           ┆   ┆           ┆ 85        ┆           ┆           │
# │ 172020390 ┆ 56279.6  ┆ 1316.117  ┆ 922.746   ┆ … ┆ -0.017417 ┆ 2655.4280 ┆ 0.014181  ┆ 1         │
# │ 8069000   ┆          ┆           ┆           ┆   ┆           ┆ 86        ┆           ┆           │
# │ 172020399 ┆ 56454.2  ┆ 773.804   ┆ 190.914   ┆ … ┆ -0.023493 ┆ 2645.4088 ┆ 0.01468   ┆ 1         │
# │ 5294000   ┆          ┆           ┆           ┆   ┆           ┆ 76        ┆           ┆           │
# │ 172020458 ┆ 56629.3  ┆ 2875.394  ┆ 1636.559  ┆ … ┆ -0.029531 ┆ 2634.3350 ┆ 0.015501  ┆ 1         │
# │ 0272000   ┆          ┆           ┆           ┆   ┆           ┆ 95        ┆           ┆           │
# │ 172020486 ┆ 56453.5  ┆ 834.671   ┆ 1169.105  ┆ … ┆ -0.023488 ┆ 2622.4564 ┆ 0.016136  ┆ 1         │
# │ 2559000   ┆          ┆           ┆           ┆   ┆           ┆ 87        ┆           ┆           │
# │ …         ┆ …        ┆ …         ┆ …         ┆ … ┆ …         ┆ …         ┆ …         ┆ …         │
# │ 175278735 ┆ 120797.6 ┆ 2258.402  ┆ 1619.338  ┆ … ┆ -0.035923 ┆ 4915.0174 ┆ -0.068554 ┆ 0         │
# │ 3416000   ┆          ┆           ┆           ┆   ┆           ┆ 29        ┆           ┆           │
# │ 175278819 ┆ 120423.1 ┆ 3517.871  ┆ 3479.18   ┆ … ┆ -0.035923 ┆ 4910.1481 ┆ -0.069837 ┆ 0         │
# │ 3037000   ┆          ┆           ┆           ┆   ┆           ┆ 35        ┆           ┆           │
# │ 175278847 ┆ 120421.9 ┆ 275.196   ┆ 239.762   ┆ … ┆ -0.035925 ┆ 4902.1106 ┆ -0.073287 ┆ 0         │
# │ 3601000   ┆          ┆           ┆           ┆   ┆           ┆ 55        ┆           ┆           │
# │ 175280286 ┆ 120661.6 ┆ 2907.939  ┆ 2549.922  ┆ … ┆ -0.034887 ┆ 4867.7471 ┆ -0.083278 ┆ 0         │
# │ 4012000   ┆          ┆           ┆           ┆   ┆           ┆ 69        ┆           ┆           │
# │ 175281845 ┆ 120657.8 ┆ 3490.967  ┆ 3378.6    ┆ … ┆ -0.022465 ┆ 4829.9395 ┆ -0.09599  ┆ 0         │
# │ 2233000   ┆          ┆           ┆           ┆   ┆           ┆ 47        ┆           ┆           │
# └───────────┴──────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴───────────┘
# num weekly dfs:  55

# %%
feat = "z_oi_di_zscaled"
up_thres = 0.35
dn_thres = -0.35

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

all_predictions_df = a_df.to_pandas()
all_predictions_df['timestamp'] = pd.to_datetime(all_predictions_df['timestamp'], unit='us') # Assuming microseconds


symbol_to_backtest = "tst"
df = all_predictions_df.copy()
df = df.sort_values('timestamp').reset_index(drop=True)

# ===============================================
# Backtesting Parameters (Ratios for costs)
# ===============================================
initial_capital = 100000  # Initial capital
commission_ratio = 0.0005 # Commission ratio (e.0.05%)
slippage_ratio = 0.0007   # Slippage ratio (e.g., 0.02%)

trade_size_ratio = 0.9    # Percentage of current equity to allocate per trade

# Strategy Thresholds (needs optimization)
long_threshold = up_thres # Predicted probability above this to go long (buy)
short_threshold = dn_thres # Predicted probability below this to go short (sell)

beta = 5


# Dynamic Take Profit / Stop Loss (in multiples of rolling_std/px)
long_stop_loss_multiplier = beta
long_take_profit_multiplier = beta
short_stop_loss_multiplier = beta
short_take_profit_multiplier = beta

# ===============================================
# Backtesting Main Logic (No change here from previous version)
# ===============================================

# Initialize account state
capital = initial_capital
position = 0          # Position size (positive for long, negative for short, 0 for flat)
entry_price = 0       # Entry price for current position
realized_pnl = 0      # Realized PnL from closed trades
equity_curve = [initial_capital] # Equity curve
unrealized_pnl_series = [0]

# Record trades
trades = []

for i in range(len(df)):
    current_time = df['timestamp'].iloc[i]
    current_px = df['px'].iloc[i]
    predicted_prob = df[feat].iloc[i]
    current_rolling_std = df['rolling_std'].iloc[i]

    # Calculate current total equity (capital + market value of position)
    if position > 0: # Long position
        unrealized_pnl = (current_px - entry_price) * position
    elif position < 0: # Short position
        unrealized_pnl = (entry_price - current_px) * abs(position) # Profit when price falls
    else: # Flat
        unrealized_pnl = 0

    current_equity = capital + unrealized_pnl
    equity_curve.append(current_equity)
    unrealized_pnl_series.append(unrealized_pnl)

    # -----------------------------------------------
    # Strategy Execution - Long-Short
    # -----------------------------------------------

    # Scenario 1: Currently FLAT (position == 0)
    if position == 0:
        if predicted_prob >= long_threshold: # Go Long Signal
            trade_type = 'BUY_OPEN'
            trade_price = current_px * (1 + slippage_ratio)
            num_shares = (current_equity * trade_size_ratio) / (trade_price * (1 + commission_ratio))

            if num_shares > 0:
                position = num_shares
                entry_price = trade_price
                # capital -= (position * entry_price * (1 + commission_ratio))

                trades.append({
                    'timestamp': current_time, 'type': trade_type, 'price': entry_price, 'shares': position,
                    'capital_after_trade': capital, 'equity_after_trade': current_equity, 'predicted_prob': predicted_prob
                })
                print(f"{current_time}: {trade_type} {position:.2f} @ {entry_price:.2f} (Prob: {predicted_prob:.4f}) | Capital: {capital:.2f}")

        elif predicted_prob <= short_threshold: # Go Short Signal
            trade_type = 'SELL_SHORT_OPEN'
            trade_price = current_px * (1 - slippage_ratio) # Price for short is lower (sell at market)
            num_shares = (current_equity * trade_size_ratio) / (trade_price * (1 + commission_ratio))

            if num_shares > 0:
                position = -num_shares # Negative for short position
                entry_price = trade_price
                # capital -= (abs(position) * entry_price * (1 + commission_ratio))

                trades.append({
                    'timestamp': current_time, 'type': trade_type, 'price': entry_price, 'shares': position,
                    'capital_after_trade': capital, 'equity_after_trade': current_equity, 'predicted_prob': predicted_prob
                })
                print(f"{current_time}: {trade_type} {position:.2f} @ {entry_price:.2f} (Prob: {predicted_prob:.4f}) | Capital: {capital:.2f}")

    # Scenario 2: Currently LONG (position > 0)
    elif position > 0:
        sl_price = entry_price - long_stop_loss_multiplier * current_rolling_std
        tp_price = entry_price + long_take_profit_multiplier * current_rolling_std

        should_close = False
        reason = ""

        if predicted_prob < short_threshold: # Changed from sell_threshold to short_threshold for consistent logic
            should_close = True
            reason = "Prediction below short threshold (close long)"
        # if current_px <= sl_price:
        #     should_close = True
        #     reason = "Long Stop Loss Hit"
        # elif current_px >= tp_price and predicted_prob < long_threshold:
        #     should_close = True
        #     reason = "Long Take Profit Hit"

        if should_close:
            trade_type = 'SELL_CLOSE_LONG'
            close_price = current_px * (1 - slippage_ratio)
            gross_pnl_on_trade = (close_price - entry_price) * position
            net_pnl_on_trade = gross_pnl_on_trade - (close_price * position * commission_ratio)

            realized_pnl += net_pnl_on_trade
            capital += net_pnl_on_trade

            trades.append({
                'timestamp': current_time, 'type': trade_type, 'price': close_price, 'shares': position,
                'pnl': net_pnl_on_trade, 'capital_after_trade': capital, 'equity_after_trade': current_equity,
                'reason': reason, 'predicted_prob': predicted_prob
            })
            print(f"{current_time}: {trade_type} {position:.2f} @ {close_price:.2f} | PnL: {net_pnl_on_trade:.2f} | Capital: {capital:.2f} | Reason: {reason}")

            position = 0
            entry_price = 0


    # Scenario 3: Currently SHORT (position < 0)
    elif position < 0:
        sl_price = entry_price + long_stop_loss_multiplier * current_rolling_std
        tp_price = entry_price - long_take_profit_multiplier * current_rolling_std

        should_close = False
        reason = ""

        if predicted_prob >= long_threshold: # Changed from buy_threshold to long_threshold
            should_close = True
            reason = "Prediction above long threshold (close short)"
        # if current_px >= sl_price:
        #     should_close = True
        #     reason = "Short Stop Loss Hit"
        # elif current_px <= tp_price and predicted_prob > short_threshold:
        #     should_close = True
        #     reason = "Short Take Profit Hit"

        if should_close:
            trade_type = 'BUY_TO_COVER_SHORT'
            close_price = current_px * (1 + slippage_ratio)
            gross_pnl_on_trade = (entry_price - close_price) * abs(position)
            net_pnl_on_trade = gross_pnl_on_trade - (close_price * abs(position) * commission_ratio)

            realized_pnl += net_pnl_on_trade
            capital += net_pnl_on_trade

            trades.append({
                'timestamp': current_time, 'type': trade_type, 'price': close_price, 'shares': position,
                'pnl': net_pnl_on_trade, 'capital_after_trade': capital, 'equity_after_trade': current_equity,
                'reason': reason, 'predicted_prob': predicted_prob
            })
            print(f"{current_time}: {trade_type} {abs(position):.2f} @ {close_price:.2f} | PnL: {net_pnl_on_trade:.2f} | Capital: {capital:.2f} | Reason: {reason}")

            position = 0
            entry_price = 0

# Final close-out at the end of backtest if any position is open
final_equity_append_time = df['timestamp'].iloc[-1] + pd.Timedelta(seconds=1)
if position != 0:
    last_px = df['px'].iloc[-1]
    if position > 0: # Close long
        final_close_price = last_px * (1 - slippage_ratio)
        gross_pnl_on_trade = (final_close_price - entry_price) * position
        net_pnl_on_trade = gross_pnl_on_trade - (final_close_price * position * commission_ratio)
        # capital += (position * final_close_price * (1 - commission_ratio))
        trades.append({
            'timestamp': final_equity_append_time, 'type': 'SELL_FINAL_LONG', 'price': final_close_price, 'shares': position,
            'pnl': net_pnl_on_trade, 'capital_after_trade': capital, 'equity_after_trade': equity_curve[-1],
            'reason': 'End of Backtest', 'predicted_prob': df[feat].iloc[-1]
        })
        print(f"End of Backtest: SELL_FINAL_LONG {position:.2f} @ {final_close_price:.2f} | PnL: {net_pnl_on_trade:.2f} | Capital: {capital:.2f}")
    else: # Close short
        final_close_price = last_px * (1 + slippage_ratio)
        gross_pnl_on_trade = (entry_price - final_close_price) * abs(position)
        net_pnl_on_trade = gross_pnl_on_trade - (final_close_price * abs(position) * commission_ratio)
        # capital += (abs(position) * entry_price * (1 - commission_ratio))
        trades.append({
            'timestamp': final_equity_append_time, 'type': 'BUY_FINAL_SHORT', 'price': final_close_price, 'shares': position,
            'pnl': net_pnl_on_trade, 'capital_after_trade': capital, 'equity_after_trade': equity_curve[-1],
            'reason': 'End of Backtest', 'predicted_prob': df[feat].iloc[-1]
        })
        print(f"End of Backtest: BUY_FINAL_SHORT {abs(position):.2f} @ {final_close_price:.2f} | PnL: {net_pnl_on_trade:.2f} | Capital: {capital:.2f}")
    realized_pnl += net_pnl_on_trade
    position = 0

# Final equity curve update
equity_curve[-1] = capital
unrealized_pnl_series[-1] = 0
# ===============================================
# Performance Metrics Calculation (KEY CHANGES HERE)
# ===============================================
equity_series = pd.Series(equity_curve, index=df['timestamp'].tolist() + [final_equity_append_time])
returns = equity_series.pct_change().dropna()
unrealized_pnl_series = pd.Series(unrealized_pnl_series, index=equity_series.index)

# Total Return
total_return = (capital - initial_capital) / initial_capital

# Annualized Return - Based on Total Duration
annualized_return = total_return # Default value if not enough data

if len(df) > 1:
    # Get the total duration of the backtest data
    total_duration = df['timestamp'].iloc[-1] - df['timestamp'].iloc[0]
    total_duration_seconds = total_duration.total_seconds()

    if total_duration_seconds > 0:
        # Number of seconds in a year
        seconds_in_year = 365 * 24 * 60 * 60

        # Annualization factor: (seconds in a year) / (total seconds in backtest)
        annualization_factor = seconds_in_year / total_duration_seconds

        # Apply annualization
        annualized_return = (1 + total_return)**annualization_factor - 1
    else:
        print("Warning: Total backtest duration is zero or invalid, cannot annualize return.")
else:
    print("Warning: Not enough data points to calculate total duration for annualization.")


# Max Drawdown
peak = equity_series.expanding(min_periods=1).max()
drawdown = (equity_series - peak) / peak
max_drawdown = drawdown.min()

# Sharpe Ratio (assuming risk-free rate is 0)
# For volatility, we use returns.std() and annualize it with the same factor
annualized_volatility = returns.std() * np.sqrt(annualization_factor) if 'annualization_factor' in locals() and annualization_factor > 0 else returns.std()
sharpe_ratio = annualized_return / annualized_volatility if annualized_volatility != 0 else np.nan

# Win Rate for closed trades
if len(trades) > 0:
    winning_trades = sum(1 for t in trades if 'pnl' in t and t['pnl'] > 0)
    total_closed_trades = sum(1 for t in trades if 'pnl' in t)
    win_rate = winning_trades / total_closed_trades if total_closed_trades > 0 else 0
else:
    win_rate = 0


print("\n" + "="*60)
print("Backtesting Results Summary (Long-Short Strategy):")
print(f"Initial Capital: {initial_capital:.2f}")
print(f"Final Capital: {capital:.2f}")
print(f"Total Return: {total_return:.2%}")
print(f"Total Realized PnL: {realized_pnl:.2f}")
print(f"年化收益 (近似): {annualized_return:.2%}")
print(f"Maximum Drawdown: {max_drawdown:.2%}")
print(f"Sharpe Ratio (Risk-Free Rate = 0): {sharpe_ratio:.2f}")
print(f"Number of Trades: {len(trades)}")
print(f"Win Rate: {win_rate:.2%}")
print("="*60)
print("tred no ma")
# ===============================================
# Plotting
# ===============================================

# Equity Curve
plt.figure(figsize=(12, 6))
plt.plot(equity_series.index, equity_series, label='Equity Curve')
plt.title(f'{symbol_to_backtest} Long-Short Strategy Equity Curve')
plt.xlabel('Timestamp')
plt.ylabel('Equity')
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# Returns Distribution
if not returns.empty:
    plt.figure(figsize=(10, 5))
    sns.histplot(returns, kde=True, bins=50)
    plt.title(f'{symbol_to_backtest} Returns Distribution')
    plt.xlabel('Return')
    plt.ylabel('Frequency')
    plt.grid(True)
    plt.tight_layout()
    plt.show()

# Drawdown Plot
if not drawdown.empty:
    plt.figure(figsize=(12, 6))
    plt.plot(drawdown.index, drawdown, label='Drawdown')
    plt.fill_between(drawdown.index, drawdown, 0, where=(drawdown < 0), color='red', alpha=0.3)
    plt.title(f'{symbol_to_backtest} Drawdown')
    plt.xlabel('Timestamp')
    plt.ylabel('Drawdown (%)')
    plt.grid(True)
    plt.legend()
    plt.tight_layout()
    plt.show()


# plt.figure(figsize=(12, 6))
# plt.plot(unrealized_pnl_series.index, unrealized_pnl_series, label="Unrealized PnL")
# plt.axhline(0, color='gray', linestyle='--')
# plt.title(f"{symbol_to_backtest} 浮动盈亏 (Unrealized PnL)")
# plt.xlabel("Timestamp")
# plt.ylabel("Unrealized PnL")
# plt.grid(True)
# plt.legend()
# plt.tight_layout()
# plt.show()
# Out:
# 2024-07-01 01:06:14.168000: SELL_SHORT_OPEN -1.43 @ 63111.39 (Prob: -0.4482) | Capital: 100000.00
# 2024-07-06 14:06:39.304000: BUY_TO_COVER_SHORT 1.43 @ 56812.94 | PnL: 8936.93 | Capital: 108936.93 | Reason: Prediction above long threshold (close short)
# 2024-07-06 14:41:21.509000: BUY_OPEN 1.72 @ 56989.46 (Prob: 0.3623) | Capital: 108936.93
# 2024-07-09 17:02:10.699000: SELL_CLOSE_LONG 1.72 @ 57692.29 | PnL: 1158.91 | Capital: 110095.84 | Reason: Prediction below short threshold (close long)
# 2024-07-09 17:15:01.567000: SELL_SHORT_OPEN -1.72 @ 57513.01 (Prob: -0.3605) | Capital: 110095.84
# 2024-07-27 19:41:19.739000: BUY_TO_COVER_SHORT 1.72 @ 67918.51 | PnL: -17976.62 | Capital: 92119.22 | Reason: Prediction above long threshold (close short)
# 2024-07-27 19:47:30.600000: BUY_OPEN 1.22 @ 68129.26 (Prob: 0.3543) | Capital: 92119.22
# 2024-08-05 22:07:10.062000: SELL_CLOSE_LONG 1.22 @ 54664.41 | PnL: -16410.59 | Capital: 75708.63 | Reason: Prediction below short threshold (close long)
# 2024-08-05 22:11:13.818000: SELL_SHORT_OPEN -1.25 @ 54494.43 (Prob: -0.3518) | Capital: 75708.63
# 2024-08-07 14:45:34.513000: BUY_TO_COVER_SHORT 1.25 @ 56009.18 | PnL: -1928.04 | Capital: 73780.59 | Reason: Prediction above long threshold (close short)
# 2024-08-07 14:47:51.095000: BUY_OPEN 1.18 @ 56182.90 (Prob: 0.3621) | Capital: 73780.59
# 2024-08-11 12:16:46.719000: SELL_CLOSE_LONG 1.18 @ 60336.53 | PnL: 4871.09 | Capital: 78651.67 | Reason: Prediction below short threshold (close long)
# 2024-08-11 13:11:20.951000: SELL_SHORT_OPEN -1.18 @ 60149.47 (Prob: -0.3627) | Capital: 78651.67
# 2024-08-14 12:30:24.664000: BUY_TO_COVER_SHORT 1.18 @ 61724.18 | PnL: -1888.56 | Capital: 76763.11 | Reason: Prediction above long threshold (close short)
# 2024-08-14 12:30:37.066000: BUY_OPEN 1.12 @ 61532.74 (Prob: 0.3565) | Capital: 76763.11
# 2024-08-27 00:51:30.311000: SELL_CLOSE_LONG 1.12 @ 62763.14 | PnL: 1345.53 | Capital: 78108.64 | Reason: Prediction below short threshold (close long)
# 2024-08-27 01:03:51.509000: SELL_SHORT_OPEN -1.12 @ 62957.90 (Prob: -0.3605) | Capital: 78108.64
# 2024-09-02 10:23:12.723000: BUY_TO_COVER_SHORT 1.12 @ 58559.26 | PnL: 4876.31 | Capital: 82984.96 | Reason: Prediction above long threshold (close short)
# 2024-09-02 10:51:04.030000: BUY_OPEN 1.28 @ 58377.34 (Prob: 0.3611) | Capital: 82984.96
# 2024-09-06 17:14:44.013000: SELL_CLOSE_LONG 1.28 @ 54201.03 | PnL: -5375.04 | Capital: 77609.92 | Reason: Prediction below short threshold (close long)
# 2024-09-06 17:26:00.030000: SELL_SHORT_OPEN -1.28 @ 54369.21 (Prob: -0.3623) | Capital: 77609.92
# 2024-09-09 21:15:26.446000: BUY_TO_COVER_SHORT 1.28 @ 58002.97 | PnL: -4703.25 | Capital: 72906.67 | Reason: Prediction above long threshold (close short)
# 2024-09-09 21:15:28.597000: BUY_OPEN 1.13 @ 58182.80 (Prob: 0.3677) | Capital: 72906.67
# 2024-09-16 13:33:05.032000: SELL_CLOSE_LONG 1.13 @ 58324.64 | PnL: 127.01 | Capital: 73033.69 | Reason: Prediction below short threshold (close long)
# 2024-09-16 13:35:11.009000: SELL_SHORT_OPEN -1.13 @ 58143.67 (Prob: -0.3607) | Capital: 73033.69
# 2024-10-04 01:27:55.668000: BUY_TO_COVER_SHORT 1.13 @ 61145.87 | PnL: -3426.78 | Capital: 69606.90 | Reason: Prediction above long threshold (close short)
# 2024-10-04 01:40:32.108000: BUY_OPEN 1.03 @ 60956.04 (Prob: 0.3590) | Capital: 69606.90
# 2024-10-23 04:39:26.928000: SELL_CLOSE_LONG 1.03 @ 67149.66 | PnL: 6327.69 | Capital: 75934.59 | Reason: Prediction below short threshold (close long)
# 2024-10-23 06:52:49.032000: SELL_SHORT_OPEN -1.02 @ 66941.21 (Prob: -0.3604) | Capital: 75934.59
# 2024-10-30 13:50:48.427000: BUY_TO_COVER_SHORT 1.02 @ 71886.49 | PnL: -5082.85 | Capital: 70851.74 | Reason: Prediction above long threshold (close short)
# 2024-10-30 13:53:35.012000: BUY_OPEN 0.88 @ 72109.34 (Prob: 0.3550) | Capital: 70851.74
# 2024-11-05 18:12:16.072000: SELL_CLOSE_LONG 0.88 @ 69690.28 | PnL: -2168.91 | Capital: 68682.83 | Reason: Prediction below short threshold (close long)
# 2024-11-05 18:28:15.954000: SELL_SHORT_OPEN -0.88 @ 69906.43 (Prob: -0.3591) | Capital: 68682.83
# 2024-11-11 23:06:51.598000: BUY_TO_COVER_SHORT 0.88 @ 88789.11 | PnL: -16727.84 | Capital: 51954.99 | Reason: Prediction above long threshold (close short)
# 2024-11-11 23:10:29.683000: BUY_OPEN 0.52 @ 89064.80 (Prob: 0.3604) | Capital: 51954.99
# 2024-11-12 14:30:40.607000: SELL_CLOSE_LONG 0.52 @ 85894.33 | PnL: -1686.22 | Capital: 50268.77 | Reason: Prediction below short threshold (close long)
# 2024-11-12 14:31:09.089000: SELL_SHORT_OPEN -0.53 @ 85628.02 (Prob: -0.3626) | Capital: 50268.77
# 2024-11-13 23:29:07.654000: BUY_TO_COVER_SHORT 0.53 @ 90397.03 | PnL: -2542.34 | Capital: 47726.43 | Reason: Prediction above long threshold (close short)
# 2024-11-13 23:58:19.448000: BUY_OPEN 0.47 @ 90677.43 (Prob: 0.3578) | Capital: 47726.43
# 2024-11-24 11:34:27.722000: SELL_CLOSE_LONG 0.47 @ 97348.81 | PnL: 3135.60 | Capital: 50862.03 | Reason: Prediction below short threshold (close long)
# 2024-11-24 12:29:08.055000: SELL_SHORT_OPEN -0.47 @ 97047.02 (Prob: -0.3555) | Capital: 50862.03
# 2024-11-29 14:52:07.070000: BUY_TO_COVER_SHORT 0.47 @ 97852.45 | PnL: -402.79 | Capital: 50459.25 | Reason: Prediction above long threshold (close short)
# 2024-11-29 14:59:30.840000: BUY_OPEN 0.46 @ 98155.86 (Prob: 0.3610) | Capital: 50459.25
# 2024-12-05 20:32:09.326000: SELL_CLOSE_LONG 0.46 @ 98165.84 | PnL: -18.08 | Capital: 50441.16 | Reason: Prediction below short threshold (close long)
# 2024-12-05 20:33:54.330000: SELL_SHORT_OPEN -0.46 @ 98470.22 (Prob: -0.3529) | Capital: 50441.16
# 2024-12-20 12:32:30.027000: BUY_TO_COVER_SHORT 0.46 @ 93892.48 | PnL: 2087.76 | Capital: 52528.92 | Reason: Prediction above long threshold (close short)
# 2024-12-20 12:34:06.920000: BUY_OPEN 0.50 @ 93601.28 (Prob: 0.3633) | Capital: 52528.92
# 2024-12-28 11:56:41.023000: SELL_CLOSE_LONG 0.50 @ 94776.61 | PnL: 569.42 | Capital: 53098.34 | Reason: Prediction below short threshold (close long)
# 2024-12-28 13:00:00.462000: SELL_SHORT_OPEN -0.51 @ 94482.72 (Prob: -0.3587) | Capital: 53098.34
# 2025-01-05 20:48:50.478000: BUY_TO_COVER_SHORT 0.51 @ 98233.62 | PnL: -1921.05 | Capital: 51177.28 | Reason: Prediction above long threshold (close short)
# 2025-01-05 21:54:24.020000: BUY_OPEN 0.47 @ 98538.33 (Prob: 0.3577) | Capital: 51177.28
# 2025-01-08 22:41:04.022000: SELL_CLOSE_LONG 0.47 @ 95027.33 | PnL: -1662.51 | Capital: 49514.77 | Reason: Prediction below short threshold (close long)
# 2025-01-09 01:24:13.999000: SELL_SHORT_OPEN -0.47 @ 95241.88 (Prob: -0.3552) | Capital: 49514.77
# 2025-01-14 14:43:20.421000: BUY_TO_COVER_SHORT 0.47 @ 96910.49 | PnL: -803.00 | Capital: 48711.77 | Reason: Prediction above long threshold (close short)
# 2025-01-14 14:47:06.516000: BUY_OPEN 0.45 @ 96609.98 (Prob: 0.3531) | Capital: 48711.77
# 2025-01-19 22:39:34.806000: SELL_CLOSE_LONG 0.45 @ 103116.87 | PnL: 2927.90 | Capital: 51639.66 | Reason: Prediction below short threshold (close long)
# 2025-01-19 22:47:05.341000: SELL_SHORT_OPEN -0.45 @ 102797.19 (Prob: -0.3571) | Capital: 51639.66
# 2025-01-21 23:04:22.344000: BUY_TO_COVER_SHORT 0.45 @ 105790.10 | PnL: -1376.35 | Capital: 50263.31 | Reason: Prediction above long threshold (close short)
# 2025-01-21 23:20:07.892000: BUY_OPEN 0.43 @ 106118.23 (Prob: 0.3528) | Capital: 50263.31
# 2025-01-24 14:18:39.036000: SELL_CLOSE_LONG 0.43 @ 105073.40 | PnL: -467.56 | Capital: 49795.75 | Reason: Prediction below short threshold (close long)
# 2025-01-24 14:32:13.889000: SELL_SHORT_OPEN -0.43 @ 104747.53 (Prob: -0.3611) | Capital: 49795.75
# 2025-01-29 02:15:34.923000: BUY_TO_COVER_SHORT 0.43 @ 101978.33 | PnL: 1162.40 | Capital: 50958.15 | Reason: Prediction above long threshold (close short)
# 2025-01-29 05:08:33.887000: BUY_OPEN 0.45 @ 102294.86 (Prob: 0.3658) | Capital: 50958.15
# 2025-02-03 00:46:52.878000: SELL_CLOSE_LONG 0.45 @ 96381.49 | PnL: -2671.44 | Capital: 48286.71 | Reason: Prediction below short threshold (close long)
# 2025-02-03 00:47:32.942000: SELL_SHORT_OPEN -0.45 @ 96082.69 (Prob: -0.3625) | Capital: 48286.71
# 2025-02-03 17:54:19.024000: BUY_TO_COVER_SHORT 0.45 @ 99122.14 | PnL: -1396.45 | Capital: 46890.25 | Reason: Prediction above long threshold (close short)
# 2025-02-03 17:55:28.990000: BUY_OPEN 0.43 @ 98814.82 (Prob: 0.3655) | Capital: 46890.25
# 2025-02-06 18:34:26.787000: SELL_CLOSE_LONG 0.43 @ 96164.34 | PnL: -1151.91 | Capital: 45738.34 | Reason: Prediction below short threshold (close long)
# 2025-02-06 18:49:32.860000: SELL_SHORT_OPEN -0.43 @ 96463.03 (Prob: -0.3616) | Capital: 45738.34
# 2025-02-14 14:39:16.539000: BUY_TO_COVER_SHORT 0.43 @ 97223.31 | PnL: -345.01 | Capital: 45393.33 | Reason: Prediction above long threshold (close short)
# 2025-02-14 14:53:10.720000: BUY_OPEN 0.42 @ 97524.82 (Prob: 0.3553) | Capital: 45393.33
# 2025-02-25 07:35:04.352000: SELL_CLOSE_LONG 0.42 @ 88633.81 | PnL: -3741.21 | Capital: 41652.12 | Reason: Prediction below short threshold (close long)
# 2025-02-25 07:35:14.007000: SELL_SHORT_OPEN -0.42 @ 88358.91 (Prob: -0.3639) | Capital: 41652.12
# 2025-02-26 15:28:27.545000: BUY_TO_COVER_SHORT 0.42 @ 87858.06 | PnL: 193.75 | Capital: 41845.87 | Reason: Prediction above long threshold (close short)
# 2025-02-26 15:38:05.047000: BUY_OPEN 0.43 @ 88130.75 (Prob: 0.3656) | Capital: 41845.87
# 2025-03-03 14:56:34.208000: SELL_CLOSE_LONG 0.43 @ 89553.77 | PnL: 588.68 | Capital: 42434.55 | Reason: Prediction below short threshold (close long)
# 2025-03-03 14:57:25.608000: SELL_SHORT_OPEN -0.43 @ 89276.06 (Prob: -0.3649) | Capital: 42434.55
# 2025-03-04 16:14:21.032000: BUY_TO_COVER_SHORT 0.43 @ 83014.57 | PnL: 2659.50 | Capital: 45094.04 | Reason: Prediction above long threshold (close short)
# 2025-03-04 16:17:05.877000: BUY_OPEN 0.49 @ 82757.19 (Prob: 0.3630) | Capital: 45094.04
# 2025-03-07 00:25:25.935000: SELL_CLOSE_LONG 0.49 @ 87064.01 | PnL: 2089.70 | Capital: 47183.74 | Reason: Prediction below short threshold (close long)
# 2025-03-07 00:25:41.346000: SELL_SHORT_OPEN -0.49 @ 86794.10 (Prob: -0.3597) | Capital: 47183.74
# 2025-03-10 00:21:15.587000: BUY_TO_COVER_SHORT 0.49 @ 80495.31 | PnL: 3060.56 | Capital: 50244.30 | Reason: Prediction above long threshold (close short)
# 2025-03-10 00:24:08.775000: BUY_OPEN 0.56 @ 80745.28 (Prob: 0.3600) | Capital: 50244.30
# 2025-03-14 14:08:12.322000: SELL_CLOSE_LONG 0.56 @ 83050.62 | PnL: 1267.17 | Capital: 51511.48 | Reason: Prediction below short threshold (close long)
# 2025-03-14 14:10:14.700000: SELL_SHORT_OPEN -0.56 @ 83308.14 (Prob: -0.3588) | Capital: 51511.48
# 2025-03-23 17:19:27.131000: BUY_TO_COVER_SHORT 0.56 @ 85434.66 | PnL: -1206.56 | Capital: 50304.92 | Reason: Prediction above long threshold (close short)
# 2025-03-23 17:32:31.067000: BUY_OPEN 0.53 @ 85169.58 (Prob: 0.3621) | Capital: 50304.92
# 2025-03-31 03:30:45.550000: SELL_CLOSE_LONG 0.53 @ 81782.11 | PnL: -1821.53 | Capital: 48483.38 | Reason: Prediction below short threshold (close long)
# 2025-03-31 03:48:20.372000: SELL_SHORT_OPEN -0.53 @ 81528.49 (Prob: -0.3591) | Capital: 48483.38
# 2025-04-02 20:28:09.999000: BUY_TO_COVER_SHORT 0.53 @ 85370.72 | PnL: -2078.21 | Capital: 46405.17 | Reason: Prediction above long threshold (close short)
# 2025-04-02 20:28:11.587000: BUY_OPEN 0.49 @ 85636.90 (Prob: 0.3610) | Capital: 46405.17
# 2025-04-07 05:05:31.040000: SELL_CLOSE_LONG 0.49 @ 76630.72 | PnL: -4408.75 | Capital: 41996.42 | Reason: Prediction below short threshold (close long)
# 2025-04-07 05:09:10.124000: SELL_SHORT_OPEN -0.49 @ 76868.45 (Prob: -0.3556) | Capital: 41996.42
# 2025-04-07 14:32:48.743000: BUY_TO_COVER_SHORT 0.49 @ 78844.15 | PnL: -990.35 | Capital: 41006.07 | Reason: Prediction above long threshold (close short)
# 2025-04-07 14:33:33.700000: BUY_OPEN 0.47 @ 79088.62 (Prob: 0.3528) | Capital: 41006.07
# 2025-04-09 05:28:40.627000: SELL_CLOSE_LONG 0.47 @ 76699.27 | PnL: -1132.28 | Capital: 39873.79 | Reason: Prediction below short threshold (close long)
# 2025-04-09 05:31:56.146000: SELL_SHORT_OPEN -0.47 @ 76461.44 (Prob: -0.3585) | Capital: 39873.79
# 2025-04-23 00:02:51.002000: BUY_TO_COVER_SHORT 0.47 @ 93760.29 | PnL: -8136.97 | Capital: 31736.81 | Reason: Prediction above long threshold (close short)
# 2025-04-23 00:11:03.558000: BUY_OPEN 0.31 @ 93469.28 (Prob: 0.3598) | Capital: 31736.81
# 2025-05-01 13:20:41.115000: SELL_CLOSE_LONG 0.31 @ 96416.36 | PnL: 885.42 | Capital: 32622.23 | Reason: Prediction below short threshold (close long)
# 2025-05-01 13:35:43.870000: SELL_SHORT_OPEN -0.31 @ 96117.37 (Prob: -0.3600) | Capital: 32622.23
# 2025-06-12 14:07:17.206000: BUY_TO_COVER_SHORT 0.31 @ 107329.48 | PnL: -3439.52 | Capital: 29182.71 | Reason: Prediction above long threshold (close short)
# 2025-06-12 14:37:19.584000: BUY_OPEN 0.24 @ 107662.21 (Prob: 0.3628) | Capital: 29182.71
# 2025-06-22 16:25:01.034000: SELL_CLOSE_LONG 0.24 @ 98562.96 | PnL: -2230.69 | Capital: 26952.02 | Reason: Prediction below short threshold (close long)
# 2025-06-22 16:36:27.288000: SELL_SHORT_OPEN -0.25 @ 98868.74 (Prob: -0.3600) | Capital: 26952.02
# 2025-08-01 22:06:33.135000: BUY_TO_COVER_SHORT 0.25 @ 113611.27 | PnL: -3629.11 | Capital: 23322.91 | Reason: Prediction above long threshold (close short)
# 2025-08-01 22:27:50.519000: BUY_OPEN 0.19 @ 113258.93 (Prob: 0.3604) | Capital: 23322.91
# 2025-08-19 10:08:17.693000: SELL_CLOSE_LONG 0.19 @ 115375.48 | PnL: 381.39 | Capital: 23704.30 | Reason: Prediction below short threshold (close long)
# 2025-08-19 13:30:52.100000: SELL_SHORT_OPEN -0.18 @ 115733.33 (Prob: -0.3575) | Capital: 23704.30
# End of Backtest: BUY_FINAL_SHORT 0.18 @ 112609.17 | PnL: 565.23 | Capital: 23704.30
#
# ============================================================
# Backtesting Results Summary (Long-Short Strategy):
# Initial Capital: 100000.00
# Final Capital: 23704.30
# Total Return: -76.30%
# Total Realized PnL: -75730.47
# 年化收益 (近似): -71.39%
# Maximum Drawdown: -81.55%
# Sharpe Ratio (Risk-Free Rate = 0): -260.36
# Number of Trades: 110
# Win Rate: 38.18%
# ============================================================
# tred no ma

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

all_predictions_df = a_df.to_pandas()
all_predictions_df['timestamp'] = pd.to_datetime(all_predictions_df['timestamp'], unit='us') # Assuming microseconds


symbol_to_backtest = "tst"
df = all_predictions_df.copy()
df = df.sort_values('timestamp').reset_index(drop=True)

# ===============================================
# Backtesting Parameters (Ratios for costs)
# ===============================================
initial_capital = 100000  # Initial capital
commission_ratio = 0.0005 # Commission ratio (e.0.05%)
slippage_ratio = 0.0007   # Slippage ratio (e.g., 0.02%)

trade_size_ratio = 0.9    # Percentage of current equity to allocate per trade

# Strategy Thresholds (needs optimization)
long_threshold = up_thres # Predicted probability above this to go long (buy)
short_threshold = dn_thres # Predicted probability below this to go short (sell)

beta = 5


# Dynamic Take Profit / Stop Loss (in multiples of rolling_std/px)
long_stop_loss_multiplier = beta
long_take_profit_multiplier = beta
short_stop_loss_multiplier = beta
short_take_profit_multiplier = beta

# ===============================================
# Backtesting Main Logic (No change here from previous version)
# ===============================================

# Initialize account state
capital = initial_capital
position = 0          # Position size (positive for long, negative for short, 0 for flat)
entry_price = 0       # Entry price for current position
realized_pnl = 0      # Realized PnL from closed trades
equity_curve = [initial_capital] # Equity curve
unrealized_pnl_series = [0]

# Record trades
trades = []

for i in range(len(df)):
    current_time = df['timestamp'].iloc[i]
    current_px = df['px'].iloc[i]
    predicted_prob = df[feat].iloc[i]
    current_rolling_std = df['rolling_std'].iloc[i]

    # Calculate current total equity (capital + market value of position)
    if position > 0: # Long position
        unrealized_pnl = (current_px - entry_price) * position
    elif position < 0: # Short position
        unrealized_pnl = (entry_price - current_px) * abs(position) # Profit when price falls
    else: # Flat
        unrealized_pnl = 0

    current_equity = capital + unrealized_pnl
    equity_curve.append(current_equity)
    unrealized_pnl_series.append(unrealized_pnl)

    # -----------------------------------------------
    # Strategy Execution - Long-Short
    # -----------------------------------------------

    # Scenario 1: Currently FLAT (position == 0)
    if position == 0:
        if predicted_prob <= short_threshold: # Go Long Signal
            trade_type = 'BUY_OPEN'
            trade_price = current_px * (1 + slippage_ratio)
            num_shares = (current_equity * trade_size_ratio) / (trade_price * (1 + commission_ratio))

            if num_shares > 0:
                position = num_shares
                entry_price = trade_price
                # capital -= (position * entry_price * (1 + commission_ratio))

                trades.append({
                    'timestamp': current_time, 'type': trade_type, 'price': entry_price, 'shares': position,
                    'capital_after_trade': capital, 'equity_after_trade': current_equity, 'predicted_prob': predicted_prob
                })
                print(f"{current_time}: {trade_type} {position:.2f} @ {entry_price:.2f} (Prob: {predicted_prob:.4f}) | Capital: {capital:.2f}")

        elif predicted_prob >= long_threshold: # Go Short Signal
            trade_type = 'SELL_SHORT_OPEN'
            trade_price = current_px * (1 - slippage_ratio) # Price for short is lower (sell at market)
            num_shares = (current_equity * trade_size_ratio) / (trade_price * (1 + commission_ratio))

            if num_shares > 0:
                position = -num_shares # Negative for short position
                entry_price = trade_price
                # capital -= (abs(position) * entry_price * (1 + commission_ratio))

                trades.append({
                    'timestamp': current_time, 'type': trade_type, 'price': entry_price, 'shares': position,
                    'capital_after_trade': capital, 'equity_after_trade': current_equity, 'predicted_prob': predicted_prob
                })
                print(f"{current_time}: {trade_type} {position:.2f} @ {entry_price:.2f} (Prob: {predicted_prob:.4f}) | Capital: {capital:.2f}")

    # Scenario 2: Currently LONG (position > 0)
    elif position > 0:
        sl_price = entry_price - long_stop_loss_multiplier * current_rolling_std
        tp_price = entry_price + long_take_profit_multiplier * current_rolling_std

        should_close = False
        reason = ""

        if predicted_prob >= long_threshold: # Changed from sell_threshold to short_threshold for consistent logic
            should_close = True
            reason = "Prediction below short threshold (close long)"
        # if current_px <= sl_price:
        #     should_close = True
        #     reason = "Long Stop Loss Hit"
        # elif current_px >= tp_price and predicted_prob > short_threshold:
        #     should_close = True
        #     reason = "Long Take Profit Hit"

        if should_close:
            trade_type = 'SELL_CLOSE_LONG'
            close_price = current_px * (1 - slippage_ratio)
            gross_pnl_on_trade = (close_price - entry_price) * position
            net_pnl_on_trade = gross_pnl_on_trade - (close_price * position * commission_ratio)

            realized_pnl += net_pnl_on_trade
            capital += net_pnl_on_trade

            trades.append({
                'timestamp': current_time, 'type': trade_type, 'price': close_price, 'shares': position,
                'pnl': net_pnl_on_trade, 'capital_after_trade': capital, 'equity_after_trade': current_equity,
                'reason': reason, 'predicted_prob': predicted_prob
            })
            print(f"{current_time}: {trade_type} {position:.2f} @ {close_price:.2f} | PnL: {net_pnl_on_trade:.2f} | Capital: {capital:.2f} | Reason: {reason}")

            position = 0
            entry_price = 0


    # Scenario 3: Currently SHORT (position < 0)
    elif position < 0:
        sl_price = entry_price + long_stop_loss_multiplier * current_rolling_std
        tp_price = entry_price - long_take_profit_multiplier * current_rolling_std

        should_close = False
        reason = ""

        if predicted_prob <= short_threshold: # Changed from buy_threshold to long_threshold
            should_close = True
            reason = "Prediction above long threshold (close short)"
        # if current_px >= sl_price:
        #     should_close = True
        #     reason = "Short Stop Loss Hit"
        # elif current_px <= tp_price and predicted_prob < long_threshold:
        #     should_close = True
        #     reason = "Short Take Profit Hit"

        if should_close:
            trade_type = 'BUY_TO_COVER_SHORT'
            close_price = current_px * (1 + slippage_ratio)
            gross_pnl_on_trade = (entry_price - close_price) * abs(position)
            net_pnl_on_trade = gross_pnl_on_trade - (close_price * abs(position) * commission_ratio)

            realized_pnl += net_pnl_on_trade
            capital += net_pnl_on_trade

            trades.append({
                'timestamp': current_time, 'type': trade_type, 'price': close_price, 'shares': position,
                'pnl': net_pnl_on_trade, 'capital_after_trade': capital, 'equity_after_trade': current_equity,
                'reason': reason, 'predicted_prob': predicted_prob
            })
            print(f"{current_time}: {trade_type} {abs(position):.2f} @ {close_price:.2f} | PnL: {net_pnl_on_trade:.2f} | Capital: {capital:.2f} | Reason: {reason}")

            position = 0
            entry_price = 0

# Final close-out at the end of backtest if any position is open
final_equity_append_time = df['timestamp'].iloc[-1] + pd.Timedelta(seconds=1)
if position != 0:
    last_px = df['px'].iloc[-1]
    if position > 0: # Close long
        final_close_price = last_px * (1 - slippage_ratio)
        gross_pnl_on_trade = (final_close_price - entry_price) * position
        net_pnl_on_trade = gross_pnl_on_trade - (final_close_price * position * commission_ratio)
        # capital += (position * final_close_price * (1 - commission_ratio))
        trades.append({
            'timestamp': final_equity_append_time, 'type': 'SELL_FINAL_LONG', 'price': final_close_price, 'shares': position,
            'pnl': net_pnl_on_trade, 'capital_after_trade': capital, 'equity_after_trade': equity_curve[-1],
            'reason': 'End of Backtest', 'predicted_prob': df[feat].iloc[-1]
        })
        print(f"End of Backtest: SELL_FINAL_LONG {position:.2f} @ {final_close_price:.2f} | PnL: {net_pnl_on_trade:.2f} | Capital: {capital:.2f}")
    else: # Close short
        final_close_price = last_px * (1 + slippage_ratio)
        gross_pnl_on_trade = (entry_price - final_close_price) * abs(position)
        net_pnl_on_trade = gross_pnl_on_trade - (final_close_price * abs(position) * commission_ratio)
        # capital += (abs(position) * entry_price * (1 - commission_ratio))
        trades.append({
            'timestamp': final_equity_append_time, 'type': 'BUY_FINAL_SHORT', 'price': final_close_price, 'shares': position,
            'pnl': net_pnl_on_trade, 'capital_after_trade': capital, 'equity_after_trade': equity_curve[-1],
            'reason': 'End of Backtest', 'predicted_prob': df[feat].iloc[-1]
        })
        print(f"End of Backtest: BUY_FINAL_SHORT {abs(position):.2f} @ {final_close_price:.2f} | PnL: {net_pnl_on_trade:.2f} | Capital: {capital:.2f}")
    realized_pnl += net_pnl_on_trade
    position = 0

# Final equity curve update
equity_curve[-1] = capital
unrealized_pnl_series[-1] = 0
# ===============================================
# Performance Metrics Calculation (KEY CHANGES HERE)
# ===============================================
equity_series = pd.Series(equity_curve, index=df['timestamp'].tolist() + [final_equity_append_time])
returns = equity_series.pct_change().dropna()
unrealized_pnl_series = pd.Series(unrealized_pnl_series, index=equity_series.index)

# Total Return
total_return = (capital - initial_capital) / initial_capital

# Annualized Return - Based on Total Duration
annualized_return = total_return # Default value if not enough data

if len(df) > 1:
    # Get the total duration of the backtest data
    total_duration = df['timestamp'].iloc[-1] - df['timestamp'].iloc[0]
    total_duration_seconds = total_duration.total_seconds()

    if total_duration_seconds > 0:
        # Number of seconds in a year
        seconds_in_year = 365 * 24 * 60 * 60

        # Annualization factor: (seconds in a year) / (total seconds in backtest)
        annualization_factor = seconds_in_year / total_duration_seconds

        # Apply annualization
        annualized_return = (1 + total_return)**annualization_factor - 1
    else:
        print("Warning: Total backtest duration is zero or invalid, cannot annualize return.")
else:
    print("Warning: Not enough data points to calculate total duration for annualization.")


# Max Drawdown
peak = equity_series.expanding(min_periods=1).max()
drawdown = (equity_series - peak) / peak
max_drawdown = drawdown.min()

# Sharpe Ratio (assuming risk-free rate is 0)
# For volatility, we use returns.std() and annualize it with the same factor
annualized_volatility = returns.std() * np.sqrt(annualization_factor) if 'annualization_factor' in locals() and annualization_factor > 0 else returns.std()
sharpe_ratio = annualized_return / annualized_volatility if annualized_volatility != 0 else np.nan

# Win Rate for closed trades
if len(trades) > 0:
    winning_trades = sum(1 for t in trades if 'pnl' in t and t['pnl'] > 0)
    total_closed_trades = sum(1 for t in trades if 'pnl' in t)
    win_rate = winning_trades / total_closed_trades if total_closed_trades > 0 else 0
else:
    win_rate = 0


print("\n" + "="*60)
print("Backtesting Results Summary (Long-Short Strategy):")
print(f"Initial Capital: {initial_capital:.2f}")
print(f"Final Capital: {capital:.2f}")
print(f"Total Return: {total_return:.2%}")
print(f"Total Realized PnL: {realized_pnl:.2f}")
print(f"年化收益 (近似): {annualized_return:.2%}")
print(f"Maximum Drawdown: {max_drawdown:.2%}")
print(f"Sharpe Ratio (Risk-Free Rate = 0): {sharpe_ratio:.2f}")
print(f"Number of Trades: {len(trades)}")
print(f"Win Rate: {win_rate:.2%}")
print("="*60)
print("reverse no ma")

# ===============================================
# Plotting
# ===============================================

# Equity Curve
plt.figure(figsize=(12, 6))
plt.plot(equity_series.index, equity_series, label='Equity Curve')
plt.title(f'{symbol_to_backtest} Long-Short Strategy Equity Curve')
plt.xlabel('Timestamp')
plt.ylabel('Equity')
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# Returns Distribution
if not returns.empty:
    plt.figure(figsize=(10, 5))
    sns.histplot(returns, kde=True, bins=50)
    plt.title(f'{symbol_to_backtest} Returns Distribution')
    plt.xlabel('Return')
    plt.ylabel('Frequency')
    plt.grid(True)
    plt.tight_layout()
    plt.show()

# Drawdown Plot
if not drawdown.empty:
    plt.figure(figsize=(12, 6))
    plt.plot(drawdown.index, drawdown, label='Drawdown')
    plt.fill_between(drawdown.index, drawdown, 0, where=(drawdown < 0), color='red', alpha=0.3)
    plt.title(f'{symbol_to_backtest} Drawdown')
    plt.xlabel('Timestamp')
    plt.ylabel('Drawdown (%)')
    plt.grid(True)
    plt.legend()
    plt.tight_layout()
    plt.show()


# plt.figure(figsize=(12, 6))
# plt.plot(unrealized_pnl_series.index, unrealized_pnl_series, label="Unrealized PnL")
# plt.axhline(0, color='gray', linestyle='--')
# plt.title(f"{symbol_to_backtest} 浮动盈亏 (Unrealized PnL)")
# plt.xlabel("Timestamp")
# plt.ylabel("Unrealized PnL")
# plt.grid(True)
# plt.legend()
# plt.tight_layout()
# plt.show()
# Out:
# 2024-07-01 01:06:14.168000: BUY_OPEN 1.42 @ 63199.81 (Prob: -0.4482) | Capital: 100000.00
# 2024-07-06 14:06:39.304000: SELL_CLOSE_LONG 1.42 @ 56733.46 | PnL: -9244.21 | Capital: 90755.79 | Reason: Prediction below short threshold (close long)
# 2024-07-06 14:41:21.509000: SELL_SHORT_OPEN -1.43 @ 56909.74 (Prob: 0.3623) | Capital: 90755.79
# 2024-07-09 17:02:10.699000: BUY_TO_COVER_SHORT 1.43 @ 57773.11 | PnL: -1279.99 | Capital: 89475.80 | Reason: Prediction above long threshold (close short)
# 2024-07-09 17:15:01.567000: BUY_OPEN 1.40 @ 57593.59 (Prob: -0.3605) | Capital: 89475.80
# 2024-07-27 19:41:19.739000: SELL_CLOSE_LONG 1.40 @ 67823.49 | PnL: 14249.06 | Capital: 103724.86 | Reason: Prediction below short threshold (close long)
# 2024-07-27 19:47:30.600000: SELL_SHORT_OPEN -1.37 @ 68033.94 (Prob: 0.3543) | Capital: 103724.86
# 2024-08-05 22:07:10.062000: BUY_TO_COVER_SHORT 1.37 @ 54740.99 | PnL: 18193.19 | Capital: 121918.05 | Reason: Prediction above long threshold (close short)
# 2024-08-05 22:11:13.818000: BUY_OPEN 2.01 @ 54570.77 (Prob: -0.3518) | Capital: 121918.05
# 2024-08-07 14:45:34.513000: SELL_CLOSE_LONG 2.01 @ 55930.82 | PnL: 2677.10 | Capital: 124595.15 | Reason: Prediction below short threshold (close long)
# 2024-08-07 14:47:51.095000: SELL_SHORT_OPEN -2.00 @ 56104.30 (Prob: 0.3621) | Capital: 124595.15
# 2024-08-11 12:16:46.719000: BUY_TO_COVER_SHORT 2.00 @ 60421.07 | PnL: -8683.96 | Capital: 115911.20 | Reason: Prediction above long threshold (close short)
# 2024-08-11 13:11:20.951000: BUY_OPEN 1.73 @ 60233.73 (Prob: -0.3627) | Capital: 115911.20
# 2024-08-14 12:30:24.664000: SELL_CLOSE_LONG 1.73 @ 61637.82 | PnL: 2377.21 | Capital: 118288.40 | Reason: Prediction below short threshold (close long)
# 2024-08-14 12:30:37.066000: SELL_SHORT_OPEN -1.73 @ 61446.66 (Prob: 0.3565) | Capital: 118288.40
# 2024-08-27 00:51:30.311000: BUY_TO_COVER_SHORT 1.73 @ 62851.06 | PnL: -2486.41 | Capital: 115801.99 | Reason: Prediction above long threshold (close short)
# 2024-08-27 01:03:51.509000: BUY_OPEN 1.65 @ 63046.10 (Prob: -0.3605) | Capital: 115801.99
# 2024-09-02 10:23:12.723000: SELL_CLOSE_LONG 1.65 @ 58477.34 | PnL: -7597.18 | Capital: 108204.81 | Reason: Prediction below short threshold (close long)
# 2024-09-02 10:51:04.030000: SELL_SHORT_OPEN -1.67 @ 58295.66 (Prob: 0.3611) | Capital: 108204.81
# 2024-09-06 17:14:44.013000: BUY_TO_COVER_SHORT 1.67 @ 54276.97 | PnL: 6664.66 | Capital: 114869.47 | Reason: Prediction above long threshold (close short)
# 2024-09-06 17:26:00.030000: BUY_OPEN 1.90 @ 54445.39 (Prob: -0.3623) | Capital: 114869.47
# 2024-09-09 21:15:26.446000: SELL_CLOSE_LONG 1.90 @ 57921.83 | PnL: 6542.91 | Capital: 121412.38 | Reason: Prediction below short threshold (close long)
# 2024-09-09 21:15:28.597000: SELL_SHORT_OPEN -1.88 @ 58101.40 (Prob: 0.3677) | Capital: 121412.38
# 2024-09-16 13:33:05.032000: BUY_TO_COVER_SHORT 1.88 @ 58406.36 | PnL: -628.14 | Capital: 120784.24 | Reason: Prediction above long threshold (close short)
# 2024-09-16 13:35:11.009000: BUY_OPEN 1.87 @ 58225.13 (Prob: -0.3607) | Capital: 120784.24
# 2024-10-04 01:27:55.668000: SELL_CLOSE_LONG 1.87 @ 61060.33 | PnL: 5233.68 | Capital: 126017.92 | Reason: Prediction below short threshold (close long)
# 2024-10-04 01:40:32.108000: SELL_SHORT_OPEN -1.86 @ 60870.76 (Prob: 0.3590) | Capital: 126017.92
# 2024-10-23 04:39:26.928000: BUY_TO_COVER_SHORT 1.86 @ 67243.74 | PnL: -11930.99 | Capital: 114086.93 | Reason: Prediction above long threshold (close short)
# 2024-10-23 06:52:49.032000: BUY_OPEN 1.53 @ 67034.99 (Prob: -0.3604) | Capital: 114086.93
# 2024-10-30 13:50:48.427000: SELL_CLOSE_LONG 1.53 @ 71785.91 | PnL: 7218.45 | Capital: 121305.38 | Reason: Prediction below short threshold (close long)
# 2024-10-30 13:53:35.012000: SELL_SHORT_OPEN -1.52 @ 72008.46 (Prob: 0.3550) | Capital: 121305.38
# 2024-11-05 18:12:16.072000: BUY_TO_COVER_SHORT 1.52 @ 69787.92 | PnL: 3312.09 | Capital: 124617.47 | Reason: Prediction above long threshold (close short)
# 2024-11-05 18:28:15.954000: BUY_OPEN 1.60 @ 70004.37 (Prob: -0.3591) | Capital: 124617.47
# 2024-11-11 23:06:51.598000: SELL_CLOSE_LONG 1.60 @ 88664.89 | PnL: 29810.55 | Capital: 154428.02 | Reason: Prediction below short threshold (close long)
# 2024-11-11 23:10:29.683000: SELL_SHORT_OPEN -1.56 @ 88940.20 (Prob: 0.3604) | Capital: 154428.02
# 2024-11-12 14:30:40.607000: BUY_TO_COVER_SHORT 1.56 @ 86014.67 | PnL: 4502.21 | Capital: 158930.24 | Reason: Prediction above long threshold (close short)
# 2024-11-12 14:31:09.089000: BUY_OPEN 1.67 @ 85747.98 (Prob: -0.3626) | Capital: 158930.24
# 2024-11-13 23:29:07.654000: SELL_CLOSE_LONG 1.67 @ 90270.57 | PnL: 7465.15 | Capital: 166395.39 | Reason: Prediction below short threshold (close long)
# 2024-11-13 23:58:19.448000: SELL_SHORT_OPEN -1.65 @ 90550.57 (Prob: 0.3578) | Capital: 166395.39
# 2024-11-24 11:34:27.722000: BUY_TO_COVER_SHORT 1.65 @ 97485.19 | PnL: -11543.57 | Capital: 154851.82 | Reason: Prediction above long threshold (close short)
# 2024-11-24 12:29:08.055000: BUY_OPEN 1.43 @ 97182.98 (Prob: -0.3555) | Capital: 154851.82
# 2024-11-29 14:52:07.070000: SELL_CLOSE_LONG 1.43 @ 97715.55 | PnL: 693.33 | Capital: 155545.15 | Reason: Prediction below short threshold (close long)
# 2024-11-29 14:59:30.840000: SELL_SHORT_OPEN -1.43 @ 98018.54 (Prob: 0.3610) | Capital: 155545.15
# 2024-12-05 20:32:09.326000: BUY_TO_COVER_SHORT 1.43 @ 98303.36 | PnL: -476.75 | Capital: 155068.40 | Reason: Prediction above long threshold (close short)
# 2024-12-05 20:33:54.330000: BUY_OPEN 1.41 @ 98608.18 (Prob: -0.3529) | Capital: 155068.40
# 2024-12-20 12:32:30.027000: SELL_CLOSE_LONG 1.41 @ 93761.12 | PnL: -6923.00 | Capital: 148145.40 | Reason: Prediction below short threshold (close long)
# 2024-12-20 12:34:06.920000: SELL_SHORT_OPEN -1.43 @ 93470.32 (Prob: 0.3633) | Capital: 148145.40
# 2024-12-28 11:56:41.023000: BUY_TO_COVER_SHORT 1.43 @ 94909.39 | PnL: -2119.39 | Capital: 146026.01 | Reason: Prediction above long threshold (close short)
# 2024-12-28 13:00:00.462000: BUY_OPEN 1.39 @ 94615.08 (Prob: -0.3587) | Capital: 146026.01
# 2025-01-05 20:48:50.478000: SELL_CLOSE_LONG 1.39 @ 98096.18 | PnL: 4764.85 | Capital: 150790.86 | Reason: Prediction below short threshold (close long)
# 2025-01-05 21:54:24.020000: SELL_SHORT_OPEN -1.38 @ 98400.47 (Prob: 0.3577) | Capital: 150790.86
# 2025-01-08 22:41:04.022000: BUY_TO_COVER_SHORT 1.38 @ 95160.47 | PnL: 4400.72 | Capital: 155191.58 | Reason: Prediction above long threshold (close short)
# 2025-01-09 01:24:13.999000: BUY_OPEN 1.46 @ 95375.32 (Prob: -0.3552) | Capital: 155191.58
# 2025-01-14 14:43:20.421000: SELL_CLOSE_LONG 1.46 @ 96774.91 | PnL: 1977.79 | Capital: 157169.37 | Reason: Prediction below short threshold (close long)
# 2025-01-14 14:47:06.516000: SELL_SHORT_OPEN -1.47 @ 96474.82 (Prob: 0.3531) | Capital: 157169.37
# 2025-01-19 22:39:34.806000: BUY_TO_COVER_SHORT 1.47 @ 103261.33 | PnL: -10021.15 | Capital: 147148.22 | Reason: Prediction above long threshold (close short)
# 2025-01-19 22:47:05.341000: BUY_OPEN 1.29 @ 102941.21 (Prob: -0.3571) | Capital: 147148.22
# 2025-01-21 23:04:22.344000: SELL_CLOSE_LONG 1.29 @ 105642.10 | PnL: 3405.03 | Capital: 150553.25 | Reason: Prediction below short threshold (close long)
# 2025-01-21 23:20:07.892000: SELL_SHORT_OPEN -1.28 @ 105969.77 (Prob: 0.3528) | Capital: 150553.25
# 2025-01-24 14:18:39.036000: BUY_TO_COVER_SHORT 1.28 @ 105220.60 | PnL: 890.20 | Capital: 151443.45 | Reason: Prediction above long threshold (close short)
# 2025-01-24 14:32:13.889000: BUY_OPEN 1.30 @ 104894.27 (Prob: -0.3611) | Capital: 151443.45
# 2025-01-29 02:15:34.923000: SELL_CLOSE_LONG 1.30 @ 101835.67 | PnL: -4038.49 | Capital: 147404.97 | Reason: Prediction below short threshold (close long)
# 2025-01-29 05:08:33.887000: SELL_SHORT_OPEN -1.30 @ 102151.74 (Prob: 0.3658) | Capital: 147404.97
# 2025-02-03 00:46:52.878000: BUY_TO_COVER_SHORT 1.30 @ 96516.51 | PnL: 7252.17 | Capital: 154657.14 | Reason: Prediction above long threshold (close short)
# 2025-02-03 00:47:32.942000: BUY_OPEN 1.45 @ 96217.30 (Prob: -0.3625) | Capital: 154657.14
# 2025-02-03 17:54:19.024000: SELL_CLOSE_LONG 1.45 @ 98983.46 | PnL: 3928.06 | Capital: 158585.20 | Reason: Prediction below short threshold (close long)
# 2025-02-03 17:55:28.990000: SELL_SHORT_OPEN -1.45 @ 98676.58 (Prob: 0.3655) | Capital: 158585.20
# 2025-02-06 18:34:26.787000: BUY_TO_COVER_SHORT 1.45 @ 96299.06 | PnL: 3367.53 | Capital: 161952.74 | Reason: Prediction above long threshold (close short)
# 2025-02-06 18:49:32.860000: BUY_OPEN 1.51 @ 96598.17 (Prob: -0.3616) | Capital: 161952.74
# 2025-02-14 14:39:16.539000: SELL_CLOSE_LONG 1.51 @ 97087.29 | PnL: 664.46 | Capital: 162617.19 | Reason: Prediction below short threshold (close long)
# 2025-02-14 14:53:10.720000: SELL_SHORT_OPEN -1.50 @ 97388.38 (Prob: 0.3553) | Capital: 162617.19
# 2025-02-25 07:35:04.352000: BUY_TO_COVER_SHORT 1.50 @ 88757.99 | PnL: 12896.63 | Capital: 175513.82 | Reason: Prediction above long threshold (close short)
# 2025-02-25 07:35:14.007000: BUY_OPEN 1.78 @ 88482.69 (Prob: -0.3639) | Capital: 175513.82
# 2025-02-26 15:28:27.545000: SELL_CLOSE_LONG 1.78 @ 87735.14 | PnL: -1412.16 | Capital: 174101.66 | Reason: Prediction below short threshold (close long)
# 2025-02-26 15:38:05.047000: SELL_SHORT_OPEN -1.78 @ 88007.45 (Prob: 0.3656) | Capital: 174101.66
# 2025-03-03 14:56:34.208000: BUY_TO_COVER_SHORT 1.78 @ 89679.23 | PnL: -3054.80 | Capital: 171046.86 | Reason: Prediction above long threshold (close short)
# 2025-03-03 14:57:25.608000: BUY_OPEN 1.72 @ 89401.14 (Prob: -0.3649) | Capital: 171046.86
# 2025-03-04 16:14:21.032000: SELL_CLOSE_LONG 1.72 @ 82898.43 | PnL: -11262.92 | Capital: 159783.94 | Reason: Prediction below short threshold (close long)
# 2025-03-04 16:17:05.877000: SELL_SHORT_OPEN -1.74 @ 82641.41 (Prob: 0.3630) | Capital: 159783.94
# 2025-03-07 00:25:25.935000: BUY_TO_COVER_SHORT 1.74 @ 87185.99 | PnL: -7979.95 | Capital: 151803.98 | Reason: Prediction above long threshold (close short)
# 2025-03-07 00:25:41.346000: BUY_OPEN 1.57 @ 86915.70 (Prob: -0.3597) | Capital: 151803.98
# 2025-03-10 00:21:15.587000: SELL_CLOSE_LONG 1.57 @ 80382.69 | PnL: -10327.31 | Capital: 141476.68 | Reason: Prediction below short threshold (close long)
# 2025-03-10 00:24:08.775000: SELL_SHORT_OPEN -1.58 @ 80632.32 (Prob: 0.3600) | Capital: 141476.68
# 2025-03-14 14:08:12.322000: BUY_TO_COVER_SHORT 1.58 @ 83166.98 | PnL: -4066.19 | Capital: 137410.49 | Reason: Prediction above long threshold (close short)
# 2025-03-14 14:10:14.700000: BUY_OPEN 1.48 @ 83424.86 (Prob: -0.3588) | Capital: 137410.49
# 2025-03-23 17:19:27.131000: SELL_CLOSE_LONG 1.48 @ 85315.14 | PnL: 2737.56 | Capital: 140148.05 | Reason: Prediction below short threshold (close long)
# 2025-03-23 17:32:31.067000: SELL_SHORT_OPEN -1.48 @ 85050.42 (Prob: 0.3621) | Capital: 140148.05
# 2025-03-31 03:30:45.550000: BUY_TO_COVER_SHORT 1.48 @ 81896.69 | PnL: 4614.08 | Capital: 144762.13 | Reason: Prediction above long threshold (close short)
# 2025-03-31 03:48:20.372000: BUY_OPEN 1.60 @ 81642.71 (Prob: -0.3591) | Capital: 144762.13
# 2025-04-02 20:28:09.999000: SELL_CLOSE_LONG 1.60 @ 85251.28 | PnL: 5687.71 | Capital: 150449.84 | Reason: Prediction below short threshold (close long)
# 2025-04-02 20:28:11.587000: SELL_SHORT_OPEN -1.58 @ 85517.10 (Prob: 0.3610) | Capital: 150449.84
# 2025-04-07 05:05:31.040000: BUY_TO_COVER_SHORT 1.58 @ 76738.08 | PnL: 13832.73 | Capital: 164282.57 | Reason: Prediction above long threshold (close short)
# 2025-04-07 05:09:10.124000: BUY_OPEN 1.92 @ 76976.15 (Prob: -0.3556) | Capital: 164282.57
# 2025-04-07 14:32:48.743000: SELL_CLOSE_LONG 1.92 @ 78733.85 | PnL: 3298.90 | Capital: 167581.47 | Reason: Prediction below short threshold (close long)
# 2025-04-07 14:33:33.700000: SELL_SHORT_OPEN -1.91 @ 78977.98 (Prob: 0.3528) | Capital: 167581.47
# 2025-04-09 05:28:40.627000: BUY_TO_COVER_SHORT 1.91 @ 76806.73 | PnL: 4071.04 | Capital: 171652.50 | Reason: Prediction above long threshold (close short)
# 2025-04-09 05:31:56.146000: BUY_OPEN 2.02 @ 76568.56 (Prob: -0.3585) | Capital: 171652.50
# 2025-04-23 00:02:51.002000: SELL_CLOSE_LONG 2.02 @ 93629.11 | PnL: 34310.33 | Capital: 205962.83 | Reason: Prediction below short threshold (close long)
# 2025-04-23 00:11:03.558000: SELL_SHORT_OPEN -1.98 @ 93338.52 (Prob: 0.3598) | Capital: 205962.83
# 2025-05-01 13:20:41.115000: BUY_TO_COVER_SHORT 1.98 @ 96551.44 | PnL: -6473.37 | Capital: 199489.46 | Reason: Prediction above long threshold (close short)
# 2025-05-01 13:35:43.870000: BUY_OPEN 1.86 @ 96252.03 (Prob: -0.3600) | Capital: 199489.46
# 2025-06-12 14:07:17.206000: SELL_CLOSE_LONG 1.86 @ 107179.32 | PnL: 20272.76 | Capital: 219762.22 | Reason: Prediction below short threshold (close long)
# 2025-06-12 14:37:19.584000: SELL_SHORT_OPEN -1.84 @ 107511.59 (Prob: 0.3628) | Capital: 219762.22
# 2025-06-22 16:25:01.034000: BUY_TO_COVER_SHORT 1.84 @ 98701.04 | PnL: 16109.67 | Capital: 235871.89 | Reason: Prediction above long threshold (close short)
# 2025-06-22 16:36:27.288000: BUY_OPEN 2.14 @ 99007.26 (Prob: -0.3600) | Capital: 235871.89
# 2025-08-01 22:06:33.135000: SELL_CLOSE_LONG 2.14 @ 113452.33 | PnL: 30835.10 | Capital: 266706.99 | Reason: Prediction below short threshold (close long)
# 2025-08-01 22:27:50.519000: SELL_SHORT_OPEN -2.12 @ 113100.47 (Prob: 0.3604) | Capital: 266706.99
# 2025-08-19 10:08:17.693000: BUY_TO_COVER_SHORT 2.12 @ 115537.12 | PnL: -5291.32 | Capital: 261415.67 | Reason: Prediction above long threshold (close short)
# 2025-08-19 13:30:52.100000: BUY_OPEN 2.03 @ 115895.47 (Prob: -0.3575) | Capital: 261415.67
# End of Backtest: SELL_FINAL_LONG 2.03 @ 112451.63 | PnL: -7101.78 | Capital: 261415.67
#
# ============================================================
# Backtesting Results Summary (Long-Short Strategy):
# Initial Capital: 100000.00
# Final Capital: 261415.67
# Total Return: 161.42%
# Total Realized PnL: 154313.90
# 年化收益 (近似): 130.59%
# Maximum Drawdown: -29.99%
# Sharpe Ratio (Risk-Free Rate = 0): 502.25
# Number of Trades: 110
# Win Rate: 60.00%
# ============================================================
# reverse no ma

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

all_predictions_df = a_df.to_pandas()
all_predictions_df['timestamp'] = pd.to_datetime(all_predictions_df['timestamp'], unit='us') # Assuming microseconds
all_predictions_df['ma'] = all_predictions_df['px'].rolling(window=200).mean()


symbol_to_backtest = "tst"
df = all_predictions_df.copy()
df = df.sort_values('timestamp').reset_index(drop=True)

# ===============================================
# Backtesting Parameters (Ratios for costs)
# ===============================================
initial_capital = 100000  # Initial capital
commission_ratio = 0.0005 # Commission ratio (e.0.05%)
slippage_ratio = 0.0007   # Slippage ratio (e.g., 0.02%)

trade_size_ratio = 0.9    # Percentage of current equity to allocate per trade

# Strategy Thresholds (needs optimization)
long_threshold = up_thres # Predicted probability above this to go long (buy)
short_threshold = dn_thres # Predicted probability below this to go short (sell)

beta = 4


# Dynamic Take Profit / Stop Loss (in multiples of rolling_std/px)
long_stop_loss_multiplier = beta
long_take_profit_multiplier = beta
short_stop_loss_multiplier = beta
short_take_profit_multiplier = beta

# ===============================================
# Backtesting Main Logic (No change here from previous version)
# ===============================================

# Initialize account state
capital = initial_capital
position = 0          # Position size (positive for long, negative for short, 0 for flat)
entry_price = 0       # Entry price for current position
realized_pnl = 0      # Realized PnL from closed trades
equity_curve = [initial_capital] # Equity curve
unrealized_pnl_series = [0]

# Record trades
trades = []

for i in range(len(df)):
    current_time = df['timestamp'].iloc[i]
    current_px = df['px'].iloc[i]
    predicted_prob = df[feat].iloc[i]
    current_rolling_std = df['rolling_std'].iloc[i]
    ma = df['ma'].iloc[i]

    # Calculate current total equity (capital + market value of position)
    if position > 0: # Long position
        unrealized_pnl = (current_px - entry_price) * position
    elif position < 0: # Short position
        unrealized_pnl = (entry_price - current_px) * abs(position) # Profit when price falls
    else: # Flat
        unrealized_pnl = 0

    current_equity = capital + unrealized_pnl
    equity_curve.append(current_equity)
    unrealized_pnl_series.append(unrealized_pnl)

    # -----------------------------------------------
    # Strategy Execution - Long-Short
    # -----------------------------------------------

    # Scenario 1: Currently FLAT (position == 0)
    if position == 0:
        if predicted_prob >= long_threshold and current_px > ma: # Go Long Signal
            trade_type = 'BUY_OPEN'
            trade_price = current_px * (1 + slippage_ratio)
            num_shares = (current_equity * trade_size_ratio) / (trade_price * (1 + commission_ratio))

            if num_shares > 0:
                position = num_shares
                entry_price = trade_price
                # capital -= (position * entry_price * (1 + commission_ratio))

                trades.append({
                    'timestamp': current_time, 'type': trade_type, 'price': entry_price, 'shares': position,
                    'capital_after_trade': capital, 'equity_after_trade': current_equity, 'predicted_prob': predicted_prob
                })
                # print(f"{current_time}: {trade_type} {position:.2f} @ {entry_price:.2f} (Prob: {predicted_prob:.4f}) | Capital: {capital:.2f}")

        elif predicted_prob <= short_threshold and current_px < ma: # Go Short Signal
            trade_type = 'SELL_SHORT_OPEN'
            trade_price = current_px * (1 - slippage_ratio) # Price for short is lower (sell at market)
            num_shares = (current_equity * trade_size_ratio) / (trade_price * (1 + commission_ratio))

            if num_shares > 0:
                position = -num_shares # Negative for short position
                entry_price = trade_price
                # capital -= (abs(position) * entry_price * (1 + commission_ratio))

                trades.append({
                    'timestamp': current_time, 'type': trade_type, 'price': entry_price, 'shares': position,
                    'capital_after_trade': capital, 'equity_after_trade': current_equity, 'predicted_prob': predicted_prob
                })
                # print(f"{current_time}: {trade_type} {position:.2f} @ {entry_price:.2f} (Prob: {predicted_prob:.4f}) | Capital: {capital:.2f}")

    # Scenario 2: Currently LONG (position > 0)
    elif position > 0:
        sl_price = entry_price - long_stop_loss_multiplier * current_rolling_std
        tp_price = entry_price + long_take_profit_multiplier * current_rolling_std

        should_close = False
        reason = ""

        if predicted_prob < short_threshold: # Changed from sell_threshold to short_threshold for consistent logic
            should_close = True
            reason = "Prediction below short threshold (close long)"
        # if current_px <= sl_price:
        #     should_close = True
        #     reason = "Long Stop Loss Hit"
        # elif current_px >= tp_price and predicted_prob < long_threshold:
        #     should_close = True
        #     reason = "Long Take Profit Hit"

        if should_close:
            trade_type = 'SELL_CLOSE_LONG'
            close_price = current_px * (1 - slippage_ratio)
            gross_pnl_on_trade = (close_price - entry_price) * position
            net_pnl_on_trade = gross_pnl_on_trade - (close_price * position * commission_ratio)

            realized_pnl += net_pnl_on_trade
            capital += net_pnl_on_trade

            trades.append({
                'timestamp': current_time, 'type': trade_type, 'price': close_price, 'shares': position,
                'pnl': net_pnl_on_trade, 'capital_after_trade': capital, 'equity_after_trade': current_equity,
                'reason': reason, 'predicted_prob': predicted_prob
            })
            # print(f"{current_time}: {trade_type} {position:.2f} @ {close_price:.2f} | PnL: {net_pnl_on_trade:.2f} | Capital: {capital:.2f} | Reason: {reason}")

            position = 0
            entry_price = 0


    # Scenario 3: Currently SHORT (position < 0)
    elif position < 0:
        sl_price = entry_price + long_stop_loss_multiplier * current_rolling_std
        tp_price = entry_price - long_take_profit_multiplier * current_rolling_std

        should_close = False
        reason = ""

        if predicted_prob >= long_threshold: # Changed from buy_threshold to long_threshold
            should_close = True
            reason = "Prediction above long threshold (close short)"
        # if current_px >= sl_price:
        #     should_close = True
        #     reason = "Short Stop Loss Hit"
        # elif current_px <= tp_price and predicted_prob > short_threshold:
        #     should_close = True
        #     reason = "Short Take Profit Hit"

        if should_close:
            trade_type = 'BUY_TO_COVER_SHORT'
            close_price = current_px * (1 + slippage_ratio)
            gross_pnl_on_trade = (entry_price - close_price) * abs(position)
            net_pnl_on_trade = gross_pnl_on_trade - (close_price * abs(position) * commission_ratio)

            realized_pnl += net_pnl_on_trade
            capital += net_pnl_on_trade

            trades.append({
                'timestamp': current_time, 'type': trade_type, 'price': close_price, 'shares': position,
                'pnl': net_pnl_on_trade, 'capital_after_trade': capital, 'equity_after_trade': current_equity,
                'reason': reason, 'predicted_prob': predicted_prob
            })
            # print(f"{current_time}: {trade_type} {abs(position):.2f} @ {close_price:.2f} | PnL: {net_pnl_on_trade:.2f} | Capital: {capital:.2f} | Reason: {reason}")

            position = 0
            entry_price = 0

# Final close-out at the end of backtest if any position is open
final_equity_append_time = df['timestamp'].iloc[-1] + pd.Timedelta(seconds=1)
if position != 0:
    last_px = df['px'].iloc[-1]
    if position > 0: # Close long
        final_close_price = last_px * (1 - slippage_ratio)
        gross_pnl_on_trade = (final_close_price - entry_price) * position
        net_pnl_on_trade = gross_pnl_on_trade - (final_close_price * position * commission_ratio)
        # capital += (position * final_close_price * (1 - commission_ratio))
        trades.append({
            'timestamp': final_equity_append_time, 'type': 'SELL_FINAL_LONG', 'price': final_close_price, 'shares': position,
            'pnl': net_pnl_on_trade, 'capital_after_trade': capital, 'equity_after_trade': equity_curve[-1],
            'reason': 'End of Backtest', 'predicted_prob': df[feat].iloc[-1]
        })
        # print(f"End of Backtest: SELL_FINAL_LONG {position:.2f} @ {final_close_price:.2f} | PnL: {net_pnl_on_trade:.2f} | Capital: {capital:.2f}")
    else: # Close short
        final_close_price = last_px * (1 + slippage_ratio)
        gross_pnl_on_trade = (entry_price - final_close_price) * abs(position)
        net_pnl_on_trade = gross_pnl_on_trade - (final_close_price * abs(position) * commission_ratio)
        # capital += (abs(position) * entry_price * (1 - commission_ratio))
        trades.append({
            'timestamp': final_equity_append_time, 'type': 'BUY_FINAL_SHORT', 'price': final_close_price, 'shares': position,
            'pnl': net_pnl_on_trade, 'capital_after_trade': capital, 'equity_after_trade': equity_curve[-1],
            'reason': 'End of Backtest', 'predicted_prob': df[feat].iloc[-1]
        })
        # print(f"End of Backtest: BUY_FINAL_SHORT {abs(position):.2f} @ {final_close_price:.2f} | PnL: {net_pnl_on_trade:.2f} | Capital: {capital:.2f}")
    realized_pnl += net_pnl_on_trade
    position = 0

# Final equity curve update
equity_curve[-1] = capital
unrealized_pnl_series[-1] = 0
# ===============================================
# Performance Metrics Calculation (KEY CHANGES HERE)
# ===============================================
equity_series = pd.Series(equity_curve, index=df['timestamp'].tolist() + [final_equity_append_time])
returns = equity_series.pct_change().dropna()
unrealized_pnl_series = pd.Series(unrealized_pnl_series, index=equity_series.index)

# Total Return
total_return = (capital - initial_capital) / initial_capital

# Annualized Return - Based on Total Duration
annualized_return = total_return # Default value if not enough data

if len(df) > 1:
    # Get the total duration of the backtest data
    total_duration = df['timestamp'].iloc[-1] - df['timestamp'].iloc[0]
    total_duration_seconds = total_duration.total_seconds()

    if total_duration_seconds > 0:
        # Number of seconds in a year
        seconds_in_year = 365 * 24 * 60 * 60

        # Annualization factor: (seconds in a year) / (total seconds in backtest)
        annualization_factor = seconds_in_year / total_duration_seconds

        # Apply annualization
        annualized_return = (1 + total_return)**annualization_factor - 1
    else:
        print("Warning: Total backtest duration is zero or invalid, cannot annualize return.")
else:
    print("Warning: Not enough data points to calculate total duration for annualization.")


# Max Drawdown
peak = equity_series.expanding(min_periods=1).max()
drawdown = (equity_series - peak) / peak
max_drawdown = drawdown.min()

# Sharpe Ratio (assuming risk-free rate is 0)
# For volatility, we use returns.std() and annualize it with the same factor
annualized_volatility = returns.std() * np.sqrt(annualization_factor) if 'annualization_factor' in locals() and annualization_factor > 0 else returns.std()
sharpe_ratio = annualized_return / annualized_volatility if annualized_volatility != 0 else np.nan

# Win Rate for closed trades
if len(trades) > 0:
    winning_trades = sum(1 for t in trades if 'pnl' in t and t['pnl'] > 0)
    total_closed_trades = sum(1 for t in trades if 'pnl' in t)
    win_rate = winning_trades / total_closed_trades if total_closed_trades > 0 else 0
else:
    win_rate = 0


print("\n" + "="*60)
print("Backtesting Results Summary (Long-Short Strategy):")
print(f"Initial Capital: {initial_capital:.2f}")
print(f"Final Capital: {capital:.2f}")
print(f"Total Return: {total_return:.2%}")
print(f"Total Realized PnL: {realized_pnl:.2f}")
print(f"年化收益 (近似): {annualized_return:.2%}")
print(f"Maximum Drawdown: {max_drawdown:.2%}")
print(f"Sharpe Ratio (Risk-Free Rate = 0): {sharpe_ratio:.2f}")
print(f"Number of Trades: {len(trades)}")
print(f"Win Rate: {win_rate:.2%}")
print("="*60)
print("tred ma")
# ===============================================
# Plotting
# ===============================================

# Equity Curve
plt.figure(figsize=(12, 6))
plt.plot(equity_series.index, equity_series, label='Equity Curve')
plt.title(f'{symbol_to_backtest} Long-Short Strategy Equity Curve')
plt.xlabel('Timestamp')
plt.ylabel('Equity')
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# Returns Distribution
if not returns.empty:
    plt.figure(figsize=(10, 5))
    sns.histplot(returns, kde=True, bins=50)
    plt.title(f'{symbol_to_backtest} Returns Distribution')
    plt.xlabel('Return')
    plt.ylabel('Frequency')
    plt.grid(True)
    plt.tight_layout()
    plt.show()

# Drawdown Plot
if not drawdown.empty:
    plt.figure(figsize=(12, 6))
    plt.plot(drawdown.index, drawdown, label='Drawdown')
    plt.fill_between(drawdown.index, drawdown, 0, where=(drawdown < 0), color='red', alpha=0.3)
    plt.title(f'{symbol_to_backtest} Drawdown')
    plt.xlabel('Timestamp')
    plt.ylabel('Drawdown (%)')
    plt.grid(True)
    plt.legend()
    plt.tight_layout()
    plt.show()


# plt.figure(figsize=(12, 6))
# plt.plot(unrealized_pnl_series.index, unrealized_pnl_series, label="Unrealized PnL")
# plt.axhline(0, color='gray', linestyle='--')
# plt.title(f"{symbol_to_backtest} 浮动盈亏 (Unrealized PnL)")
# plt.xlabel("Timestamp")
# plt.ylabel("Unrealized PnL")
# plt.grid(True)
# plt.legend()
# plt.tight_layout()
# plt.show()
# Out:
# ============================================================
# Backtesting Results Summary (Long-Short Strategy):
# Initial Capital: 100000.00
# Final Capital: 18966.25
# Total Return: -81.03%
# Total Realized PnL: -80581.49
# 年化收益 (近似): -76.44%
# Maximum Drawdown: -83.36%
# Sharpe Ratio (Risk-Free Rate = 0): -281.99
# Number of Trades: 108
# Win Rate: 33.33%
# ============================================================
# tred ma

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

all_predictions_df = a_df.to_pandas()
all_predictions_df['timestamp'] = pd.to_datetime(all_predictions_df['timestamp'], unit='us') # Assuming microseconds
all_predictions_df['ma'] = all_predictions_df['px'].rolling(window=500).mean()


symbol_to_backtest = "tst"
df = all_predictions_df.copy()
df = df.sort_values('timestamp').reset_index(drop=True)

# ===============================================
# Backtesting Parameters (Ratios for costs)
# ===============================================
initial_capital = 100000  # Initial capital
commission_ratio = 0.0005 # Commission ratio (e.0.05%)
slippage_ratio = 0.001   # Slippage ratio (e.g., 0.02%)

trade_size_ratio = 0.9    # Percentage of current equity to allocate per trade

# Strategy Thresholds (needs optimization)
long_threshold = up_thres # Predicted probability above this to go long (buy)
short_threshold = dn_thres # Predicted probability below this to go short (sell)

beta = 2


# Dynamic Take Profit / Stop Loss (in multiples of rolling_std/px)
long_stop_loss_multiplier = beta
long_take_profit_multiplier = beta
short_stop_loss_multiplier = beta
short_take_profit_multiplier = beta

# ===============================================
# Backtesting Main Logic (No change here from previous version)
# ===============================================

# Initialize account state
capital = initial_capital
position = 0          # Position size (positive for long, negative for short, 0 for flat)
entry_price = 0       # Entry price for current position
realized_pnl = 0      # Realized PnL from closed trades
equity_curve = [initial_capital] # Equity curve
unrealized_pnl_series = [0]

# Record trades
trades = []

for i in range(len(df)):
    current_time = df['timestamp'].iloc[i]
    current_px = df['px'].iloc[i]
    predicted_prob = df[feat].iloc[i]
    current_rolling_std = df['rolling_std'].iloc[i]
    ma = df['ma'].iloc[i]

    # Calculate current total equity (capital + market value of position)
    if position > 0: # Long position
        unrealized_pnl = (current_px - entry_price) * position
    elif position < 0: # Short position
        unrealized_pnl = (entry_price - current_px) * abs(position) # Profit when price falls
    else: # Flat
        unrealized_pnl = 0

    current_equity = capital + unrealized_pnl
    equity_curve.append(current_equity)
    unrealized_pnl_series.append(unrealized_pnl)

    # -----------------------------------------------
    # Strategy Execution - Long-Short
    # -----------------------------------------------

    # Scenario 1: Currently FLAT (position == 0)
    if position == 0:
        if predicted_prob <= short_threshold and current_px < ma: # Go Long Signal
            trade_type = 'BUY_OPEN'
            trade_price = current_px * (1 + slippage_ratio)
            num_shares = (current_equity * trade_size_ratio) / (trade_price * (1 + commission_ratio))

            if num_shares > 0:
                position = num_shares
                entry_price = trade_price
                # capital -= (position * entry_price * (1 + commission_ratio))

                trades.append({
                    'timestamp': current_time, 'type': trade_type, 'price': entry_price, 'shares': position,
                    'capital_after_trade': capital, 'equity_after_trade': current_equity, 'predicted_prob': predicted_prob
                })
                print(f"{current_time}: {trade_type} {position:.2f} @ {entry_price:.2f} (Prob: {predicted_prob:.4f}) | Capital: {capital:.2f}")
                print(i, current_px, ma)

        elif predicted_prob >= long_threshold and current_px > ma: # Go Short Signal
            trade_type = 'SELL_SHORT_OPEN'
            trade_price = current_px * (1 - slippage_ratio) # Price for short is lower (sell at market)
            num_shares = (current_equity * trade_size_ratio) / (trade_price * (1 + commission_ratio))

            if num_shares > 0:
                position = -num_shares # Negative for short position
                entry_price = trade_price
                # capital -= (abs(position) * entry_price * (1 + commission_ratio))

                trades.append({
                    'timestamp': current_time, 'type': trade_type, 'price': entry_price, 'shares': position,
                    'capital_after_trade': capital, 'equity_after_trade': current_equity, 'predicted_prob': predicted_prob
                })
                print(f"{current_time}: {trade_type} {position:.2f} @ {entry_price:.2f} (Prob: {predicted_prob:.4f}) | Capital: {capital:.2f}")
                print(i, current_px, ma)


    # Scenario 2: Currently LONG (position > 0)
    elif position > 0:
        sl_price = entry_price - long_stop_loss_multiplier * current_rolling_std
        tp_price = entry_price + long_take_profit_multiplier * current_rolling_std

        should_close = False
        reason = ""

        if predicted_prob >= long_threshold: # Changed from sell_threshold to short_threshold for consistent logic
            should_close = True
            reason = "Prediction below short threshold (close long)"
        # if current_px <= sl_price:
        #     should_close = True
        #     reason = "Long Stop Loss Hit"
        # elif current_px >= tp_price and predicted_prob > short_threshold:
        #     should_close = True
        #     reason = "Long Take Profit Hit"

        if should_close:
            trade_type = 'SELL_CLOSE_LONG'
            close_price = current_px * (1 - slippage_ratio)
            gross_pnl_on_trade = (close_price - entry_price) * position
            net_pnl_on_trade = gross_pnl_on_trade - (close_price * position * commission_ratio)

            realized_pnl += net_pnl_on_trade
            capital += net_pnl_on_trade

            trades.append({
                'timestamp': current_time, 'type': trade_type, 'price': close_price, 'shares': position,
                'pnl': net_pnl_on_trade, 'capital_after_trade': capital, 'equity_after_trade': current_equity,
                'reason': reason, 'predicted_prob': predicted_prob
            })
            print(f"{current_time}: {trade_type} {position:.2f} @ {close_price:.2f} | PnL: {net_pnl_on_trade:.2f} | Capital: {capital:.2f} | Reason: {reason}")
            print(i)

            position = 0
            entry_price = 0


    # Scenario 3: Currently SHORT (position < 0)
    elif position < 0:
        sl_price = entry_price + long_stop_loss_multiplier * current_rolling_std
        tp_price = entry_price - long_take_profit_multiplier * current_rolling_std

        should_close = False
        reason = ""

        if predicted_prob <= short_threshold: # Changed from buy_threshold to long_threshold
            should_close = True
            reason = "Prediction above long threshold (close short)"
        # if current_px >= sl_price:
        #     should_close = True
        #     reason = "Short Stop Loss Hit"
        # elif current_px <= tp_price and predicted_prob < long_threshold:
        #     should_close = True
        #     reason = "Short Take Profit Hit"

        if should_close:
            trade_type = 'BUY_TO_COVER_SHORT'
            close_price = current_px * (1 + slippage_ratio)
            gross_pnl_on_trade = (entry_price - close_price) * abs(position)
            net_pnl_on_trade = gross_pnl_on_trade - (close_price * abs(position) * commission_ratio)

            realized_pnl += net_pnl_on_trade
            capital += net_pnl_on_trade

            trades.append({
                'timestamp': current_time, 'type': trade_type, 'price': close_price, 'shares': position,
                'pnl': net_pnl_on_trade, 'capital_after_trade': capital, 'equity_after_trade': current_equity,
                'reason': reason, 'predicted_prob': predicted_prob
            })
            print(f"{current_time}: {trade_type} {abs(position):.2f} @ {close_price:.2f} | PnL: {net_pnl_on_trade:.2f} | Capital: {capital:.2f} | Reason: {reason}")
            print(i)

            position = 0
            entry_price = 0

# Final close-out at the end of backtest if any position is open
final_equity_append_time = df['timestamp'].iloc[-1] + pd.Timedelta(seconds=1)
if position != 0:
    last_px = df['px'].iloc[-1]
    if position > 0: # Close long
        final_close_price = last_px * (1 - slippage_ratio)
        gross_pnl_on_trade = (final_close_price - entry_price) * position
        net_pnl_on_trade = gross_pnl_on_trade - (final_close_price * position * commission_ratio)
        # capital += (position * final_close_price * (1 - commission_ratio))
        trades.append({
            'timestamp': final_equity_append_time, 'type': 'SELL_FINAL_LONG', 'price': final_close_price, 'shares': position,
            'pnl': net_pnl_on_trade, 'capital_after_trade': capital, 'equity_after_trade': equity_curve[-1],
            'reason': 'End of Backtest', 'predicted_prob': df[feat].iloc[-1]
        })
        print(f"End of Backtest: SELL_FINAL_LONG {position:.2f} @ {final_close_price:.2f} | PnL: {net_pnl_on_trade:.2f} | Capital: {capital:.2f}")
    else: # Close short
        final_close_price = last_px * (1 + slippage_ratio)
        gross_pnl_on_trade = (entry_price - final_close_price) * abs(position)
        net_pnl_on_trade = gross_pnl_on_trade - (final_close_price * abs(position) * commission_ratio)
        # capital += (abs(position) * entry_price * (1 - commission_ratio))
        trades.append({
            'timestamp': final_equity_append_time, 'type': 'BUY_FINAL_SHORT', 'price': final_close_price, 'shares': position,
            'pnl': net_pnl_on_trade, 'capital_after_trade': capital, 'equity_after_trade': equity_curve[-1],
            'reason': 'End of Backtest', 'predicted_prob': df[feat].iloc[-1]
        })
        print(f"End of Backtest: BUY_FINAL_SHORT {abs(position):.2f} @ {final_close_price:.2f} | PnL: {net_pnl_on_trade:.2f} | Capital: {capital:.2f}")
    realized_pnl += net_pnl_on_trade
    position = 0

# Final equity curve update
equity_curve[-1] = capital
unrealized_pnl_series[-1] = 0
# ===============================================
# Performance Metrics Calculation (KEY CHANGES HERE)
# ===============================================
equity_series = pd.Series(equity_curve, index=df['timestamp'].tolist() + [final_equity_append_time])
returns = equity_series.pct_change().dropna()
unrealized_pnl_series = pd.Series(unrealized_pnl_series, index=equity_series.index)

# Total Return
total_return = (capital - initial_capital) / initial_capital

# Annualized Return - Based on Total Duration
annualized_return = total_return # Default value if not enough data

if len(df) > 1:
    # Get the total duration of the backtest data
    total_duration = df['timestamp'].iloc[-1] - df['timestamp'].iloc[0]
    total_duration_seconds = total_duration.total_seconds()

    if total_duration_seconds > 0:
        # Number of seconds in a year
        seconds_in_year = 365 * 24 * 60 * 60

        # Annualization factor: (seconds in a year) / (total seconds in backtest)
        annualization_factor = seconds_in_year / total_duration_seconds

        # Apply annualization
        annualized_return = (1 + total_return)**annualization_factor - 1
    else:
        print("Warning: Total backtest duration is zero or invalid, cannot annualize return.")
else:
    print("Warning: Not enough data points to calculate total duration for annualization.")


# Max Drawdown
peak = equity_series.expanding(min_periods=1).max()
drawdown = (equity_series - peak) / peak
max_drawdown = drawdown.min()

# Sharpe Ratio (assuming risk-free rate is 0)
# For volatility, we use returns.std() and annualize it with the same factor
annualized_volatility = returns.std() * np.sqrt(annualization_factor) if 'annualization_factor' in locals() and annualization_factor > 0 else returns.std()
sharpe_ratio = annualized_return / annualized_volatility if annualized_volatility != 0 else np.nan

# Win Rate for closed trades
if len(trades) > 0:
    winning_trades = sum(1 for t in trades if 'pnl' in t and t['pnl'] > 0)
    total_closed_trades = sum(1 for t in trades if 'pnl' in t)
    win_rate = winning_trades / total_closed_trades if total_closed_trades > 0 else 0
else:
    win_rate = 0


print("\n" + "="*60)
print("Backtesting Results Summary (Long-Short Strategy):")
print(f"Initial Capital: {initial_capital:.2f}")
print(f"Final Capital: {capital:.2f}")
print(f"Total Return: {total_return:.2%}")
print(f"Total Realized PnL: {realized_pnl:.2f}")
print(f"年化收益 (近似): {annualized_return:.2%}")
print(f"Maximum Drawdown: {max_drawdown:.2%}")
print(f"Sharpe Ratio (Risk-Free Rate = 0): {sharpe_ratio:.2f}")
print(f"Number of Trades: {len(trades)}")
print(f"Win Rate: {win_rate:.2%}")
print("="*60)
print("reverse ma")

# ===============================================
# Plotting
# ===============================================

# Equity Curve
plt.figure(figsize=(12, 6))
plt.plot(equity_series.index, equity_series, label='Equity Curve')
plt.title(f'{symbol_to_backtest} Long-Short Strategy Equity Curve')
plt.xlabel('Timestamp')
plt.ylabel('Equity')
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# Returns Distribution
if not returns.empty:
    plt.figure(figsize=(10, 5))
    sns.histplot(returns, kde=True, bins=50)
    plt.title(f'{symbol_to_backtest} Returns Distribution')
    plt.xlabel('Return')
    plt.ylabel('Frequency')
    plt.grid(True)
    plt.tight_layout()
    plt.show()

# Drawdown Plot
if not drawdown.empty:
    plt.figure(figsize=(12, 6))
    plt.plot(drawdown.index, drawdown, label='Drawdown')
    plt.fill_between(drawdown.index, drawdown, 0, where=(drawdown < 0), color='red', alpha=0.3)
    plt.title(f'{symbol_to_backtest} Drawdown')
    plt.xlabel('Timestamp')
    plt.ylabel('Drawdown (%)')
    plt.grid(True)
    plt.legend()
    plt.tight_layout()
    plt.show()


# plt.figure(figsize=(12, 6))
# plt.plot(unrealized_pnl_series.index, unrealized_pnl_series, label="Unrealized PnL")
# plt.axhline(0, color='gray', linestyle='--')
# plt.title(f"{symbol_to_backtest} 浮动盈亏 (Unrealized PnL)")
# plt.xlabel("Timestamp")
# plt.ylabel("Unrealized PnL")
# plt.grid(True)
# plt.legend()
# plt.tight_layout()
# plt.show()
# Out:
# 2024-07-06 15:31:56.776000: SELL_SHORT_OPEN -1.57 @ 57246.10 (Prob: 0.3773) | Capital: 100000.00
# 540 57303.4 57161.77952
# 2024-07-09 17:02:10.699000: BUY_TO_COVER_SHORT 1.57 @ 57790.43 | PnL: -900.76 | Capital: 99099.24 | Reason: Prediction above long threshold (close short)
# 883
# 2024-07-12 12:30:45.848000: BUY_OPEN 1.56 @ 57187.23 (Prob: -0.3554) | Capital: 99099.24
# 1132 57130.1 57276.9934
# 2024-07-27 19:41:19.739000: SELL_CLOSE_LONG 1.56 @ 67803.13 | PnL: 16495.46 | Capital: 115594.70 | Reason: Prediction below short threshold (close long)
# 2015
# 2024-07-27 19:47:30.600000: SELL_SHORT_OPEN -1.53 @ 68013.52 (Prob: 0.3543) | Capital: 115594.70
# 2016 68081.6 66210.188
# 2024-08-05 22:07:10.062000: BUY_TO_COVER_SHORT 1.53 @ 54757.40 | PnL: 20224.90 | Capital: 135819.60 | Reason: Prediction above long threshold (close short)
# 3788
# 2024-08-07 14:45:34.513000: SELL_SHORT_OPEN -2.19 @ 55914.03 (Prob: 0.3556) | Capital: 135819.60
# 4170 55970.0 55457.481759999995
# 2024-08-11 12:16:46.719000: BUY_TO_COVER_SHORT 2.19 @ 60439.18 | PnL: -9953.84 | Capital: 125865.76 | Reason: Prediction above long threshold (close short)
# 4643
# 2024-08-11 20:08:03.109000: BUY_OPEN 1.92 @ 58949.79 (Prob: -0.5931) | Capital: 125865.76
# 4671 58890.9 58912.808600000004
# 2024-08-14 12:30:24.664000: SELL_CLOSE_LONG 1.92 @ 61619.32 | PnL: 5068.08 | Capital: 130933.84 | Reason: Prediction below short threshold (close long)
# 4994
# 2024-08-14 12:30:37.066000: SELL_SHORT_OPEN -1.92 @ 61428.21 (Prob: 0.3565) | Capital: 130933.84
# 4995 61489.7 59777.8836
# 2024-08-27 00:51:30.311000: BUY_TO_COVER_SHORT 1.92 @ 62869.91 | PnL: -2824.56 | Capital: 128109.28 | Reason: Prediction above long threshold (close short)
# 5846
# 2024-08-27 21:17:59.162000: BUY_OPEN 1.88 @ 61320.36 (Prob: -0.4237) | Capital: 128109.28
# 5878 61259.1 61323.9532
# 2024-09-02 10:23:12.723000: SELL_CLOSE_LONG 1.88 @ 58459.78 | PnL: -5430.88 | Capital: 122678.40 | Reason: Prediction below short threshold (close long)
# 6320
# 2024-09-02 20:55:27.086000: SELL_SHORT_OPEN -1.86 @ 59182.76 (Prob: 0.3835) | Capital: 122678.40
# 6344 59242.0 59167.3092
# 2024-09-06 17:14:44.013000: BUY_TO_COVER_SHORT 1.86 @ 54293.24 | PnL: 9066.64 | Capital: 131745.05 | Reason: Prediction above long threshold (close short)
# 6674
# 2024-09-06 17:26:00.030000: BUY_OPEN 2.18 @ 54461.71 (Prob: -0.3623) | Capital: 131745.05
# 6675 54407.3 57219.026020000005
# 2024-09-09 21:15:26.446000: SELL_CLOSE_LONG 2.18 @ 57904.44 | PnL: 7428.54 | Capital: 139173.59 | Reason: Prediction below short threshold (close long)
# 6879
# 2024-09-09 21:15:28.597000: SELL_SHORT_OPEN -2.16 @ 58083.96 (Prob: 0.3677) | Capital: 139173.59
# 6880 58142.1 55728.75982
# 2024-09-16 13:33:05.032000: BUY_TO_COVER_SHORT 2.16 @ 58423.87 | PnL: -795.60 | Capital: 138377.99 | Reason: Prediction above long threshold (close short)
# 7215
# 2024-10-06 14:47:55.024000: SELL_SHORT_OPEN -1.99 @ 62538.60 (Prob: 0.5573) | Capital: 138377.99
# 8220 62601.2 62507.38
# 2024-10-23 04:39:26.928000: BUY_TO_COVER_SHORT 1.99 @ 67263.90 | PnL: -9472.26 | Capital: 128905.73 | Reason: Prediction above long threshold (close short)
# 8912
# 2024-10-23 09:15:01.033000: BUY_OPEN 1.75 @ 66226.66 (Prob: -0.3887) | Capital: 128905.73
# 8919 66160.5 66177.908
# 2024-10-30 13:50:48.427000: SELL_CLOSE_LONG 1.75 @ 71764.36 | PnL: 9633.22 | Capital: 138538.95 | Reason: Prediction below short threshold (close long)
# 9233
# 2024-10-30 13:53:35.012000: SELL_SHORT_OPEN -1.73 @ 71986.84 (Prob: 0.3550) | Capital: 138538.95
# 9234 72058.9 68359.5952
# 2024-11-05 18:12:16.072000: BUY_TO_COVER_SHORT 1.73 @ 69808.84 | PnL: 3710.10 | Capital: 142249.05 | Reason: Prediction above long threshold (close short)
# 9553
# 2024-11-05 19:50:12.767000: BUY_OPEN 1.84 @ 69591.12 (Prob: -0.3774) | Capital: 142249.05
# 9558 69521.6 69736.2734
# 2024-11-11 23:06:51.598000: SELL_CLOSE_LONG 1.84 @ 88638.27 | PnL: 34941.32 | Capital: 177190.37 | Reason: Prediction below short threshold (close long)
# 10197
# 2024-11-11 23:10:29.683000: SELL_SHORT_OPEN -1.79 @ 88913.50 (Prob: 0.3604) | Capital: 177190.37
# 10198 89002.5 79258.503
# 2024-11-12 14:30:40.607000: BUY_TO_COVER_SHORT 1.79 @ 86040.45 | PnL: 5073.27 | Capital: 182263.64 | Reason: Prediction above long threshold (close short)
# 10367
# 2024-11-13 23:29:07.654000: SELL_SHORT_OPEN -1.82 @ 90243.47 (Prob: 0.3504) | Capital: 182263.64
# 10690 90333.8 88715.6704
# 2024-11-24 11:34:27.722000: BUY_TO_COVER_SHORT 1.82 @ 97514.42 | PnL: -13298.52 | Capital: 168965.12 | Reason: Prediction above long threshold (close short)
# 11560
# 2024-11-25 15:11:47.032000: BUY_OPEN 1.60 @ 95048.65 (Prob: -0.3811) | Capital: 168965.12
# 11634 94953.7 95063.571
# 2024-11-29 14:52:07.070000: SELL_CLOSE_LONG 1.60 @ 97686.22 | PnL: 4139.63 | Capital: 173104.75 | Reason: Prediction below short threshold (close long)
# 11949
# 2024-11-29 14:59:30.840000: SELL_SHORT_OPEN -1.59 @ 97989.11 (Prob: 0.3610) | Capital: 173104.75
# 11950 98087.2 95532.2884
# 2024-12-05 20:32:09.326000: BUY_TO_COVER_SHORT 1.59 @ 98332.83 | PnL: -624.35 | Capital: 172480.40 | Reason: Prediction above long threshold (close short)
# 12367
# 2024-12-05 22:26:41.176000: BUY_OPEN 1.58 @ 98022.82 (Prob: -0.3679) | Capital: 172480.40
# 12378 97924.9 98004.026
# 2024-12-20 12:32:30.027000: SELL_CLOSE_LONG 1.58 @ 93732.97 | PnL: -6864.35 | Capital: 165616.05 | Reason: Prediction below short threshold (close long)
# 13683
# 2024-12-21 07:35:10.664000: SELL_SHORT_OPEN -1.51 @ 98880.82 (Prob: 0.8740) | Capital: 165616.05
# 13766 98979.8 98764.82979999999
# 2024-12-28 11:56:41.023000: BUY_TO_COVER_SHORT 1.51 @ 94937.84 | PnL: 5869.21 | Capital: 171485.27 | Reason: Prediction above long threshold (close short)
# 14228
# 2024-12-28 13:00:00.462000: BUY_OPEN 1.63 @ 94643.45 (Prob: -0.3587) | Capital: 171485.27
# 14229 94548.9 96127.04319999999
# 2025-01-05 20:48:50.478000: SELL_CLOSE_LONG 1.63 @ 98066.74 | PnL: 5499.70 | Capital: 176984.97 | Reason: Prediction below short threshold (close long)
# 14554
# 2025-01-05 21:54:24.020000: SELL_SHORT_OPEN -1.62 @ 98370.93 (Prob: 0.3577) | Capital: 176984.97
# 14555 98469.4 95576.51879999999
# 2025-01-08 22:41:04.022000: BUY_TO_COVER_SHORT 1.62 @ 95188.99 | PnL: 5072.73 | Capital: 182057.70 | Reason: Prediction above long threshold (close short)
# 14772
# 2025-01-09 01:24:13.999000: BUY_OPEN 1.72 @ 95403.91 (Prob: -0.3552) | Capital: 182057.70
# 14773 95308.6 96163.095
# 2025-01-14 14:43:20.421000: SELL_CLOSE_LONG 1.72 @ 96745.86 | PnL: 2220.55 | Capital: 184278.25 | Reason: Prediction below short threshold (close long)
# 15170
# 2025-01-14 14:47:06.516000: SELL_SHORT_OPEN -1.72 @ 96445.86 (Prob: 0.3531) | Capital: 184278.25
# 15171 96542.4 93753.569
# 2025-01-19 22:39:34.806000: BUY_TO_COVER_SHORT 1.72 @ 103292.29 | PnL: -11856.16 | Capital: 172422.09 | Reason: Prediction above long threshold (close short)
# 15537
# 2025-01-19 23:31:15.198000: BUY_OPEN 1.55 @ 100116.92 (Prob: -0.5190) | Capital: 172422.09
# 15579 100016.9 100125.428
# 2025-01-21 23:04:22.344000: SELL_CLOSE_LONG 1.55 @ 105610.38 | PnL: 8428.74 | Capital: 180850.83 | Reason: Prediction below short threshold (close long)
# 16254
# 2025-01-21 23:20:07.892000: SELL_SHORT_OPEN -1.54 @ 105937.96 (Prob: 0.3528) | Capital: 180850.83
# 16255 106044.0 104121.64039999999
# 2025-01-24 14:18:39.036000: BUY_TO_COVER_SHORT 1.54 @ 105252.15 | PnL: 972.35 | Capital: 181823.18 | Reason: Prediction above long threshold (close short)
# 16637
# 2025-01-24 23:04:34.396000: BUY_OPEN 1.56 @ 104584.48 (Prob: -0.5990) | Capital: 181823.18
# 16671 104480.0 104502.59659999999
# 2025-01-29 02:15:34.923000: SELL_CLOSE_LONG 1.56 @ 101805.09 | PnL: -4426.27 | Capital: 177396.90 | Reason: Prediction below short threshold (close long)
# 16950
# 2025-01-29 18:48:39.030000: SELL_SHORT_OPEN -1.55 @ 102748.05 (Prob: 0.5175) | Capital: 177396.90
# 16969 102850.9 102772.548
# 2025-02-03 00:46:52.878000: BUY_TO_COVER_SHORT 1.55 @ 96545.45 | PnL: 9558.25 | Capital: 186955.16 | Reason: Prediction above long threshold (close short)
# 17256
# 2025-02-03 00:47:32.942000: BUY_OPEN 1.75 @ 96246.15 (Prob: -0.3625) | Capital: 186955.16
# 17257 96150.0 100880.406
# 2025-02-03 17:54:19.024000: SELL_CLOSE_LONG 1.75 @ 98953.75 | PnL: 4644.66 | Capital: 191599.82 | Reason: Prediction below short threshold (close long)
# 17521
# 2025-02-03 17:55:28.990000: SELL_SHORT_OPEN -1.75 @ 98646.95 (Prob: 0.3655) | Capital: 191599.82
# 17522 98745.7 97262.563
# 2025-02-06 18:34:26.787000: BUY_TO_COVER_SHORT 1.75 @ 96327.93 | PnL: 3967.59 | Capital: 195567.41 | Reason: Prediction above long threshold (close short)
# 17822
# 2025-02-06 18:49:32.860000: BUY_OPEN 1.82 @ 96627.13 (Prob: -0.3616) | Capital: 195567.41
# 17823 96530.6 97197.41
# 2025-02-14 14:39:16.539000: SELL_CLOSE_LONG 1.82 @ 97058.14 | PnL: 696.37 | Capital: 196263.78 | Reason: Prediction below short threshold (close long)
# 18189
# 2025-02-14 14:53:10.720000: SELL_SHORT_OPEN -1.81 @ 97359.14 (Prob: 0.3553) | Capital: 196263.78
# 18190 97456.6 96912.39119999998
# 2025-02-25 07:35:04.352000: BUY_TO_COVER_SHORT 1.81 @ 88784.60 | PnL: 15468.41 | Capital: 211732.19 | Reason: Prediction above long threshold (close short)
# 18560
# 2025-02-25 07:35:14.007000: BUY_OPEN 2.15 @ 88509.22 (Prob: -0.3639) | Capital: 211732.19
# 18561 88420.8 95399.769
# 2025-02-26 15:28:27.545000: SELL_CLOSE_LONG 2.15 @ 87708.80 | PnL: -1816.80 | Capital: 209915.39 | Reason: Prediction below short threshold (close long)
# 18788
# 2025-03-02 17:31:06.007000: SELL_SHORT_OPEN -2.03 @ 92796.91 (Prob: 0.3528) | Capital: 209915.39
# 19568 92889.8 83596.25720000001
# 2025-03-03 14:56:34.208000: BUY_TO_COVER_SHORT 2.03 @ 89706.12 | PnL: 6198.09 | Capital: 216113.48 | Reason: Prediction above long threshold (close short)
# 19726
# 2025-03-03 18:26:06.698000: BUY_OPEN 2.19 @ 88577.29 (Prob: -0.7088) | Capital: 216113.48
# 19780 88488.8 88569.0168
# 2025-03-04 16:14:21.032000: SELL_CLOSE_LONG 2.19 @ 82873.54 | PnL: -12609.23 | Capital: 203504.25 | Reason: Prediction below short threshold (close long)
# 20103
# 2025-03-04 18:53:21.051000: SELL_SHORT_OPEN -2.12 @ 86266.05 (Prob: 0.6963) | Capital: 203504.25
# 20146 86352.4 86297.3174
# 2025-03-07 00:25:25.935000: BUY_TO_COVER_SHORT 2.12 @ 87212.12 | PnL: -2100.17 | Capital: 201404.07 | Reason: Prediction above long threshold (close short)
# 20559
# 2025-03-07 00:25:41.346000: BUY_OPEN 2.08 @ 86941.75 (Prob: -0.3597) | Capital: 201404.07
# 20560 86854.9 88203.38139999998
# 2025-03-10 00:21:15.587000: SELL_CLOSE_LONG 2.08 @ 80358.56 | PnL: -13802.08 | Capital: 187601.99 | Reason: Prediction below short threshold (close long)
# 21002
# 2025-03-16 22:09:36.927000: BUY_OPEN 2.05 @ 82293.81 (Prob: -0.5654) | Capital: 187601.99
# 21840 82211.6 82460.9194
# 2025-03-23 17:19:27.131000: SELL_CLOSE_LONG 2.05 @ 85289.53 | PnL: 6055.77 | Capital: 193657.76 | Reason: Prediction below short threshold (close long)
# 22147
# 2025-03-23 17:32:31.067000: SELL_SHORT_OPEN -2.05 @ 85024.89 (Prob: 0.3621) | Capital: 193657.76
# 22148 85110.0 83589.21
# 2025-03-31 03:30:45.550000: BUY_TO_COVER_SHORT 2.05 @ 81921.24 | PnL: 6275.05 | Capital: 199932.81 | Reason: Prediction above long threshold (close short)
# 22436
# 2025-03-31 03:48:20.372000: BUY_OPEN 2.20 @ 81667.19 (Prob: -0.3591) | Capital: 199932.81
# 22437 81585.6 85061.6202
# 2025-04-02 20:28:09.999000: SELL_CLOSE_LONG 2.20 @ 85225.69 | PnL: 7742.79 | Capital: 207675.60 | Reason: Prediction below short threshold (close long)
# 22628
# 2025-04-02 20:28:11.587000: SELL_SHORT_OPEN -2.19 @ 85491.42 (Prob: 0.3610) | Capital: 207675.60
# 22629 85577.0 85172.4178
# 2025-04-07 05:05:31.040000: BUY_TO_COVER_SHORT 2.19 @ 76761.08 | PnL: 18993.54 | Capital: 226669.14 | Reason: Prediction above long threshold (close short)
# 23038
# 2025-04-07 05:09:10.124000: BUY_OPEN 2.65 @ 76999.22 (Prob: -0.3556) | Capital: 226669.14
# 23039 76922.3 82366.75159999999
# 2025-04-07 14:32:48.743000: SELL_CLOSE_LONG 2.65 @ 78710.21 | PnL: 4426.62 | Capital: 231095.76 | Reason: Prediction below short threshold (close long)
# 23227
# 2025-04-07 14:33:51.767000: SELL_SHORT_OPEN -2.59 @ 80355.66 (Prob: 0.3606) | Capital: 231095.76
# 23231 80436.1 79592.5172
# 2025-04-09 05:28:40.627000: BUY_TO_COVER_SHORT 2.59 @ 76829.75 | PnL: 9022.25 | Capital: 240118.01 | Reason: Prediction above long threshold (close short)
# 23534
# 2025-04-09 05:31:56.146000: BUY_OPEN 2.82 @ 76591.51 (Prob: -0.3585) | Capital: 240118.01
# 23535 76515.0 77750.31180000001
# 2025-04-23 00:02:51.002000: SELL_CLOSE_LONG 2.82 @ 93601.01 | PnL: 47837.03 | Capital: 287955.04 | Reason: Prediction below short threshold (close long)
# 24437
# 2025-04-23 00:11:03.558000: SELL_SHORT_OPEN -2.78 @ 93310.50 (Prob: 0.3598) | Capital: 287955.04
# 24438 93403.9 85925.71620000001
# 2025-05-01 13:20:41.115000: BUY_TO_COVER_SHORT 2.78 @ 96580.38 | PnL: -9211.27 | Capital: 278743.77 | Reason: Prediction above long threshold (close short)
# 24732
# 2025-05-06 13:51:04.162000: BUY_OPEN 2.68 @ 93619.13 (Prob: -0.4574) | Capital: 278743.77
# 24840 93525.6 93721.9624
# 2025-06-12 14:07:17.206000: SELL_CLOSE_LONG 2.68 @ 107147.15 | PnL: 36089.17 | Capital: 314832.95 | Reason: Prediction below short threshold (close long)
# 26157
# 2025-06-12 14:37:19.584000: SELL_SHORT_OPEN -2.64 @ 107479.31 (Prob: 0.3628) | Capital: 314832.95
# 26158 107586.9 106527.8488
# 2025-06-22 16:25:01.034000: BUY_TO_COVER_SHORT 2.64 @ 98730.63 | PnL: 22922.70 | Capital: 337755.65 | Reason: Prediction above long threshold (close short)
# 26492
# 2025-06-22 16:36:27.288000: BUY_OPEN 3.07 @ 99036.94 (Prob: -0.3600) | Capital: 337755.65
# 26493 98938.0 105034.95079999999
# 2025-08-01 22:06:33.135000: SELL_CLOSE_LONG 3.07 @ 113418.27 | PnL: 43945.46 | Capital: 381701.11 | Reason: Prediction below short threshold (close long)
# 27633
# 2025-08-07 11:28:58.298000: SELL_SHORT_OPEN -2.94 @ 116615.37 (Prob: 0.4601) | Capital: 381701.11
# 27741 116732.1 116582.9446
# 2025-08-19 10:08:17.693000: BUY_TO_COVER_SHORT 2.94 @ 115571.76 | PnL: 2902.64 | Capital: 384603.75 | Reason: Prediction above long threshold (close short)
# 28061
# 2025-08-19 13:30:52.100000: BUY_OPEN 2.98 @ 115930.21 (Prob: -0.3575) | Capital: 384603.75
# 28062 115814.4 117044.0416
# End of Backtest: SELL_FINAL_LONG 2.98 @ 112417.87 | PnL: -10649.63 | Capital: 384603.75
#
# ============================================================
# Backtesting Results Summary (Long-Short Strategy):
# Initial Capital: 100000.00
# Final Capital: 384603.75
# Total Return: 284.60%
# Total Realized PnL: 273954.12
# 年化收益 (近似): 222.58%
# Maximum Drawdown: -16.96%
# Sharpe Ratio (Risk-Free Rate = 0): 945.51
# Number of Trades: 100
# Win Rate: 66.00%
# ============================================================
# reverse ma

# %%
import polars as pl
import matplotlib.pyplot as plt
a="z_oi_di_zscaled"
b="oi_di_zscaled"
# 假设 origin_df 是你的 Polars DataFrame
# 转成 pandas DataFrame
pdf = origin_df.select([
    a,
    b,
    "px"
]).to_pandas()[-150000:]
pdf['ma'] = pdf['px'].rolling(window=500).mean()


fig, ax1 = plt.subplots(figsize=(12, 6))

ax2 = ax1.twinx()  # 第二个y轴，右侧
ax3 = ax1.twinx()  # 第三个y轴，右侧，需要偏移避免重叠

# 偏移第三个y轴，让它不和第二个y轴重叠
ax3.spines["right"].set_position(("axes", 1.1))  # 向右偏移 10%

# 画线
ax1.plot(pdf[a], color='blue', label=a)
ax1.set_ylabel(a, color='blue')
ax1.tick_params(axis='y', colors='blue')

ax2.plot(pdf['ma'], color='orange', label='ma')
ax2.set_ylabel('ma', color='orange')
ax2.tick_params(axis='y', colors='orange')

ax3.plot(pdf["px"], color='green', label="px")
ax3.set_ylabel("px", color='green')
ax3.tick_params(axis='y', colors='green')

plt.title("Three curves with independent y axes")
plt.xlabel("Index")

# 合并图例
lines_1, labels_1 = ax1.get_legend_handles_labels()
lines_2, labels_2 = ax2.get_legend_handles_labels()
lines_3, labels_3 = ax3.get_legend_handles_labels()
plt.legend(lines_1 + lines_2 + lines_3, labels_1 + labels_2 + labels_3, loc='upper left')

plt.show()

# %%
print(all_predictions_df[feat])
print(all_predictions_df["ma"])

plot_last_n_rows_with_px(
    all_predictions_df[feat], 
    all_predictions_df["ma"],
    all_predictions_df[feat], 
    all_predictions_df['px'],
    std_array=all_predictions_df['rolling_std'],
    n=1,
    m=-1,
    alpha=beta,
)
# Out:
# 0        0.000000
# 1       -0.304430
# 2       -0.448176
# 3       -0.530915
# 4       -0.584140
#            ...
# 28224   -0.694526
# 28225   -0.694777
# 28226   -0.694998
# 28227   -0.695189
# 28228   -0.695351
# Name: z_oi_di_zscaled, Length: 28229, dtype: float64
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN
#             ...
# 28224    116913.0480
# 28225    116907.8702
# 28226    116902.6764
# 28227    116896.0710
# 28228    116890.8778
# Name: ma, Length: 28229, dtype: float64

# %%
print(all_predictions_df[feat])
plot_last_n_rows_with_px(
    all_predictions_df[feat], 
    all_predictions_df[feat],      
    all_predictions_df[feat], 
    all_predictions_df['px'],
    std_array=all_predictions_df['rolling_std'],
    n=1,
    m=-1,
    alpha=beta,
)
# Out:
# 0        0.000000
# 1       -0.304430
# 2       -0.448176
# 3       -0.530915
# 4       -0.584140
#            ...
# 28224   -0.694526
# 28225   -0.694777
# 28226   -0.694998
# 28227   -0.695189
# 28228   -0.695351
# Name: z_oi_di_zscaled, Length: 28229, dtype: float64
